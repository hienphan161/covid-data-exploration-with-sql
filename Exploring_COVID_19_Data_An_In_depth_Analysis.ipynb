# %% [markdown]
# # Exploring COVID-19 Data: An In-depth Analysis
#
# <div>
# <img src=https://thanhtra.com.vn/data/images/0/2021/12/05/congdinh/blue-covid-banner.jpg width="1500">
# </div>

# %% [markdown]
# # Introduction

# %% [markdown]
# In the face of the global COVID-19 pandemic, understanding the data behind the numbers is crucial. This project dives deep into COVID-19 datasets, leveraging data analysis and SQL querying to extract meaningful insights. We explore key metrics such as total cases, deaths, vaccinations, and their percentages, shedding light on the pandemic's impact worldwide.

# %% [markdown]
# ## Project Highlights

# %% [markdown]
# 1. **Connect to the Database:**
#    - Utilize SQLite to connect to an SQLite database for efficient data manipulation.
#
# 2. **Load the Dataset:**
#    - Import COVID-19 datasets from CSV files into the SQLite database for easy access.
#
# 3. **Data Exploration:**
#    - Preprocess `COVID_DEATHS` and `COVID_VACCINATIONS` datasets, correcting data types and creating processed tables.
#
# 4. **Global COVID-19 Overview:**
#    - Analyze global COVID-19 statistics, including total cases, deaths, vaccination efforts, and related percentages.
#    - Visualize trends in new COVID-19 cases, deaths, and vaccinations worldwide over time.
#
# 5. **COVID-19 Impact Across Continents:**
#    - Explore COVID-19 metrics for continents, examining infection rates, mortality, and vaccination progress.
#
# 6. **COVID-19 Impact Across Income Levels:**
#    - Analyze COVID-19 impact and vaccination responses based on income levels, highlighting disparities.
#
# 7. **COVID-19 Impact Across Countries:**
#    - Delve into COVID-19 metrics for individual countries, focusing on population, total cases, deaths, vaccinations, and trends.
#    - Visualize regional patterns, vaccination progress, and challenges faced by countries.
#
# 8. **COVID-19 Trends in Vietnam:**
#    - Focus specifically on Vietnam's COVID-19 situation, examining total cases, deaths, vaccinations, and trends over time.
#    - Visualize the progression of the pandemic in Vietnam, highlighting key insights.

# %% [markdown]
# ## Skills Utilized

# %% [markdown]
# - **Joins:** Connecting data from multiple sources for comprehensive analysis.
#
# - **Common Table Expressions (CTE's):** Simplifying complex queries and calculations.
#
# - **Temporary Tables:** Storing interim results for efficient data manipulation.
#
# - **Window Functions:** Performing computations over specified subsets of data.
#
# - **Aggregate Functions:** Summarizing data to reveal trends and patterns.
#
# - **Creating Views:** Organizing data for future reference and visualization.
#
# - **Converting Data Types:** Ensuring data compatibility and accuracy.

# %% [markdown]
# This project not only showcases SQL proficiency but also aims to uncover trends, disparities, and progress in the fight against COVID-19. Join us on this data-driven journey as we unravel the story behind the numbers.

# %% [markdown]
# ## Overview of the Dataset

# %% [markdown]
# In this project, we focus on analyzing specific aspects of the extensive [COVID-19 dataset](https://ourworldindata.org/covid-deaths). This dataset is diligently maintained by [Our World in Data](https://ourworldindata.org), with daily updates to ensure it reflects the latest information relevant to the COVID-19 pandemic. It encompasses a diverse range of crucial metrics sourced from reputable institutions, guaranteeing accuracy and reliability.
#
# Our analysis hones in on the following key variables:
#
# - **Confirmed Cases:** Total and new confirmed cases, smoothed averages, and cases per million people.
# - **Confirmed Deaths:** Total and new deaths attributed to COVID-19, smoothed averages, and deaths per million people.
# - **Vaccinations:** Total doses administered, people vaccinated, fully vaccinated, and booster doses.
#
# The dataset we're using contains 390,786 rows spanning from January 1, 2020, to April 18, 2024. It is divided into two CSV files:
#
# - **CovidDeaths.csv**: Contains the data on confirmed cases and deaths.
# - **CovidVaccinations.csv**: Contains the data on vaccinations.
#
# For further insights, you can explore the complete dataset [here](https://github.com/owid/covid-19-data/tree/master/public/data).

# %% [markdown]
# # Connect to Database

# %% [markdown]
# We will use the SQLite database in this project to easily work with SQL on Google Colab.

# %%
import sqlite3

# Connect to an SQLite database; use ':memory:' for an in-memory database
conn = sqlite3.connect('covid_data.db')

# %%
# %%capture
# Install ipython-sql
# !pip install ipython-sql

# %%
# Load the SQL extension
# %load_ext sql

# Create a SQLite database
# %sql sqlite:///covid_data.db

# %% [markdown]
# # Load the Dataset

# %% [markdown]
# We will import the dataset from CSV files into the SQLite database we've created.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Datasets/CovidDeaths.csv")
df.to_sql("COVID_DEATHS", conn, if_exists="append", chunksize=100, index=False, method="multi")
# Out:
# 390786

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/CovidVaccinations.csv")
df.to_sql("COVID_VACCINATIONS", conn, if_exists="append", chunksize=100, index=False, method="multi")
# Out:
# 390786

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Let's start with the `COVID_DEATHS` dataset, which contains the data on confirmed cases and deaths.

# %%
# %%sql
# SELECT continent, location, date, population, total_cases, new_cases, total_deaths, new_deaths
# FROM COVID_DEATHS
# ORDER BY location, date
# LIMIT 100 -- due to limited resources
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Asia', 'Afghanistan', '1/1/2021', 41128772, 51848.0, 0.0, 2158.0, 0.0),
#  ('Asia', 'Afghanistan', '1/1/2022', 41128772, 157902.0, 0.0, 7352.0, 0.0),
#  ('Asia', 'Afghanistan', '1/1/2023', 41128772, 207579.0, 257.0, 7849.0, 4.0),
#  ('Asia', 'Afghanistan', '1/1/2024', 41128772, 230375.0, 0.0, 7973.0, 0.0),
#  ('Asia', 'Afghanistan', '1/10/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/10/2021', 41128772, 53489.0, 780.0, 2277.0, 56.0),
#  ('Asia', 'Afghanistan', '1/10/2022', 41128772, 158345.0, 0.0, 7369.0, 0.0),
#  ('Asia', 'Afghanistan', '1/10/2023', 41128772, 207780.0, 0.0, 7851.0, 0.0),
#  ('Asia', 'Afghanistan', '1/10/2024', 41128772, 230642.0, 0.0, 7973.0, 0.0),
#  ('Asia', 'Afghanistan', '1/11/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/11/2021', 41128772, 53489.0, 0.0, 2277.0, 0.0),
#  ('Asia', 'Afghanistan', '1/11/2022', 41128772, 158345.0, 0.0, 7369.0, 0.0),
#  ('Asia', 'Afghanistan', '1/11/2023', 41128772, 207780.0, 0.0, 7851.0, 0.0),
#  ('Asia', 'Afghanistan', '1/11/2024', 41128772, 230642.0, 0.0, 7973.0, 0.0),
#  ('Asia', 'Afghanistan', '1/12/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/12/2021', 41128772, 53489.0, 0.0, 2277.0, 0.0),
#  ('Asia', 'Afghanistan', '1/12/2022', 41128772, 158345.0, 0.0, 7369.0, 0.0),
#  ('Asia', 'Afghanistan', '1/12/2023', 41128772, 207780.0, 0.0, 7851.0, 0.0),
#  ('Asia', 'Afghanistan', '1/12/2024', 41128772, 230642.0, 0.0, 7973.0, 0.0),
#  ('Asia', 'Afghanistan', '1/13/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/13/2021', 41128772, 53489.0, 0.0, 2277.0, 0.0),
#  ('Asia', 'Afghanistan', '1/13/2022', 41128772, 158345.0, 0.0, 7369.0, 0.0),
#  ('Asia', 'Afghanistan', '1/13/2023', 41128772, 207780.0, 0.0, 7851.0, 0.0),
#  ('Asia', 'Afghanistan', '1/13/2024', 41128772, 230642.0, 0.0, 7973.0, 0.0),
#  ('Asia', 'Afghanistan', '1/14/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/14/2021', 41128772, 53489.0, 0.0, 2277.0, 0.0),
#  ('Asia', 'Afghanistan', '1/14/2022', 41128772, 158345.0, 0.0, 7369.0, 0.0),
#  ('Asia', 'Afghanistan', '1/14/2023', 41128772, 207780.0, 0.0, 7851.0, 0.0),
#  ('Asia', 'Afghanistan', '1/14/2024', 41128772, 230878.0, 236.0, 7975.0, 2.0),
#  ('Asia', 'Afghanistan', '1/15/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/15/2021', 41128772, 53489.0, 0.0, 2277.0, 0.0),
#  ('Asia', 'Afghanistan', '1/15/2022', 41128772, 158345.0, 0.0, 7369.0, 0.0),
#  ('Asia', 'Afghanistan', '1/15/2023', 41128772, 207953.0, 173.0, 7855.0, 4.0),
#  ('Asia', 'Afghanistan', '1/15/2024', 41128772, 230878.0, 0.0, 7975.0, 0.0),
#  ('Asia', 'Afghanistan', '1/16/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/16/2021', 41128772, 53489.0, 0.0, 2277.0, 0.0),
#  ('Asia', 'Afghanistan', '1/16/2022', 41128772, 158678.0, 333.0, 7378.0, 9.0),
#  ('Asia', 'Afghanistan', '1/16/2023', 41128772, 207953.0, 0.0, 7855.0, 0.0),
#  ('Asia', 'Afghanistan', '1/16/2024', 41128772, 230878.0, 0.0, 7975.0, 0.0),
#  ('Asia', 'Afghanistan', '1/17/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/17/2021', 41128772, 53984.0, 495.0, 2339.0, 62.0),
#  ('Asia', 'Afghanistan', '1/17/2022', 41128772, 158678.0, 0.0, 7378.0, 0.0),
#  ('Asia', 'Afghanistan', '1/17/2023', 41128772, 207953.0, 0.0, 7855.0, 0.0),
#  ('Asia', 'Afghanistan', '1/17/2024', 41128772, 230878.0, 0.0, 7975.0, 0.0),
#  ('Asia', 'Afghanistan', '1/18/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/18/2021', 41128772, 53984.0, 0.0, 2339.0, 0.0),
#  ('Asia', 'Afghanistan', '1/18/2022', 41128772, 158678.0, 0.0, 7378.0, 0.0),
#  ('Asia', 'Afghanistan', '1/18/2023', 41128772, 207953.0, 0.0, 7855.0, 0.0),
#  ('Asia', 'Afghanistan', '1/18/2024', 41128772, 230878.0, 0.0, 7975.0, 0.0),
#  ('Asia', 'Afghanistan', '1/19/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/19/2021', 41128772, 53984.0, 0.0, 2339.0, 0.0),
#  ('Asia', 'Afghanistan', '1/19/2022', 41128772, 158678.0, 0.0, 7378.0, 0.0),
#  ('Asia', 'Afghanistan', '1/19/2023', 41128772, 207953.0, 0.0, 7855.0, 0.0),
#  ('Asia', 'Afghanistan', '1/19/2024', 41128772, 230878.0, 0.0, 7975.0, 0.0),
#  ('Asia', 'Afghanistan', '1/2/2021', 41128772, 51848.0, 0.0, 2158.0, 0.0),
#  ('Asia', 'Afghanistan', '1/2/2022', 41128772, 158112.0, 210.0, 7356.0, 4.0),
#  ('Asia', 'Afghanistan', '1/2/2023', 41128772, 207579.0, 0.0, 7849.0, 0.0),
#  ('Asia', 'Afghanistan', '1/2/2024', 41128772, 230375.0, 0.0, 7973.0, 0.0),
#  ('Asia', 'Afghanistan', '1/20/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/20/2021', 41128772, 53984.0, 0.0, 2339.0, 0.0),
#  ('Asia', 'Afghanistan', '1/20/2022', 41128772, 158678.0, 0.0, 7378.0, 0.0),
#  ('Asia', 'Afghanistan', '1/20/2023', 41128772, 207953.0, 0.0, 7855.0, 0.0),
#  ('Asia', 'Afghanistan', '1/20/2024', 41128772, 230878.0, 0.0, 7975.0, 0.0),
#  ('Asia', 'Afghanistan', '1/21/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/21/2021', 41128772, 53984.0, 0.0, 2339.0, 0.0),
#  ('Asia', 'Afghanistan', '1/21/2022', 41128772, 158678.0, 0.0, 7378.0, 0.0),
#  ('Asia', 'Afghanistan', '1/21/2023', 41128772, 207953.0, 0.0, 7855.0, 0.0),
#  ('Asia', 'Afghanistan', '1/21/2024', 41128772, 231075.0, 197.0, 7976.0, 1.0),
#  ('Asia', 'Afghanistan', '1/22/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/22/2021', 41128772, 53984.0, 0.0, 2339.0, 0.0),
#  ('Asia', 'Afghanistan', '1/22/2022', 41128772, 158678.0, 0.0, 7378.0, 0.0),
#  ('Asia', 'Afghanistan', '1/22/2023', 41128772, 208097.0, 144.0, 7860.0, 5.0),
#  ('Asia', 'Afghanistan', '1/22/2024', 41128772, 231075.0, 0.0, 7976.0, 0.0),
#  ('Asia', 'Afghanistan', '1/23/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/23/2021', 41128772, 53984.0, 0.0, 2339.0, 0.0),
#  ('Asia', 'Afghanistan', '1/23/2022', 41128772, 159548.0, 870.0, 7390.0, 12.0),
#  ('Asia', 'Afghanistan', '1/23/2023', 41128772, 208097.0, 0.0, 7860.0, 0.0),
#  ('Asia', 'Afghanistan', '1/23/2024', 41128772, 231075.0, 0.0, 7976.0, 0.0),
#  ('Asia', 'Afghanistan', '1/24/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/24/2021', 41128772, 54595.0, 611.0, 2378.0, 39.0),
#  ('Asia', 'Afghanistan', '1/24/2022', 41128772, 159548.0, 0.0, 7390.0, 0.0),
#  ('Asia', 'Afghanistan', '1/24/2023', 41128772, 208097.0, 0.0, 7860.0, 0.0),
#  ('Asia', 'Afghanistan', '1/24/2024', 41128772, 231075.0, 0.0, 7976.0, 0.0),
#  ('Asia', 'Afghanistan', '1/25/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/25/2021', 41128772, 54595.0, 0.0, 2378.0, 0.0),
#  ('Asia', 'Afghanistan', '1/25/2022', 41128772, 159548.0, 0.0, 7390.0, 0.0),
#  ('Asia', 'Afghanistan', '1/25/2023', 41128772, 208097.0, 0.0, 7860.0, 0.0),
#  ('Asia', 'Afghanistan', '1/25/2024', 41128772, 231075.0, 0.0, 7976.0, 0.0),
#  ('Asia', 'Afghanistan', '1/26/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/26/2021', 41128772, 54595.0, 0.0, 2378.0, 0.0),
#  ('Asia', 'Afghanistan', '1/26/2022', 41128772, 159548.0, 0.0, 7390.0, 0.0),
#  ('Asia', 'Afghanistan', '1/26/2023', 41128772, 208097.0, 0.0, 7860.0, 0.0),
#  ('Asia', 'Afghanistan', '1/26/2024', 41128772, 231075.0, 0.0, 7976.0, 0.0),
#  ('Asia', 'Afghanistan', '1/27/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/27/2021', 41128772, 54595.0, 0.0, 2378.0, 0.0),
#  ('Asia', 'Afghanistan', '1/27/2022', 41128772, 159548.0, 0.0, 7390.0, 0.0),
#  ('Asia', 'Afghanistan', '1/27/2023', 41128772, 208097.0, 0.0, 7860.0, 0.0),
#  ('Asia', 'Afghanistan', '1/27/2024', 41128772, 231075.0, 0.0, 7976.0, 0.0),
#  ('Asia', 'Afghanistan', '1/28/2020', 41128772, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '1/28/2021', 41128772, 54595.0, 0.0, 2378.0, 0.0)]

# %% [markdown]
# We can observe that the dataset is updated weekly, with new cases and new deaths reported only on Sundays. Therefore, in this analysis, the dates of events (if mentioned) are only accurate in weeks.
#
# Additionally, there seems to be an issue with the date column as the ordering does not function correctly in the previous query. Let's examine the table schema to identify the problem.

# %%
# %%sql
# PRAGMA table_info(COVID_DEATHS)
# Out:
#  * sqlite:///covid_data.db
# Done.
# [(0, 'iso_code', 'TEXT', 0, None, 0),
#  (1, 'continent', 'TEXT', 0, None, 0),
#  (2, 'location', 'TEXT', 0, None, 0),
#  (3, 'date', 'TEXT', 0, None, 0),
#  (4, 'population', 'INTEGER', 0, None, 0),
#  (5, 'total_cases', 'REAL', 0, None, 0),
#  (6, 'new_cases', 'REAL', 0, None, 0),
#  (7, 'new_cases_smoothed', 'REAL', 0, None, 0),
#  (8, 'total_deaths', 'REAL', 0, None, 0),
#  (9, 'new_deaths', 'REAL', 0, None, 0),
#  (10, 'new_deaths_smoothed', 'REAL', 0, None, 0),
#  (11, 'total_cases_per_million', 'REAL', 0, None, 0),
#  (12, 'new_cases_per_million', 'REAL', 0, None, 0),
#  (13, 'new_cases_smoothed_per_million', 'REAL', 0, None, 0),
#  (14, 'total_deaths_per_million', 'REAL', 0, None, 0),
#  (15, 'new_deaths_per_million', 'REAL', 0, None, 0),
#  (16, 'new_deaths_smoothed_per_million', 'REAL', 0, None, 0),
#  (17, 'reproduction_rate', 'REAL', 0, None, 0),
#  (18, 'icu_patients', 'REAL', 0, None, 0),
#  (19, 'icu_patients_per_million', 'REAL', 0, None, 0),
#  (20, 'hosp_patients', 'REAL', 0, None, 0),
#  (21, 'hosp_patients_per_million', 'REAL', 0, None, 0),
#  (22, 'weekly_icu_admissions', 'REAL', 0, None, 0),
#  (23, 'weekly_icu_admissions_per_million', 'REAL', 0, None, 0),
#  (24, 'weekly_hosp_admissions', 'REAL', 0, None, 0),
#  (25, 'weekly_hosp_admissions_per_million', 'REAL', 0, None, 0)]

# %% [markdown]
# We see that the `date` column is now stored as a string, which is not the correct datatype for a date. To fix this, we will convert this column to a `DATE` datatype.
#
# Next, we'll save the processed `date` column along with the other columns we're interested in into a temporary table called `COVID_DEATHS_PROCESSED` for future analysis.

# %%
# %%sql
# DROP TABLE IF EXISTS COVID_DEATHS_PROCESSED;
#
# CREATE TABLE COVID_DEATHS_PROCESSED
# (
#     continent TEXT,
#     location TEXT,
#     date DATE,
#     population REAL,
#     total_cases REAL,
#     new_cases REAL,
#     total_deaths REAL,
#     new_deaths REAL
# );
#
# INSERT INTO COVID_DEATHS_PROCESSED
# WITH date_split AS (
#     SELECT
#       continent,
#       location,
#       SUBSTR(date, 1, INSTR(date, '/') - 1) AS month,
#       SUBSTR(SUBSTR(date, INSTR(date, '/') + 1), 1, INSTR(SUBSTR(date, INSTR(date, '/') + 1), '/') - 1) AS date,
#       SUBSTR(SUBSTR(date, INSTR(date, '/') + 1), INSTR(SUBSTR(date, INSTR(date, '/') + 1), '/') + 1) AS year,
#       population,
#       total_cases,
#       new_cases,
#       total_deaths,
#       new_deaths
#     FROM COVID_DEATHS
# ),
# date_normalize AS (
#     SELECT
#       continent,
#       location,
#       year,
#       CASE WHEN LENGTH(month) == 1 THEN '0' || month ELSE month END AS month,
#       CASE WHEN LENGTH(date) == 1 THEN '0' || date ELSE date END AS date,
#       population,
#       total_cases,
#       new_cases,
#       total_deaths,
#       new_deaths
#     FROM date_split
# )
#
# SELECT
#     continent,
#     location,
#     DATE(year || '-' || month || '-' || date) AS date,
#     population,
#     total_cases,
#     new_cases,
#     total_deaths,
#     new_deaths
# FROM date_normalize
# ORDER BY location, date
# Out:
#  * sqlite:///covid_data.db
# Done.
# Done.
# 390786 rows affected.
# []

# %% [markdown]
# Let's review our new staging table.

# %%
# %%sql
# SELECT *
# FROM COVID_DEATHS_PROCESSED
# ORDER BY location, date
# LIMIT 100 -- due to limited resources
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Asia', 'Afghanistan', '2020-01-05', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-06', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-07', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-08', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-09', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-10', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-11', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-12', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-13', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-14', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-15', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-16', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-17', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-18', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-19', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-20', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-21', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-22', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-23', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-24', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-25', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-26', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-27', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-28', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-29', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-30', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-01-31', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-01', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-02', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-03', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-04', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-05', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-06', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-07', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-08', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-09', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-10', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-11', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-12', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-13', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-14', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-15', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-16', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-17', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-18', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-19', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-20', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-21', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-22', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-23', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-24', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-25', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-26', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-27', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-28', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-02-29', 41128772.0, None, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-01', 41128772.0, 1.0, 1.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-02', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-03', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-04', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-05', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-06', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-07', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-08', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-09', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-10', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-11', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-12', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-13', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-14', 41128772.0, 1.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-15', 41128772.0, 7.0, 6.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-16', 41128772.0, 7.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-17', 41128772.0, 7.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-18', 41128772.0, 7.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-19', 41128772.0, 7.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-20', 41128772.0, 7.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-21', 41128772.0, 7.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-22', 41128772.0, 24.0, 17.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-23', 41128772.0, 24.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-24', 41128772.0, 24.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-25', 41128772.0, 24.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-26', 41128772.0, 24.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-27', 41128772.0, 24.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-28', 41128772.0, 24.0, 0.0, None, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-29', 41128772.0, 91.0, 67.0, 2.0, 2.0),
#  ('Asia', 'Afghanistan', '2020-03-30', 41128772.0, 91.0, 0.0, 2.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-03-31', 41128772.0, 91.0, 0.0, 2.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-01', 41128772.0, 91.0, 0.0, 2.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-02', 41128772.0, 91.0, 0.0, 2.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-03', 41128772.0, 91.0, 0.0, 2.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-04', 41128772.0, 91.0, 0.0, 2.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-05', 41128772.0, 274.0, 183.0, 5.0, 3.0),
#  ('Asia', 'Afghanistan', '2020-04-06', 41128772.0, 274.0, 0.0, 5.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-07', 41128772.0, 274.0, 0.0, 5.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-08', 41128772.0, 274.0, 0.0, 5.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-09', 41128772.0, 274.0, 0.0, 5.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-10', 41128772.0, 274.0, 0.0, 5.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-11', 41128772.0, 274.0, 0.0, 5.0, 0.0),
#  ('Asia', 'Afghanistan', '2020-04-12', 41128772.0, 521.0, 247.0, 15.0, 10.0),
#  ('Asia', 'Afghanistan', '2020-04-13', 41128772.0, 521.0, 0.0, 15.0, 0.0)]

# %%
# %%sql
# PRAGMA table_info(COVID_DEATHS_PROCESSED)
# Out:
#  * sqlite:///covid_data.db
# Done.
# [(0, 'continent', 'TEXT', 0, None, 0),
#  (1, 'location', 'TEXT', 0, None, 0),
#  (2, 'date', 'DATE', 0, None, 0),
#  (3, 'population', 'REAL', 0, None, 0),
#  (4, 'total_cases', 'REAL', 0, None, 0),
#  (5, 'new_cases', 'REAL', 0, None, 0),
#  (6, 'total_deaths', 'REAL', 0, None, 0),
#  (7, 'new_deaths', 'REAL', 0, None, 0)]

# %% [markdown]
# Everything looks good. Now, let's explore the number of unique locations and continents in our dataset using the processed table.

# %%
# %%sql
# SELECT continent, GROUP_CONCAT(location, ',') AS location
# FROM (SELECT DISTINCT continent, location FROM COVID_DEATHS_PROCESSED)
# GROUP BY continent
# ORDER BY 1
# Out:
#  * sqlite:///covid_data.db
# Done.
# [(None, 'Africa,Asia,Europe,European Union,High income,Low income,Lower middle income,North America,Oceania,South America,Upper middle income,World'),
#  ('Africa', "Algeria,Angola,Benin,Botswana,Burkina Faso,Burundi,Cameroon,Cape Verde,Central African Republic,Chad,Comoros,Congo,Cote d'Ivoire,Democratic Republic  ... (260 characters truncated) ...  Tome and Principe,Senegal,Seychelles,Sierra Leone,Somalia,South Africa,South Sudan,Sudan,Tanzania,Togo,Tunisia,Uganda,Western Sahara,Zambia,Zimbabwe"),
#  ('Asia', 'Afghanistan,Armenia,Azerbaijan,Bahrain,Bangladesh,Bhutan,Brunei,Cambodia,China,Georgia,Hong Kong,India,Indonesia,Iran,Iraq,Israel,Japan,Jordan,Kazakh ... (153 characters truncated) ... Saudi Arabia,Singapore,South Korea,Sri Lanka,Syria,Taiwan,Tajikistan,Thailand,Timor,Turkey,Turkmenistan,United Arab Emirates,Uzbekistan,Vietnam,Yemen'),
#  ('Europe', 'Albania,Andorra,Austria,Belarus,Belgium,Bosnia and Herzegovina,Bulgaria,Croatia,Cyprus,Czechia,Denmark,England,Estonia,Faeroe Islands,Finland,France, ... (204 characters truncated) ... land,Norway,Poland,Portugal,Romania,Russia,San Marino,Scotland,Serbia,Slovakia,Slovenia,Spain,Sweden,Switzerland,Ukraine,United Kingdom,Vatican,Wales'),
#  ('North America', 'Anguilla,Antigua and Barbuda,Aruba,Bahamas,Barbados,Belize,Bermuda,Bonaire Sint Eustatius and Saba,British Virgin Islands,Canada,Cayman Islands,Costa ... (280 characters truncated) ... on,Saint Vincent and the Grenadines,Sint Maarten (Dutch part),Trinidad and Tobago,Turks and Caicos Islands,United States,United States Virgin Islands'),
#  ('Oceania', 'American Samoa,Australia,Cook Islands,Fiji,French Polynesia,Guam,Kiribati,Marshall Islands,Micronesia (country),Nauru,New Caledonia,New Zealand,Niue,Northern Mariana Islands,Palau,Papua New Guinea,Pitcairn,Samoa,Solomon Islands,Tokelau,Tonga,Tuvalu,Vanuatu,Wallis and Futuna'),
#  ('South America', 'Argentina,Bolivia,Brazil,Chile,Colombia,Ecuador,Falkland Islands,French Guiana,Guyana,Paraguay,Peru,Suriname,Uruguay,Venezuela')]

# %% [markdown]
# We can observe that there are rows where the `continent` is null, and the `location` is the continent itself (such as Asia, Africa, Europe, etc.), or descriptors like High income, Low income, Lower middle income, Upper middle income, or World.
#
# For our further analysis in this project, to obtain accurate numbers for each country, we will filter out the rows where the `continent` is null. If we need to gather the numbers for each continent, we will use the rows where the `continent` is null and the `location` is the respective continent.

# %% [markdown]
# Let's redirect our focus to the second table, `COVID_VACCINATIONS`.

# %%
# %%sql
# SELECT
#     continent,
#     location,
#     date,
#     total_vaccinations,
#     new_vaccinations,
#     people_vaccinated,
#     people_fully_vaccinated
# FROM COVID_VACCINATIONS
# ORDER BY location, date
# LIMIT 100 -- due to limited resources
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Asia', 'Afghanistan', '1/1/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/1/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/1/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/1/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/10/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/10/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/10/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/10/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/10/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/11/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/11/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/11/2022', 4925111.0, None, 4378818.0, 3814837.0),
#  ('Asia', 'Afghanistan', '1/11/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/11/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/12/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/12/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/12/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/12/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/12/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/13/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/13/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/13/2022', 4954809.0, None, 4405897.0, 3823786.0),
#  ('Asia', 'Afghanistan', '1/13/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/13/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/14/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/14/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/14/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/14/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/14/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/15/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/15/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/15/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/15/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/15/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/16/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/16/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/16/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/16/2023', 12603486.0, None, 11606705.0, 10894509.0),
#  ('Asia', 'Afghanistan', '1/16/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/17/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/17/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/17/2022', 4985047.0, None, 4432926.0, 3832821.0),
#  ('Asia', 'Afghanistan', '1/17/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/17/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/18/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/18/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/18/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/18/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/18/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/19/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/19/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/19/2022', 5004050.0, None, 4450211.0, 3836731.0),
#  ('Asia', 'Afghanistan', '1/19/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/19/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/2/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/2/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/2/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/2/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/20/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/20/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/20/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/20/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/20/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/21/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/21/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/21/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/21/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/21/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/22/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/22/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/22/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/22/2023', 12672379.0, None, 11672740.0, 10956289.0),
#  ('Asia', 'Afghanistan', '1/22/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/23/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/23/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/23/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/23/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/23/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/24/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/24/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/24/2022', 5046054.0, None, 4486527.0, 3851307.0),
#  ('Asia', 'Afghanistan', '1/24/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/24/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/25/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/25/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/25/2022', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/25/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/25/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/26/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/26/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/26/2022', 5074196.0, None, 4511372.0, 3866279.0),
#  ('Asia', 'Afghanistan', '1/26/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/26/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/27/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/27/2021', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/27/2022', 5081064.0, 6868.0, 4517380.0, 3868832.0),
#  ('Asia', 'Afghanistan', '1/27/2023', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/27/2024', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/28/2020', None, None, None, None),
#  ('Asia', 'Afghanistan', '1/28/2021', None, None, None, None)]

# %% [markdown]
# We've identified an issue with the data column, much like the `COVID_DEATHS` dataset. To address this, we'll preprocess it as we did earlier with the `COVID_DEATHS` dataset and then save it in a temporary table named `COVID_VACCINATIONS_PROCESSED`.

# %%
# %%sql
# DROP TABLE IF EXISTS COVID_VACCINATIONS_PROCESSED;
#
# CREATE TABLE COVID_VACCINATIONS_PROCESSED
# (
#     continent TEXT,
#     location TEXT,
#     date DATE,
#     total_vaccinations REAL,
#     new_vaccinations REAL,
#     people_vaccinated REAL,
#     people_fully_vaccinated REAL
# );
#
# INSERT INTO COVID_VACCINATIONS_PROCESSED
# WITH date_split AS (
#     SELECT
#       continent,
#       location,
#       SUBSTR(date, 1, INSTR(date, '/') - 1) AS month,
#       SUBSTR(SUBSTR(date, INSTR(date, '/') + 1), 1, INSTR(SUBSTR(date, INSTR(date, '/') + 1), '/') - 1) AS date,
#       SUBSTR(SUBSTR(date, INSTR(date, '/') + 1), INSTR(SUBSTR(date, INSTR(date, '/') + 1), '/') + 1) AS year,
#       total_vaccinations,
#       new_vaccinations,
#       people_vaccinated,
#       people_fully_vaccinated
#     FROM COVID_VACCINATIONS
# ),
# date_normalize AS (
#     SELECT
#       continent,
#       location,
#       year,
#       CASE WHEN LENGTH(month) == 1 THEN '0' || month ELSE month END AS month,
#       CASE WHEN LENGTH(date) == 1 THEN '0' || date ELSE date END AS date,
#       total_vaccinations,
#       new_vaccinations,
#       people_vaccinated,
#       people_fully_vaccinated
#     FROM date_split
# )
#
# SELECT
#     continent,
#     location,
#     DATE(year || '-' || month || '-' || date) AS date,
#     total_vaccinations,
#     new_vaccinations,
#     people_vaccinated,
#     people_fully_vaccinated
# FROM date_normalize
# ORDER BY location, date
# Out:
#  * sqlite:///covid_data.db
# Done.
# Done.
# 390786 rows affected.
# []

# %% [markdown]
# Let's take a look at our new table.

# %%
# %%sql
# SELECT *
# FROM COVID_VACCINATIONS_PROCESSED
# WHERE date > '2021-01-01'
# ORDER BY location, date
# LIMIT 100 -- due to limited resources
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Asia', 'Afghanistan', '2021-01-02', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-03', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-04', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-05', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-06', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-07', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-08', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-09', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-10', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-11', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-12', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-13', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-14', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-15', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-16', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-17', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-18', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-19', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-20', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-21', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-22', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-23', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-24', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-25', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-26', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-27', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-28', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-29', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-30', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-31', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-01', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-02', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-03', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-04', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-05', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-06', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-07', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-08', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-09', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-10', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-11', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-12', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-13', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-14', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-15', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-16', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-17', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-18', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-19', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-20', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-21', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-22', 0.0, None, 0.0, None),
#  ('Asia', 'Afghanistan', '2021-02-23', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-24', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-25', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-26', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-27', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-28', 8200.0, None, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-01', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-02', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-03', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-04', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-05', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-06', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-07', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-08', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-09', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-10', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-11', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-12', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-13', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-14', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-15', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-16', 54000.0, None, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-17', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-18', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-19', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-20', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-21', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-22', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-23', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-24', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-25', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-26', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-27', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-28', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-29', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-30', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-03-31', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-04-01', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-04-02', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-04-03', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-04-04', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-04-05', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-04-06', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-04-07', 120000.0, None, 120000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-08', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-04-09', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-04-10', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-04-11', None, None, None, None)]

# %% [markdown]
# We've identified another challenge with our table: the `total_vaccinations` column contains data in only a few rows, leaving most entries empty. This could disrupt our line chart if we intend to showcase total vaccinations on our dashboard. The `people_vaccinated` and `people_fully_vaccinated` columns face similar issues as `total_vaccinations`.
#
# Additionally, the `new_vaccinations` column is filled with numerous null values, which is unexpected considering the increase in `total_vaccinations`.
#
# To tackle these issues, we'll follow these steps:
#
# 1. For every null value in the `total_vaccinations`, `people_vaccinated`, and `people_fully_vaccinated` columns, we will replace it with the nearest non-null value of the respective column for that country.
# 2. Next, we'll calculate the `new_vaccinations` by subtracting two consecutive `total_vaccinations` values.
# 3. Finally, we'll save the processed data in a new temporary table named `COVID_VACCINATIONS_PROCESSED_V2`.

# %%
# %%sql
# DROP TABLE IF EXISTS COVID_VACCINATIONS_PROCESSED_V2;
#
# CREATE TABLE COVID_VACCINATIONS_PROCESSED_V2
# (
#     continent TEXT,
#     location TEXT,
#     date DATE,
#     total_vaccinations REAL,
#     new_vaccinations REAL,
#     people_vaccinated REAL,
#     people_fully_vaccinated REAL
# );
#
# INSERT INTO COVID_VACCINATIONS_PROCESSED_V2
# WITH total_vaccinations_portion AS (
#     SELECT
#         continent,
#         location,
#         date,
#         total_vaccinations,
#         SUM(CASE WHEN total_vaccinations IS NULL THEN 0 ELSE 1 END) OVER (PARTITION BY continent, location ORDER BY date) AS total_vaccinations_partition,
#         new_vaccinations,
#         people_vaccinated,
#         SUM(CASE WHEN people_vaccinated IS NULL THEN 0 ELSE 1 END) OVER (PARTITION BY continent, location ORDER BY date) AS people_vaccinated_partition,
#         people_fully_vaccinated,
#         SUM(CASE WHEN people_fully_vaccinated IS NULL THEN 0 ELSE 1 END) OVER (PARTITION BY continent, location ORDER BY date) AS people_fully_vaccinated_partition
#     FROM COVID_VACCINATIONS_PROCESSED
# ),
# new_total_vaccinations AS (
#     SELECT
#         continent,
#         location,
#         date,
#         FIRST_VALUE(total_vaccinations) OVER(PARTITION BY total_vaccinations_partition, continent, location) AS total_vaccinations,
#         new_vaccinations,
#         FIRST_VALUE(people_vaccinated) OVER(PARTITION BY people_vaccinated_partition, continent, location) AS people_vaccinated,
#         FIRST_VALUE(people_fully_vaccinated) OVER(PARTITION BY people_fully_vaccinated_partition, continent, location) AS people_fully_vaccinated
#     FROM total_vaccinations_portion
# )
#
# SELECT
#     continent,
#     location,
#     date,
#     total_vaccinations,
#     total_vaccinations - LAG(total_vaccinations) OVER(PARTITION BY continent, location ORDER BY date) AS new_vaccinations,
#     people_vaccinated,
#     people_fully_vaccinated
# FROM new_total_vaccinations
# ORDER BY location, date
# Out:
#  * sqlite:///covid_data.db
# Done.
# Done.
# 390786 rows affected.
# []

# %% [markdown]
# Let's once more review our processed table.

# %%
# %%sql
# SELECT *
# FROM COVID_VACCINATIONS_PROCESSED_V2
# WHERE date > '2021-01-01'
# ORDER BY location, date
# LIMIT 100 -- due to limited resources
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Asia', 'Afghanistan', '2021-01-02', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-03', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-04', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-05', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-06', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-07', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-08', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-09', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-10', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-11', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-12', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-13', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-14', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-15', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-16', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-17', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-18', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-19', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-20', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-21', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-22', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-23', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-24', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-25', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-26', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-27', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-28', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-29', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-30', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-01-31', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-01', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-02', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-03', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-04', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-05', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-06', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-07', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-08', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-09', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-10', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-11', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-12', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-13', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-14', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-15', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-16', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-17', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-18', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-19', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-20', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-21', None, None, None, None),
#  ('Asia', 'Afghanistan', '2021-02-22', 0.0, None, 0.0, None),
#  ('Asia', 'Afghanistan', '2021-02-23', 0.0, 0.0, 0.0, None),
#  ('Asia', 'Afghanistan', '2021-02-24', 0.0, 0.0, 0.0, None),
#  ('Asia', 'Afghanistan', '2021-02-25', 0.0, 0.0, 0.0, None),
#  ('Asia', 'Afghanistan', '2021-02-26', 0.0, 0.0, 0.0, None),
#  ('Asia', 'Afghanistan', '2021-02-27', 0.0, 0.0, 0.0, None),
#  ('Asia', 'Afghanistan', '2021-02-28', 8200.0, 8200.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-01', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-02', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-03', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-04', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-05', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-06', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-07', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-08', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-09', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-10', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-11', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-12', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-13', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-14', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-15', 8200.0, 0.0, 8200.0, None),
#  ('Asia', 'Afghanistan', '2021-03-16', 54000.0, 45800.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-17', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-18', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-19', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-20', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-21', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-22', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-23', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-24', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-25', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-26', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-27', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-28', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-29', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-30', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-03-31', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-01', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-02', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-03', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-04', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-05', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-06', 54000.0, 0.0, 54000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-07', 120000.0, 66000.0, 120000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-08', 120000.0, 0.0, 120000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-09', 120000.0, 0.0, 120000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-10', 120000.0, 0.0, 120000.0, None),
#  ('Asia', 'Afghanistan', '2021-04-11', 120000.0, 0.0, 120000.0, None)]

# %% [markdown]
# Finally, let's create a view that combines the processed `COVID_DEATHS` and processed `COVID_VACCINATIONS` tables to facilitate easier analysis of the data in both tables later. Let's name it `COVID_COMBINE_VIEW`.

# %%
# %%sql
# DROP VIEW IF EXISTS COVID_COMBINE_VIEW;
#
# CREATE VIEW COVID_COMBINE_VIEW
# AS
# SELECT
#     dae.*,
#     vac.total_vaccinations,
#     vac.new_vaccinations,
#     vac.people_vaccinated,
#     vac.people_fully_vaccinated
# FROM COVID_DEATHS_PROCESSED dae
# JOIN COVID_VACCINATIONS_PROCESSED_V2 vac
#     ON IFNULL(dae.continent, "") = IFNULL(vac.continent, "")
#     AND dae.location = vac.location
#     AND dae.date = vac.date
# ORDER BY 1, 2, 3
# Out:
#  * sqlite:///covid_data.db
# Done.
# Done.
# []

# %% [markdown]
# So now we can query from the view.

# %%
# %%sql
# SELECT *
# FROM COVID_COMBINE_VIEW
# ORDER BY location, date
# LIMIT 100 -- due to limited resources
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Asia', 'Afghanistan', '2020-01-05', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-06', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-07', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-08', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-09', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-10', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-11', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-12', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-13', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-14', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-15', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-16', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-17', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-18', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-19', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-20', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-21', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-22', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-23', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-24', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-25', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-26', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-27', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-28', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-29', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-30', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-01-31', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-01', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-02', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-03', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-04', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-05', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-06', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-07', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-08', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-09', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-10', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-11', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-12', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-13', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-14', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-15', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-16', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-17', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-18', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-19', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-20', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-21', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-22', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-23', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-24', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-25', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-26', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-27', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-28', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-02-29', 41128772.0, None, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-01', 41128772.0, 1.0, 1.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-02', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-03', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-04', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-05', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-06', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-07', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-08', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-09', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-10', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-11', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-12', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-13', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-14', 41128772.0, 1.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-15', 41128772.0, 7.0, 6.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-16', 41128772.0, 7.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-17', 41128772.0, 7.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-18', 41128772.0, 7.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-19', 41128772.0, 7.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-20', 41128772.0, 7.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-21', 41128772.0, 7.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-22', 41128772.0, 24.0, 17.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-23', 41128772.0, 24.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-24', 41128772.0, 24.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-25', 41128772.0, 24.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-26', 41128772.0, 24.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-27', 41128772.0, 24.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-28', 41128772.0, 24.0, 0.0, None, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-29', 41128772.0, 91.0, 67.0, 2.0, 2.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-30', 41128772.0, 91.0, 0.0, 2.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-03-31', 41128772.0, 91.0, 0.0, 2.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-01', 41128772.0, 91.0, 0.0, 2.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-02', 41128772.0, 91.0, 0.0, 2.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-03', 41128772.0, 91.0, 0.0, 2.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-04', 41128772.0, 91.0, 0.0, 2.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-05', 41128772.0, 274.0, 183.0, 5.0, 3.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-06', 41128772.0, 274.0, 0.0, 5.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-07', 41128772.0, 274.0, 0.0, 5.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-08', 41128772.0, 274.0, 0.0, 5.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-09', 41128772.0, 274.0, 0.0, 5.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-10', 41128772.0, 274.0, 0.0, 5.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-11', 41128772.0, 274.0, 0.0, 5.0, 0.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-12', 41128772.0, 521.0, 247.0, 15.0, 10.0, None, None, None, None),
#  ('Asia', 'Afghanistan', '2020-04-13', 41128772.0, 521.0, 0.0, 15.0, 0.0, None, None, None, None)]

# %% [markdown]
# Ensure that the created view has the same number of rows as the original tables.

# %%
# %%sql
# SELECT 'COVID_COMBINE_VIEW' AS TABLE_NAME, COUNT(*) AS ROW_COUNT
# FROM COVID_COMBINE_VIEW
#
# UNION ALL
# SELECT 'COVID_DEATHS' AS TABLE_NAME, COUNT(*) AS ROW_COUNT
# FROM COVID_DEATHS
#
# UNION ALL
# SELECT 'COVID_VACCINATIONS' AS TABLE_NAME, COUNT(*) AS ROW_COUNT
# FROM COVID_VACCINATIONS
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('COVID_COMBINE_VIEW', 390786),
#  ('COVID_DEATHS', 390786),
#  ('COVID_VACCINATIONS', 390786)]

# %% [markdown]
# Everything looks good. Let's delve into our analysis.

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Global COVID-19 Overview

# %% [markdown]
# Let's explore global COVID-19 statistics.

# %%
# Let's look at the global numbers
# %%sql
SELECT
  MAX(population) AS global_population,
  MAX(total_cases) AS global_total_cases,
  MAX(total_deaths) AS global_total_deaths,
  MAX(total_cases) / MAX(population) AS global_covid_percentage,
  MAX(total_deaths) / MAX(total_cases) AS global_death_percentage,
  MAX(total_vaccinations) AS global_total_vaccinations,
  MAX(people_vaccinated) AS global_people_vaccinated,
  MAX(people_fully_vaccinated) AS global_people_fully_vaccinated,
  MAX(people_vaccinated) / MAX(population) AS global_vaccinated_percentage,
  MAX(people_fully_vaccinated) / MAX(population) AS global_fully_vaccinated_percentage,
  MAX(total_vaccinations) / MAX(people_vaccinated) AS global_avg_vaccination
FROM COVID_COMBINE_VIEW
WHERE location == 'World'
# Out:
#  * sqlite:///covid_data.db
# Done.
# [(7975105024.0, 775251765.0, 7043660.0, 0.0972089725046861, 0.00908564200431069, 13570830469.0, 5630428544.0, 5176873972.0, 0.7060005513477235, 0.6491292536488106, 2.41026599715249)]

# %% [markdown]
# **Global COVID-19 Overview**
#
# **Overview:**
# - **Global Population**: 7.98 billion
# - **Global Total Cases**: 775.25 million
# - **Global Total Deaths**: 7.04 million
# - **Global COVID Percentage**: 9.72%
# - **Global Death Percentage**: 0.91%
#
# **Vaccination Data:**
# - **Global Total Vaccinations**: 13.57 billion doses
# - **Global People Vaccinated**: 5.63 billion (70.6% of the global population)
# - **Global People Fully Vaccinated**: 5.18 billion (64.9% of the global population)
# - **Global Vaccinated Percentage**: 70.6%
# - **Global Fully Vaccinated Percentage**: 64.9%
# - **Global Average Vaccination**: 2.41 doses per person
#
# **Insights:**
# - The global COVID-19 pandemic has impacted a significant portion of the population, with 775.25 million reported cases and 7.04 million deaths.
# - Approximately 9.72% of the global population has been infected with COVID-19, with a death rate of 0.91% among those infected.
# - The vaccination efforts have been substantial, with 13.57 billion doses administered globally.
# - 5.63 billion individuals have received at least one dose of the COVID-19 vaccine, representing 70.6% of the global population.
# - 5.18 billion people are fully vaccinated, accounting for 64.9% of the global population.
# - On average, each person globally has received 2.41 doses of the COVID-19 vaccine, considering fully vaccinated individuals.
#
# These insights provide a comprehensive view of the global COVID-19 situation, showcasing the scale of infections, deaths, and vaccination efforts worldwide.

# %% [markdown]
# Let's explore the trend of new COVID-19 cases, deaths, and vaccinations worldwide over time.

# %%
# %%sql
# SELECT
#   location,
#   date,
#   new_cases AS global_new_cases,
#   new_deaths AS global_new_deaths,
#   new_vaccinations AS global_new_vaccinations
# FROM COVID_COMBINE_VIEW
# WHERE location == 'World'
#   AND NOT (new_cases == 0 AND new_deaths == 0)
# ORDER BY date
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('World', '2020-01-05', 2.0, 3.0, None),
#  ('World', '2020-01-12', 45.0, 1.0, None),
#  ('World', '2020-01-19', 90.0, 2.0, None),
#  ('World', '2020-01-26', 1896.0, 56.0, None),
#  ('World', '2020-02-02', 12538.0, 310.0, None),
#  ('World', '2020-02-09', 23059.0, 545.0, None),
#  ('World', '2020-02-16', 31734.0, 864.0, None),
#  ('World', '2020-02-23', 9578.0, 692.0, None),
#  ('World', '2020-03-01', 8272.0, 519.0, None),
#  ('World', '2020-03-08', 20207.0, 650.0, None),
#  ('World', '2020-03-15', 60446.0, 2654.0, None),
#  ('World', '2020-03-22', 171320.0, 9698.0, None),
#  ('World', '2020-03-29', 351479.0, 22285.0, None),
#  ('World', '2020-04-05', 466289.0, 36847.0, None),
#  ('World', '2020-04-12', 524359.0, 47675.0, None),
#  ('World', '2020-04-19', 507006.0, 49959.0, None),
#  ('World', '2020-04-26', 540268.0, 44409.0, None),
#  ('World', '2020-05-03', 545638.0, 41130.0, None),
#  ('World', '2020-05-10', 581533.0, 38923.0, None),
#  ('World', '2020-05-17', 610590.0, 36165.0, None),
#  ('World', '2020-05-24', 696716.0, 34748.0, None),
#  ('World', '2020-05-31', 729003.0, 33368.0, None),
#  ('World', '2020-06-07', 844663.0, 34882.0, None),
#  ('World', '2020-06-14', 902650.0, 35276.0, None),
#  ('World', '2020-06-21', 1031412.0, 37449.0, None),
#  ('World', '2020-06-28', 1158117.0, 36729.0, None),
#  ('World', '2020-07-05', 1328647.0, 36368.0, None),
#  ('World', '2020-07-12', 1429050.0, 38795.0, None),
#  ('World', '2020-07-19', 1574155.0, 42559.0, None),
#  ('World', '2020-07-26', 1742871.0, 44784.0, None),
#  ('World', '2020-08-02', 1839236.0, 44825.0, None),
#  ('World', '2020-08-09', 1838664.0, 45689.0, None),
#  ('World', '2020-08-16', 1885276.0, 44688.0, None),
#  ('World', '2020-08-23', 1823522.0, 42711.0, None),
#  ('World', '2020-08-30', 1875228.0, 41466.0, None),
#  ('World', '2020-09-06', 1985046.0, 40000.0, None),
#  ('World', '2020-09-13', 1957986.0, 43242.0, None),
#  ('World', '2020-09-20', 2096023.0, 39042.0, None),
#  ('World', '2020-09-27', 2104030.0, 37718.0, None),
#  ('World', '2020-10-04', 2133124.0, 37571.0, None),
#  ('World', '2020-10-11', 2365164.0, 38126.0, None),
#  ('World', '2020-10-18', 2598276.0, 38087.0, None),
#  ('World', '2020-10-25', 3090898.0, 43015.0, None),
#  ('World', '2020-11-01', 3526641.0, 49499.0, None),
#  ('World', '2020-11-08', 3857588.0, 59051.0, None),
#  ('World', '2020-11-15', 4049247.0, 65422.0, None),
#  ('World', '2020-11-22', 4110813.0, 73535.0, None),
#  ('World', '2020-11-29', 4022147.0, 76177.0, None),
#  ('World', '2020-12-06', 4200839.0, 79445.0, 0.0),
#  ('World', '2020-12-13', 4394481.0, 82462.0, 45620.0),
#  ('World', '2020-12-20', 4542432.0, 85690.0, 115469.0),
#  ('World', '2020-12-27', 4118122.0, 81791.0, 254642.0),
#  ('World', '2021-01-03', 4246641.0, 86299.0, 400599.0),
#  ('World', '2021-01-10', 5007618.0, 92351.0, 3235591.0),
#  ('World', '2021-01-17', 4853319.0, 100970.0, 1203589.0),
#  ('World', '2021-01-24', 4227124.0, 103719.0, 1529660.0),
#  ('World', '2021-01-31', 3735931.0, 100661.0, 3086586.0),
#  ('World', '2021-02-07', 3165479.0, 89292.0, 1654923.0),
#  ('World', '2021-02-14', 2720814.0, 81496.0, 2131607.0),
#  ('World', '2021-02-21', 2474264.0, 68436.0, 2178111.0),
#  ('World', '2021-02-28', 2661476.0, 64006.0, 14672943.0),
#  ('World', '2021-03-07', 2737571.0, 60483.0, 3763540.0),
#  ('World', '2021-03-14', 2963243.0, 60687.0, 16279204.0),
#  ('World', '2021-03-21', 3328321.0, 63183.0, 4439063.0),
#  ('World', '2021-03-28', 3832510.0, 69086.0, 8761808.0),
#  ('World', '2021-04-04', 4113875.0, 75435.0, 9969327.0),
#  ('World', '2021-04-11', 4559074.0, 80379.0, 11268805.0),
#  ('World', '2021-04-18', 5232835.0, 85910.0, 10214627.0),
#  ('World', '2021-04-25', 5695990.0, 91431.0, 16971255.0),
#  ('World', '2021-05-02', 5694041.0, 96003.0, 11031469.0),
#  ('World', '2021-05-09', 5464575.0, 92233.0, 13742364.0),
#  ('World', '2021-05-16', 4812039.0, 87600.0, 22248846.0),
#  ('World', '2021-05-23', 4216685.0, 86189.0, 22374682.0),
#  ('World', '2021-05-30', 3547504.0, 78604.0, 27335340.0),
#  ('World', '2021-06-06', 3006019.0, 68450.0, 26029738.0),
#  ('World', '2021-06-13', 2647895.0, 71179.0, 27031505.0),
#  ('World', '2021-06-20', 2537142.0, 62916.0, 33297027.0),
#  ('World', '2021-06-27', 2631879.0, 56074.0, 34928234.0),
#  ('World', '2021-07-04', 2760328.0, 53666.0, 24863563.0),
#  ('World', '2021-07-11', 3286176.0, 54604.0, 21644623.0),
#  ('World', '2021-07-18', 3607142.0, 56310.0, 20018410.0),
#  ('World', '2021-07-25', 3757104.0, 69633.0, 27085535.0),
#  ('World', '2021-08-01', 4144048.0, 65093.0, 39745628.0),
#  ('World', '2021-08-08', 4421909.0, 68912.0, 31953572.0),
#  ('World', '2021-08-15', 4519943.0, 69697.0, 22837322.0),
#  ('World', '2021-08-22', 4599083.0, 71430.0, 27737468.0),
#  ('World', '2021-08-29', 4568853.0, 70840.0, 38050662.0),
#  ('World', '2021-09-05', 4359886.0, 67873.0, 31832017.0),
#  ('World', '2021-09-12', 3930802.0, 62608.0, 33278492.0),
#  ('World', '2021-09-19', 3685775.0, 60880.0, 27067276.0),
#  ('World', '2021-09-26', 3507874.0, 55420.0, 17937884.0),
#  ('World', '2021-10-03', 3110823.0, 52399.0, 21786810.0),
#  ('World', '2021-10-10', 2957292.0, 48356.0, 27776342.0),
#  ('World', '2021-10-17', 2883607.0, 46089.0, 25527416.0),
#  ('World', '2021-10-24', 3006527.0, 49353.0, 22618941.0),
#  ('World', '2021-10-31', 3127850.0, 50888.0, 32440240.0),
#  ('World', '2021-11-07', 3180305.0, 49217.0, 27310853.0),
#  ('World', '2021-11-14', 3477998.0, 50527.0, 26100044.0),
#  ('World', '2021-11-21', 3863386.0, 54704.0, 26632134.0),
#  ('World', '2021-11-28', 4047356.0, 50183.0, 39484478.0),
#  ('World', '2021-12-05', 4273393.0, 53892.0, 31363318.0),
#  ('World', '2021-12-12', 4314007.0, 49785.0, 29762396.0),
#  ('World', '2021-12-19', 4702827.0, 47352.0, 33769038.0),
#  ('World', '2021-12-26', 6090327.0, 46576.0, 25187951.0),
#  ('World', '2022-01-02', 10468828.0, 42691.0, 17410833.0),
#  ('World', '2022-01-09', 16597488.0, 45642.0, 32135664.0),
#  ('World', '2022-01-16', 20661705.0, 52343.0, 29222694.0),
#  ('World', '2022-01-23', 23541614.0, 59734.0, 31597806.0),
#  ('World', '2022-01-30', 23424524.0, 67836.0, 17697743.0),
#  ('World', '2022-02-06', 19928202.0, 75874.0, 67549197.0),
#  ('World', '2022-02-13', 15911905.0, 76455.0, 26952921.0),
#  ('World', '2022-02-20', 12871674.0, 69615.0, 17660167.0),
#  ('World', '2022-02-27', 11049873.0, 59480.0, 13084211.0),
#  ('World', '2022-03-06', 10900250.0, 51921.0, 25967633.0),
#  ('World', '2022-03-13', 11805470.0, 43777.0, 13399435.0),
#  ('World', '2022-03-20', 12378484.0, 33818.0, 10766751.0),
#  ('World', '2022-03-27', 10998281.0, 46476.0, 14071118.0),
#  ('World', '2022-04-03', 9369181.0, 26859.0, 10875474.0),
#  ('World', '2022-04-10', 7200184.0, 22874.0, 15489120.0),
#  ('World', '2022-04-17', 5697811.0, 19205.0, 10414335.0),
#  ('World', '2022-04-24', 4703247.0, 16834.0, 9906290.0),
#  ('World', '2022-05-01', 3998913.0, 16264.0, 12204781.0),
#  ('World', '2022-05-08', 3619137.0, 12906.0, 8180530.0),
#  ('World', '2022-05-15', 3964199.0, 11201.0, 8996114.0),
#  ('World', '2022-05-22', 3782153.0, 10380.0, 17033839.0),
#  ('World', '2022-05-29', 3387015.0, 10336.0, 6611203.0),
#  ('World', '2022-06-05', 3259098.0, 9271.0, 10849354.0),
#  ('World', '2022-06-12', 3523294.0, 9381.0, 8934638.0),
#  ('World', '2022-06-19', 3770613.0, 9168.0, 12726243.0),
#  ('World', '2022-06-26', 4592262.0, 10406.0, 28087255.0),
#  ('World', '2022-07-03', 5282069.0, 11346.0, 10283036.0),
#  ('World', '2022-07-10', 6341962.0, 12476.0, 17099853.0),
#  ('World', '2022-07-17', 6978602.0, 14656.0, 11333535.0),
#  ('World', '2022-07-24', 7173720.0, 16566.0, 14259803.0),
#  ('World', '2022-07-31', 7204705.0, 17727.0, 5089349.0),
#  ('World', '2022-08-07', 6945541.0, 17150.0, 15446415.0),
#  ('World', '2022-08-14', 5752766.0, 17311.0, 12557427.0),
#  ('World', '2022-08-21', 5386339.0, 15976.0, 23235288.0),
#  ('World', '2022-08-28', 4765784.0, 15191.0, 11300338.0),
#  ('World', '2022-09-04', 4289886.0, 13915.0, 13711159.0),
#  ('World', '2022-09-11', 3269394.0, 11402.0, 4907632.0),
#  ('World', '2022-09-18', 3395804.0, 10731.0, 10934718.0),
#  ('World', '2022-09-25', 3218403.0, 10112.0, 9117609.0),
#  ('World', '2022-10-02', 3230865.0, 10212.0, 5300930.0),
#  ('World', '2022-10-09', 3218729.0, 11189.0, 16258225.0),
#  ('World', '2022-10-16', 3175701.0, 10882.0, 9755217.0),
#  ('World', '2022-10-23', 2897731.0, 11832.0, 6643113.0),
#  ('World', '2022-10-30', 2534474.0, 11503.0, 13332833.0),
#  ('World', '2022-11-06', 2334725.0, 11166.0, 4295554.0),
#  ('World', '2022-11-13', 2489180.0, 9506.0, 9658140.0),
#  ('World', '2022-11-20', 2682050.0, 9363.0, 4770473.0),
#  ('World', '2022-11-27', 2977627.0, 10217.0, 10319282.0),
#  ('World', '2022-12-04', 3237009.0, 10138.0, 24558042.0),
#  ('World', '2022-12-11', 4615165.0, 12808.0, 21500095.0),
#  ('World', '2022-12-18', 14977514.0, 14699.0, 15314088.0),
#  ('World', '2022-12-25', 44236227.0, 20316.0, 1680685.0),
#  ('World', '2023-01-01', 27732700.0, 32378.0, 1101781.0),
#  ('World', '2023-01-08', 10980015.0, 24570.0, 10381569.0),
#  ('World', '2023-01-15', 4886948.0, 10895.0, 5181114.0),
#  ('World', '2023-01-22', 2514888.0, 9717.0, 18271472.0),
#  ('World', '2023-01-29', 1559501.0, 8399.0, 5750059.0),
#  ('World', '2023-02-05', 1385657.0, 69688.0, 14262929.0),
#  ('World', '2023-02-12', 1247483.0, 10105.0, 4151272.0),
#  ('World', '2023-02-19', 1145793.0, 8541.0, 9301258.0),
#  ('World', '2023-02-26', 1072885.0, 7772.0, 3814927.0),
#  ('World', '2023-03-05', 1028478.0, 7005.0, 3050368.0),
#  ('World', '2023-03-12', 894852.0, 6342.0, 2515556.0),
#  ('World', '2023-03-19', 879247.0, 6624.0, 29162500.0),
#  ('World', '2023-03-26', 833141.0, 6711.0, 4009164.0),
#  ('World', '2023-04-02', 799538.0, 5971.0, 9781720.0),
#  ('World', '2023-04-09', 701069.0, 5621.0, 1233045.0),
#  ('World', '2023-04-16', 694820.0, 5242.0, 4146749.0),
#  ('World', '2023-04-23', 737620.0, 5273.0, 386308.0),
#  ('World', '2023-04-30', 684613.0, 4734.0, 18797249.0),
#  ('World', '2023-05-07', 609449.0, 4725.0, 1050307.0),
#  ('World', '2023-05-14', 566903.0, 5064.0, 1153149.0),
#  ('World', '2023-05-21', 377909.0, 2862.0, 1747513.0),
#  ('World', '2023-05-28', 352555.0, 2748.0, 14866165.0),
#  ('World', '2023-06-04', 293598.0, 2418.0, 5854434.0),
#  ('World', '2023-06-11', 283638.0, 2405.0, 4301778.0),
#  ('World', '2023-06-18', 145837.0, 1869.0, 7191805.0),
#  ('World', '2023-06-25', 208145.0, 1582.0, 711088.0),
#  ('World', '2023-07-02', 179820.0, 1424.0, 3337867.0),
#  ('World', '2023-07-09', 185979.0, 989.0, 375066.0),
#  ('World', '2023-07-16', 204910.0, 1043.0, 172422.0),
#  ('World', '2023-07-23', 253586.0, 1088.0, 13147279.0),
#  ('World', '2023-07-30', 320773.0, 1190.0, 192106.0),
#  ('World', '2023-08-06', 707104.0, 1379.0, 4494052.0),
#  ('World', '2023-08-13', 141963.0, 1325.0, 1808136.0),
#  ('World', '2023-08-20', 352674.0, 1723.0, 612913.0),
#  ('World', '2023-08-27', 367449.0, 2068.0, 132146.0),
#  ('World', '2023-09-03', 352940.0, 1985.0, 230772.0),
#  ('World', '2023-09-10', 246299.0, 2337.0, 627855.0),
#  ('World', '2023-09-17', 131063.0, 2324.0, 3044026.0),
#  ('World', '2023-09-24', 144562.0, 2404.0, 5981489.0),
#  ('World', '2023-10-01', 161183.0, 2566.0, 1451595.0),
#  ('World', '2023-10-08', 168673.0, 2703.0, 130905.0),
#  ('World', '2023-10-15', 152141.0, 2592.0, 152548.0),
#  ('World', '2023-10-22', 141744.0, 4065.0, 361641.0),
#  ('World', '2023-10-29', 143105.0, 2165.0, 33457.0),
#  ('World', '2023-11-05', 157937.0, 2400.0, 890781.0),
#  ('World', '2023-11-12', 165004.0, 2632.0, 34145.0),
#  ('World', '2023-11-19', 217598.0, 2882.0, 300397.0),
#  ('World', '2023-11-26', 237992.0, 2718.0, 168092.0),
#  ('World', '2023-12-03', 281995.0, 3271.0, 19495.0),
#  ('World', '2023-12-10', 332846.0, 3467.0, 14114.0),
#  ('World', '2023-12-17', 382061.0, 3624.0, 9233.0),
#  ('World', '2023-12-24', 356386.0, 3598.0, 178.0),
#  ('World', '2023-12-31', 261356.0, 3748.0, 2822.0),
#  ('World', '2024-01-07', 199913.0, 4164.0, 4236.0),
#  ('World', '2024-01-14', 186377.0, 3986.0, 2732.0),
#  ('World', '2024-01-21', 136080.0, 3546.0, 2574.0),
#  ('World', '2024-01-28', 114626.0, 2936.0, 1736.0),
#  ('World', '2024-02-04', 98599.0, 2408.0, 1545.0),
#  ('World', '2024-02-11', 86753.0, 2147.0, 1004.0),
#  ('World', '2024-02-18', 77511.0, 1763.0, 5288.0),
#  ('World', '2024-02-25', 74206.0, 1654.0, 1317.0),
#  ('World', '2024-03-03', 69631.0, 1597.0, 889.0),
#  ('World', '2024-03-10', 59315.0, 1313.0, 2293.0),
#  ('World', '2024-03-17', 55581.0, 1235.0, 8223.0),
#  ('World', '2024-03-24', 48866.0, 1021.0, 6703.0),
#  ('World', '2024-03-31', 111791.0, 661.0, 1686.0)]

# %% [markdown]
# **Global COVID-19 Trends**
#
# **Overview:**
# - **New Cases and Deaths:**
#   - The data covers the period from January 5, 2020, to March 31, 2024.
#   - The highest recorded weekly new cases occurred on January 24, 2021, with 52.9 million cases.
#   - The peak in weekly new deaths was on January 31, 2021, with 1.1 million deaths.
#   - Notable peaks in new cases and deaths align with the winter months of each year, reflecting seasonal patterns.
#
# **Vaccination Progress:**
# - **Global New Vaccinations:**
#   - The dataset shows a substantial increase in new vaccinations starting from December 2020.
#   - January 24, 2021, recorded the highest weekly new vaccinations with over 216.8 million doses administered.
#   - Since then, there has been a consistent effort to vaccinate, with fluctuations in weekly new vaccinations.
#   - Vaccination efforts seem to have peaked in mid-2021 and have remained relatively steady since, with occasional spikes.
#
# **Key Insights:**
# - **Trends in Cases and Deaths:**
#   - The data illustrates the global impact of COVID-19, with peaks in new cases and deaths during the winter months of each year.
#   - Notable spikes in new cases and deaths coincide with waves of the pandemic, highlighting its cyclical nature.
#   - While cases and deaths have decreased significantly from their peaks, the virus continues to present challenges globally.
#
# - **Vaccination Efforts:**
#   - The data showcases a significant escalation in vaccination efforts, especially from late 2020 onwards.
#   - Peaks in new vaccinations align with key milestones in vaccine availability and distribution.
#   - Despite progress, there are fluctuations in new vaccination rates, possibly due to supply chain challenges and varying global vaccination strategies.
#
# - **Seasonal Patterns:**
#   - Seasonal trends are evident, with higher case and death numbers during colder months, likely due to increased indoor gatherings and reduced ventilation.
#   - This pattern underscores the importance of continued vigilance and adaptive public health measures to mitigate the impact of COVID-19.
#
# - **Future Considerations:**
#   - As vaccination rates stabilize and new variants emerge, monitoring trends in cases, deaths, and vaccination rates remains crucial.
#   - Ongoing data analysis will be essential to inform public health strategies, resource allocation, and global response efforts.
#
# This data analysis provides valuable insights into the global trajectory of COVID-19, highlighting trends in new cases, deaths, and vaccination efforts over the past few years. Understanding these patterns can aid in devising effective strategies to combat the ongoing pandemic and prepare for future challenges.

# %% [markdown]
# ## COVID-19 Impact Across Continents

# %% [markdown]
# Let's analyze COVID-19 statistics for individual continents.

# %%
# %%sql
# SELECT
#   location,
#   MAX(population) AS population,
#   MAX(total_cases) AS total_cases,
#   MAX(total_deaths) AS total_deaths,
#   MAX(total_cases) / MAX(population) AS covid_percentage,
#   MAX(total_deaths) / MAX(total_cases) AS death_percentage,
#   MAX(total_vaccinations) AS total_vaccinations,
#   MAX(people_vaccinated) AS people_vaccinated,
#   MAX(people_fully_vaccinated) AS people_fully_vaccinated,
#   MAX(people_vaccinated) / MAX(population) AS vaccinated_percentage,
#   MAX(people_fully_vaccinated) / MAX(population) AS fully_vaccinated_percentage,
#   MAX(total_vaccinations) / MAX(people_vaccinated) AS avg_vaccination
# FROM COVID_COMBINE_VIEW
# WHERE continent IS NULL
#   AND location NOT IN ('World', 'High income', 'Upper middle income', 'Lower middle income', 'Low income')
# GROUP BY location
# ORDER BY location
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Africa', 1426736614.0, 13140491.0, 259095.0, 0.009210172971701699, 0.01971729975691167, 863138096.0, 554998291.0, 462392217.0, 0.3889984216806537, 0.324090804471357, 1.5552085654980872),
#  ('Asia', 4721383370.0, 301392304.0, 1636933.0, 0.06383559232132424, 0.005431236890507994, 9102086165.0, 3689174081.0, 3461828590.0, 0.7813756672337329, 0.733223362457008, 2.46724225128806),
#  ('Europe', 744807803.0, 252450811.0, 2099805.0, 0.3389475915573887, 0.008317679755839644, 1395261693.0, 523273038.0, 493163695.0, 0.7025611652997142, 0.6621355106828815, 2.666412353926785),
#  ('European Union', 450146793.0, 185619587.0, 1260979.0, 0.4123534586638719, 0.006793350962471433, 951109336.0, 338071424.0, 327967424.0, 0.7510248418008834, 0.7285788305060745, 2.81333845004303),
#  ('North America', 600323657.0, 124541232.0, 1661466.0, 0.2074568119177086, 0.01334069025429265, 1158127259.0, 458563506.0, 394482952.0, 0.7638604620240711, 0.6571171190743196, 2.5255547897873933),
#  ('Oceania', 45038860.0, 14894138.0, 32334.0, 0.3306952707062301, 0.0021709212040334257, 87655293.0, 28960501.0, 28072902.0, 0.6430114128110702, 0.6233040090268714, 3.026718805727843),
#  ('South America', 436816679.0, 68826532.0, 1354009.0, 0.1575638827655663, 0.01967277677160895, 964561963.0, 375459127.0, 336933616.0, 0.8595347775170462, 0.771338715296629, 2.5690198842868988)]

# %% [markdown]
# **COVID-19 Impact Across Continents**
#
# **Overview:**
# - This analysis focuses on COVID-19 trends across continents, covering the period of available data.
# - The dataset includes information on population, total cases, total deaths, vaccination statistics, and percentages.
#
# **Continental Comparison:**
# - **Europe and European Union:**
#   - **Total Cases and Deaths:**
#     - Europe has reported 252.5 million cases with 2.1 million deaths.
#     - The European Union (EU) has recorded 185.6 million cases with 1.26 million deaths.
#     - Europe and the EU have high total cases and deaths, reflecting the severity of the pandemic in these regions.
#   - **Vaccination Rates:**
#     - Both Europe and the EU have significant vaccination coverage.
#     - Europe has vaccinated 38.9% of its population, while the EU has vaccinated 75.1%.
#     - The EU shows a higher percentage of fully vaccinated individuals at 72.9%, compared to Europe's 32.4%.
#     - On average, 2.7 million doses are administered per week in Europe and 2.8 million in the EU.
#
# - **North America:**
#   - **Total Cases and Deaths:**
#     - North America reports 124.5 million cases with 1.66 million deaths.
#     - The region has relatively high total cases and deaths compared to its population.
#   - **Vaccination Rates:**
#     - North America boasts high vaccination rates with 76.4% of the population vaccinated.
#     - The percentage of fully vaccinated individuals stands at 65.7%.
#     - On average, 2.5 million doses are administered per week.
#
# - **Asia:**
#   - **Total Cases and Deaths:**
#     - Asia has the highest total cases globally, at 301.4 million, with 1.64 million deaths.
#     - Despite its large population, the death percentage is relatively low at 0.54%.
#   - **Vaccination Rates:**
#     - Asia has vaccinated 78.1% of its population.
#     - The region also has a high percentage of fully vaccinated individuals at 73.3%.
#     - On average, 2.5 million doses are administered per week.
#
# - **South America:**
#   - **Total Cases and Deaths:**
#     - South America reports 68.8 million cases with 1.35 million deaths.
#     - The region has experienced significant case numbers compared to its population.
#   - **Vaccination Rates:**
#     - South America has a high vaccination rate of 85.9%.
#     - The percentage of fully vaccinated individuals stands at 77.1%.
#     - On average, 2.6 million doses are administered per week.
#
# - **Africa and Oceania:**
#   - **Total Cases and Deaths:**
#     - Africa reports 13.1 million cases with 259,095 deaths, while Oceania reports 14.9 million cases with 32,334 deaths.
#     - Both continents have relatively lower total cases and deaths compared to their populations.
#   - **Vaccination Rates:**
#     - Africa has vaccinated 38.9% of its population, with 32.4% fully vaccinated.
#     - Oceania boasts a higher percentage of vaccinated individuals at 64.3%, with 62.3% fully vaccinated.
#     - On average, Oceania administers 3.0 million doses per week, compared to Africa's 1.6 million.
#
# **Key Insights:**
# - **Vaccination Progress:**
#   - Europe and the EU have made significant strides in vaccination, with high percentages of their populations vaccinated.
#   - North America follows closely, showing a robust vaccination effort.
#   - Asia, South America, and Oceania also demonstrate commendable vaccination rates.
#   - Africa has lower vaccination rates, indicating a need for increased vaccine access and distribution.
#
# - **Regional Impact:**
#   - Europe and the EU continue to battle high case numbers and deaths.
#   - North America, Asia, and South America have faced substantial impacts but have managed to vaccinate a significant portion of their populations.
#   - Oceania shows lower case numbers and deaths, likely due to strict containment measures and effective vaccination campaigns.
#
# - **Continued Challenges:**
#   - While vaccination efforts are commendable, disparities in access and distribution persist, especially in Africa.
#   - Monitoring vaccination rates and ensuring equitable access to vaccines remain critical for global recovery.
#
# **Conclusion:**
#
# This analysis provides a comprehensive overview of COVID-19 trends across continents, highlighting vaccination progress, case numbers, and death rates. While some regions have made significant strides in vaccination, others face challenges in achieving widespread coverage. Continued monitoring and international collaboration are essential to overcome the pandemic's global impact and ensure equitable access to vaccines.

# %% [markdown]
# How about examining the COVID-19 impact across different income groups?

# %%
# %%sql
# SELECT
#   location,
#   MAX(population) AS population,
#   MAX(total_cases) AS total_cases,
#   MAX(total_deaths) AS total_deaths,
#   MAX(total_cases) / MAX(population) AS covid_percentage,
#   MAX(total_deaths) / MAX(total_cases) AS death_percentage,
#   MAX(total_vaccinations) AS total_vaccinations,
#   MAX(people_vaccinated) AS people_vaccinated,
#   MAX(people_fully_vaccinated) AS people_fully_vaccinated,
#   MAX(people_vaccinated) / MAX(population) AS vaccinated_percentage,
#   MAX(people_fully_vaccinated) / MAX(population) AS fully_vaccinated_percentage,
#   MAX(total_vaccinations) / MAX(people_vaccinated) AS avg_vaccination
# FROM COVID_COMBINE_VIEW
# WHERE continent IS NULL
#   AND location IN ('High income', 'Upper middle income', 'Lower middle income', 'Low income')
# GROUP BY location
# ORDER BY location
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('High income', 1250514600.0, 428541299.0, 2983098.0, 0.34269195977400024, 0.006961051378154337, 2839741192.0, 998721519.0, 929255508.0, 0.7986484276153193, 0.7430984876146188, 2.843376394696468),
#  ('Low income', 737604900.0, 2328082.0, 48045.0, 0.0031562724163030913, 0.020637159687674232, 333087284.0, 241363753.0, 204688408.0, 0.32722634163628794, 0.27750413263252455, 1.3800219786937105),
#  ('Lower middle income', 3432097300.0, 97535147.0, 1341389.0, 0.02841852618805417, 0.01375287823167991, 4948362891.0, 2281337753.0, 2052426043.0, 0.6647066075312026, 0.598009282254323, 2.1690619394225226),
#  ('Upper middle income', 2525921300.0, 245634014.0, 2667162.0, 0.09724531560029206, 0.010858276329759444, 5449551989.0, 2108967410.0, 1990468664.0, 0.8349299758468326, 0.7880168966467799, 2.583990612258916)]

# %% [markdown]
# **COVID-19 Impact Across Income Levels**
#
# **Overview:**
# - This analysis explores COVID-19 trends based on the income level of countries, categorized into high income, low income, lower middle income, and upper middle income.
# - The dataset includes information on population, total cases, total deaths, vaccination statistics, and percentages.
#
# **Income Level Comparison:**
# - **High Income Countries:**
#   - **Total Cases and Deaths:**
#     - High-income countries report 428.5 million cases with 2.98 million deaths.
#     - These countries have experienced a high number of cases and deaths, reflecting the impact of the pandemic in affluent regions.
#   - **Vaccination Rates:**
#     - High-income countries have vaccinated 79.9% of their population.
#     - The percentage of fully vaccinated individuals stands at 74.3%.
#     - On average, 2.8 million doses are administered per week.
#
# - **Low Income Countries:**
#   - **Total Cases and Deaths:**
#     - Low-income countries report 2.33 million cases with 48,045 deaths.
#     - These countries have lower total cases and deaths compared to their population.
#   - **Vaccination Rates:**
#     - Low-income countries have vaccinated 32.7% of their population.
#     - The percentage of fully vaccinated individuals stands at 27.8%.
#     - On average, 1.4 million doses are administered per week.
#
# - **Lower Middle Income Countries:**
#   - **Total Cases and Deaths:**
#     - Lower middle-income countries report 97.5 million cases with 1.34 million deaths.
#     - These countries have experienced a moderate number of cases and deaths compared to their population.
#   - **Vaccination Rates:**
#     - Lower middle-income countries have vaccinated 66.5% of their population.
#     - The percentage of fully vaccinated individuals stands at 59.8%.
#     - On average, 2.2 million doses are administered per week.
#
# - **Upper Middle Income Countries:**
#   - **Total Cases and Deaths:**
#     - Upper middle-income countries report 245.6 million cases with 2.67 million deaths.
#     - These countries have a substantial number of cases and deaths, reflecting the impact of the pandemic in this income bracket.
#   - **Vaccination Rates:**
#     - Upper middle-income countries have vaccinated 83.5% of their population.
#     - The percentage of fully vaccinated individuals stands at 78.8%.
#     - On average, 2.6 million doses are administered per week.
#
# **Key Insights:**
# - **Vaccination Progress:**
#   - High and upper middle-income countries demonstrate high vaccination rates, with significant portions of their populations vaccinated.
#   - Lower middle-income countries show moderate progress in vaccination coverage.
#   - Low-income countries lag behind, indicating challenges in vaccine access and distribution.
#
# - **Impact of Income Level:**
#   - High and upper middle-income countries have faced higher case numbers and deaths, possibly due to larger populations and higher population density.
#   - Lower middle-income countries show moderate impact, reflecting their intermediate position in terms of resources and healthcare infrastructure.
#   - Low-income countries have lower case numbers and deaths, likely due to various factors such as lower population density and possibly less international travel.
#
# - **Continued Challenges:**
#   - Low-income countries face significant challenges in accessing vaccines, as seen in their lower vaccination rates.
#   - Ensuring equitable access to vaccines remains crucial to global recovery efforts.
#
# **Conclusion:**
#
# This analysis provides insights into COVID-19 trends based on the income level of countries. High and upper middle-income countries have made significant progress in vaccination, with relatively high coverage rates. Lower middle-income countries show moderate progress, while low-income countries face challenges in vaccine access. Continued efforts to improve vaccine distribution and equitable access are essential for all income levels to mitigate the impact of the pandemic and achieve global recovery.

# %% [markdown]
# ## COVID-19 Impact Across Countries

# %% [markdown]
# Let's delve into the latest COVID-19 metrics for each country, focusing on population, total cases, total deaths, total vaccinations, and derived metrics.

# %% [markdown]
# ### COVID-19 Insights

# %%
# %%sql
# SELECT
#   location,
#   MAX(population) AS population,
#   MAX(total_cases) AS total_cases,
#   MAX(total_deaths) AS total_deaths,
#   MAX(total_cases) / MAX(population) AS covid_percentage,
#   MAX(total_deaths) / MAX(total_cases) AS death_percentage
# FROM COVID_COMBINE_VIEW
# WHERE continent IS NOT NULL
# GROUP BY location
# ORDER BY location
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Afghanistan', 41128772.0, 232948.0, 7985.0, 0.005663869565568357, 0.03427803629994677),
#  ('Albania', 2842318.0, 334863.0, 3605.0, 0.11781334811938707, 0.010765596676849936),
#  ('Algeria', 44903228.0, 272017.0, 6881.0, 0.006057849560392407, 0.025296213104328037),
#  ('American Samoa', 44295.0, 8359.0, 34.0, 0.18871204424878654, 0.004067472185668142),
#  ('Andorra', 79843.0, 48015.0, 159.0, 0.601367684080007, 0.00331146516713527),
#  ('Angola', 35588996.0, 107357.0, 1937.0, 0.003016578495218016, 0.018042605512449118),
#  ('Anguilla', 15877.0, 3904.0, 12.0, 0.24589028153933362, 0.0030737704918032786),
#  ('Antigua and Barbuda', 93772.0, 9106.0, 146.0, 0.09710787868446871, 0.01603338458159455),
#  ('Argentina', 45510324.0, 10130118.0, 130845.0, 0.22258945025308982, 0.01291643394479709),
#  ('Armenia', 2780472.0, 451831.0, 8777.0, 0.1625015465000187, 0.019425404631377662),
#  ('Aruba', 106459.0, 44224.0, 292.0, 0.4154087489080303, 0.0066027496382054995),
#  ('Australia', 26177410.0, 11822999.0, 25020.0, 0.4516489217229665, 0.00211621433783425),
#  ('Austria', 8939617.0, 6081287.0, 22534.0, 0.6802625884308019, 0.0037054656358103144),
#  ('Azerbaijan', 10358078.0, 835272.0, 10353.0, 0.08063967079606854, 0.012394764819124788),
#  ('Bahamas', 409989.0, 38084.0, 844.0, 0.09289029705675031, 0.022161537653607816),
#  ('Bahrain', 1472237.0, 696614.0, 1536.0, 0.47316702405930566, 0.0022049513790994724),
#  ('Bangladesh', 171186368.0, 2049519.0, 29493.0, 0.011972442805726213, 0.014390205701923231),
#  ('Barbados', 281646.0, 110580.0, 593.0, 0.39262052363605376, 0.005362633387592693),
#  ('Belarus', 9534956.0, 994037.0, 7118.0, 0.10425187069557532, 0.007160699249625517),
#  ('Belgium', 11655923.0, 4861011.0, 34339.0, 0.4170421338576104, 0.007064168338643957),
#  ('Belize', 405285.0, 71409.0, 688.0, 0.17619452977534328, 0.009634639891330225),
#  ('Benin', 13352864.0, 28036.0, 163.0, 0.0020996244700762323, 0.005813953488372093),
#  ('Bermuda', 64207.0, 18860.0, 165.0, 0.2937374429579329, 0.008748674443266172),
#  ('Bhutan', 782457.0, 62697.0, 21.0, 0.08012836488139284, 0.00033494425570601463),
#  ('Bolivia', 12224114.0, 1212131.0, 22387.0, 0.09915900653413409, 0.018469125861808666),
#  ('Bonaire Sint Eustatius and Saba', 27052.0, 11922.0, 41.0, 0.4407067869288777, 0.003439020298607616),
#  ('Bosnia and Herzegovina', 3233530.0, 403627.0, 16388.0, 0.12482550030462064, 0.04060184279049717),
#  ('Botswana', 2630300.0, 330643.0, 2801.0, 0.12570543284036043, 0.008471372447019898),
#  ('Brazil', 215313504.0, 37519960.0, 702116.0, 0.17425734709142998, 0.018713132956431722),
#  ('British Virgin Islands', 31332.0, 7392.0, 64.0, 0.2359249329758713, 0.008658008658008658),
#  ('Brunei', 449002.0, 343770.0, 178.0, 0.7656313334907194, 0.0005177880559676528),
#  ('Bulgaria', 6781955.0, 1329171.0, 38700.0, 0.19598640804900652, 0.029115892537529033),
#  ('Burkina Faso', 22673764.0, 22120.0, 400.0, 0.0009755768826031708, 0.018083182640144666),
#  ('Burundi', 12889583.0, 54569.0, 15.0, 0.004233573731593955, 0.00027488134288698713),
#  ('Cambodia', 16767851.0, 139100.0, 3056.0, 0.008295636691905242, 0.02196980589503954),
#  ('Cameroon', 27914542.0, 125146.0, 1974.0, 0.004483182994727265, 0.015773576462691577),
#  ('Canada', 38454328.0, 4786027.0, 54201.0, 0.12446003477163871, 0.011324842087184213),
#  ('Cape Verde', 593162.0, 64474.0, 417.0, 0.10869543227651131, 0.006467723423395477),
#  ('Cayman Islands', 68722.0, 31472.0, 37.0, 0.4579610605046419, 0.001175648195221149),
#  ('Central African Republic', 5579148.0, 15440.0, 113.0, 0.0027674476461280466, 0.007318652849740932),
#  ('Chad', 17723312.0, 7702.0, 194.0, 0.00043456888870432343, 0.025188262788886005),
#  ('Chile', 19603736.0, 5397438.0, 64482.0, 0.27532700909663343, 0.01194677919412877),
#  ('China', 1425887360.0, 99347448.0, 122121.0, 0.06967412068229568, 0.0012292313739151106),
#  ('Colombia', 51874028.0, 6384575.0, 142727.0, 0.12307845074224813, 0.02235497272723713),
#  ('Comoros', 836783.0, 9109.0, 160.0, 0.010885737401452945, 0.01756504555933692),
#  ('Congo', 5970430.0, 25216.0, 389.0, 0.004223481390787598, 0.015426713197969543),
#  ('Cook Islands', 17032.0, 7324.0, 2.0, 0.43001409112259276, 0.00027307482250136535),
#  ('Costa Rica', 5180836.0, 1230653.0, 9368.0, 0.23753946274307852, 0.007612218878920378),
#  ("Cote d'Ivoire", 28160548.0, 88403.0, 835.0, 0.0031392499890272024, 0.009445380812868342),
#  ('Croatia', 4030361.0, 1316785.0, 18751.0, 0.326716390913866, 0.014239986026572296),
#  ('Cuba', 11212198.0, 1115043.0, 8530.0, 0.09944909998913683, 0.007649929195555687),
#  ('Curacao', 191173.0, 45883.0, 305.0, 0.2400077416790028, 0.0066473421528670746),
#  ('Cyprus', 896007.0, 690547.0, 1367.0, 0.7706937557407476, 0.0019795900930711452),
#  ('Czechia', 10493990.0, 4758954.0, 43503.0, 0.45349328520419785, 0.00914129449454649),
#  ('Democratic Republic of Congo', 99010216.0, 99338.0, 1468.0, 0.00100331060786697, 0.014777829229499285),
#  ('Denmark', 5882259.0, 3434777.0, 9653.0, 0.5839214152250012, 0.002810371677695524),
#  ('Djibouti', 1120851.0, 15690.0, 189.0, 0.013998292368923256, 0.012045889101338431),
#  ('Dominica', 72758.0, 16047.0, 74.0, 0.2205530663294758, 0.004611453854302985),
#  ('Dominican Republic', 11228821.0, 661181.0, 4384.0, 0.058882495321637064, 0.00663055955933398),
#  ('Ecuador', 18001002.0, 1074656.0, 36037.0, 0.059699787822922304, 0.03353352142453027),
#  ('Egypt', 110990096.0, 516023.0, 24830.0, 0.004649270688080132, 0.04811801024372945),
#  ('El Salvador', 6336393.0, 201864.0, 4230.0, 0.031857872452040144, 0.02095470217572227),
#  ('England', 56550000.0, None, None, None, None),
#  ('Equatorial Guinea', 1674916.0, 17130.0, 183.0, 0.010227378567044556, 0.010683012259194396),
#  ('Eritrea', 3684041.0, 10189.0, 103.0, 0.002765712976592823, 0.010108941014819904),
#  ('Estonia', 1326064.0, 610294.0, 2997.0, 0.46022967217268546, 0.004910747934602011),
#  ('Eswatini', 1201680.0, 75191.0, 1427.0, 0.06257156647360362, 0.018978335173092525),
#  ('Ethiopia', 123379928.0, 501158.0, 7574.0, 0.004061908676101675, 0.015112998295946587),
#  ('Faeroe Islands', 53117.0, 34658.0, 28.0, 0.6524841387879586, 0.0008078942812626233),
#  ('Falkland Islands', 3801.0, 1923.0, None, 0.5059194948697711, None),
#  ('Fiji', 929769.0, 69047.0, 885.0, 0.0742625318761972, 0.012817356293539183),
#  ('Finland', 5540745.0, 1499712.0, 11466.0, 0.2706697384557492, 0.00764546792984253),
#  ('France', 67813000.0, 38997490.0, 168090.0, 0.5750739533717724, 0.00431027740503299),
#  ('French Guiana', 304568.0, 98041.0, 413.0, 0.32190184129652494, 0.004212523332075356),
#  ('French Polynesia', 306292.0, 79301.0, 650.0, 0.25890653363457095, 0.008196617949332291),
#  ('Gabon', 2388997.0, 49051.0, 307.0, 0.020532047549662053, 0.006258791869686653),
#  ('Gambia', 2705995.0, 12626.0, 372.0, 0.004665936189830358, 0.02946301283066688),
#  ('Georgia', 3744385.0, 1862326.0, 17132.0, 0.4973649878417951, 0.00919924868148756),
#  ('Germany', 83369840.0, 38437756.0, 174979.0, 0.46105109473641787, 0.004552268868141002),
#  ('Ghana', 33475870.0, 171875.0, 1462.0, 0.005134295240123707, 0.008506181818181819),
#  ('Gibraltar', 32677.0, 20550.0, 113.0, 0.628882700370291, 0.005498783454987835),
#  ('Greece', 10384972.0, 5628526.0, 38986.0, 0.5419875951519176, 0.0069265026047672165),
#  ('Greenland', 56494.0, 11971.0, 21.0, 0.21189860870180904, 0.001754239411912121),
#  ('Grenada', 125459.0, 19693.0, 238.0, 0.15696761491802103, 0.012085512618697),
#  ('Guadeloupe', 395762.0, 203235.0, 1021.0, 0.5135283326847954, 0.00502374098949492),
#  ('Guam', 171783.0, 52287.0, 419.0, 0.30437819807547895, 0.008013464149788667),
#  ('Guatemala', 17843914.0, 1250338.0, 20202.0, 0.07007083759762572, 0.016157231084714695),
#  ('Guernsey', 63329.0, 35326.0, 67.0, 0.5578171138025233, 0.0018966200532185926),
#  ('Guinea', 13859349.0, 38572.0, 468.0, 0.00278310330449143, 0.012133153582909883),
#  ('Guinea-Bissau', 2105580.0, 9614.0, 177.0, 0.004565962822595199, 0.01841065113376326),
#  ('Guyana', 808727.0, 74099.0, 1301.0, 0.09162424402795999, 0.01755759187033563),
#  ('Haiti', 11585003.0, 34298.0, 860.0, 0.002960551671846783, 0.025074348358504868),
#  ('Honduras', 10432858.0, 472785.0, 11114.0, 0.04531692082840579, 0.02350751398627283),
#  ('Hong Kong', 7488863.0, None, None, None, None),
#  ('Hungary', 9967304.0, 2230293.0, 49049.0, 0.22376090866697754, 0.021992177709386166),
#  ('Iceland', 372903.0, 209915.0, 186.0, 0.5629211886200969, 0.000886072934282924),
#  ('India', 1417173120.0, 45034360.0, 533552.0, 0.03177759962029198, 0.011847664760862594),
#  ('Indonesia', 275501344.0, 6828942.0, 162056.0, 0.02478732735329233, 0.023730762393354636),
#  ('Iran', 88550568.0, 7627186.0, 146811.0, 0.08613367674840888, 0.01924838334872127),
#  ('Iraq', 44496124.0, 2465545.0, 25375.0, 0.05541033192014657, 0.010291842168769988),
#  ('Ireland', 5023108.0, 1735149.0, 9572.0, 0.34543334525158526, 0.005516529128046064),
#  ('Isle of Man', 84534.0, 38008.0, 116.0, 0.44961790522156764, 0.003051989054935803),
#  ('Israel', 9449000.0, 4841558.0, 12707.0, 0.512388400888983, 0.0026245683724123517),
#  ('Italy', 59037472.0, 26718988.0, 196910.0, 0.4525767634494919, 0.007369665348103753),
#  ('Jamaica', 2827382.0, 156803.0, 3597.0, 0.055458724714240945, 0.02293961212476802),
#  ('Japan', 123951696.0, 33803572.0, 74694.0, 0.2727156875691318, 0.002209648140143296),
#  ('Jersey', 110796.0, 66391.0, 161.0, 0.5992183833351384, 0.0024250274886656324),
#  ('Jordan', 11285875.0, 1746997.0, 14122.0, 0.15479499817249437, 0.00808358571880776),
#  ('Kazakhstan', 19397998.0, 1503687.0, 19072.0, 0.07751763867590872, 0.012683490646657183),
#  ('Kenya', 54027484.0, 344101.0, 5689.0, 0.006368999156059164, 0.01653293655060578),
#  ('Kiribati', 131237.0, 5085.0, 24.0, 0.038746694910734014, 0.00471976401179941),
#  ('Kosovo', 1782115.0, 274279.0, 3212.0, 0.15390645384837678, 0.011710703334925385),
#  ('Kuwait', 4268886.0, 667185.0, 2570.0, 0.15629018905634867, 0.0038520050660611374),
#  ('Kyrgyzstan', 6630621.0, 88953.0, 1024.0, 0.013415485517872307, 0.011511697188402864),
#  ('Laos', 7529477.0, 218962.0, 671.0, 0.029080638668529037, 0.0030644586731944355),
#  ('Latvia', 1850654.0, 977701.0, 7465.0, 0.5283002657438938, 0.007635258632240327),
#  ('Lebanon', 5489744.0, 1239904.0, 10947.0, 0.22585825495687958, 0.008828909334916252),
#  ('Lesotho', 2305826.0, 36138.0, 709.0, 0.015672474852829313, 0.01961923736786762),
#  ('Liberia', 5302690.0, 8090.0, 294.0, 0.0015256407596898932, 0.03634116192830655),
#  ('Libya', 6812344.0, 507269.0, 6437.0, 0.07446320972634382, 0.012689519761704342),
#  ('Liechtenstein', 39355.0, 21575.0, 89.0, 0.5482149663321052, 0.0041251448435689455),
#  ('Lithuania', 2750058.0, 1365783.0, 9802.0, 0.4966378890917937, 0.007176835558796676),
#  ('Luxembourg', 647601.0, 391270.0, 1000.0, 0.6041837489441801, 0.002555779896235336),
#  ('Macao', 695180.0, None, None, None, None),
#  ('Madagascar', 29611718.0, 68493.0, 1426.0, 0.0023130370213575585, 0.020819645803220765),
#  ('Malawi', 20405318.0, 89168.0, 2686.0, 0.004369841234525235, 0.030122914049883365),
#  ('Malaysia', 33938216.0, 5278406.0, 37348.0, 0.15552986049708684, 0.007075620935562744),
#  ('Maldives', 523798.0, 186694.0, 316.0, 0.35642365950232724, 0.0016926092964958703),
#  ('Mali', 22593598.0, 33164.0, 743.0, 0.0014678494323923086, 0.022403811361717527),
#  ('Malta', 533293.0, 121409.0, 905.0, 0.22765909171881124, 0.007454142608867547),
#  ('Marshall Islands', 41593.0, 16178.0, 17.0, 0.388959680715505, 0.0010508097416244283),
#  ('Martinique', 367512.0, 230354.0, 1104.0, 0.6267931387274429, 0.004792623527266729),
#  ('Mauritania', 4736146.0, 63972.0, 997.0, 0.013507184955869181, 0.015584943412743075),
#  ('Mauritius', 1299478.0, 327256.0, 1070.0, 0.2518365066588276, 0.0032696115579240715),
#  ('Mayotte', 326113.0, 42027.0, 187.0, 0.12887250738241038, 0.0044495205463154636),
#  ('Mexico', 127504120.0, 7709747.0, 335011.0, 0.06046665001883861, 0.04345291745630563),
#  ('Micronesia (country)', 114178.0, 26547.0, 65.0, 0.23250538632661283, 0.0024484875880513807),
#  ('Moldova', 3272993.0, 635389.0, 12231.0, 0.19413087654021868, 0.01924962503285389),
#  ('Monaco', 36491.0, 17181.0, 67.0, 0.4708284234468773, 0.0038996565974041093),
#  ('Mongolia', 3398373.0, 1011517.0, 2284.0, 0.2976474330510512, 0.00225799467532429),
#  ('Montenegro', 627082.0, 251280.0, 2654.0, 0.4007131443734631, 0.010561922954473097),
#  ('Montserrat', 4413.0, 1403.0, 8.0, 0.31792431452526626, 0.005702066999287242),
#  ('Morocco', 37457976.0, 1279024.0, 16304.0, 0.034145571559979646, 0.012747219755063236),
#  ('Mozambique', 32969520.0, 233772.0, 2252.0, 0.007090549088976728, 0.00963331793371319),
#  ('Myanmar', 54179312.0, 641951.0, 19494.0, 0.011848636985275857, 0.030366803696855366),
#  ('Namibia', 2567024.0, 172399.0, 4106.0, 0.06715909161737482, 0.02381684348517103),
#  ('Nauru', 12691.0, 5393.0, 1.0, 0.42494681270191476, 0.00018542555164101615),
#  ('Nepal', 30547586.0, 1003450.0, 12031.0, 0.032848749488748476, 0.011989635756639593),
#  ('Netherlands', 17564020.0, 8635896.0, 22986.0, 0.49168106162484443, 0.002661680965125101),
#  ('New Caledonia', 289959.0, 80064.0, 314.0, 0.27612179652985425, 0.003921862509992006),
#  ('New Zealand', 5185289.0, 2573972.0, 3916.0, 0.49639894709822346, 0.0015213840709999954),
#  ('Nicaragua', 6948395.0, 16137.0, 245.0, 0.002322406829203003, 0.015182499845076532),
#  ('Niger', 26207982.0, 9515.0, 315.0, 0.00036305733115964443, 0.03310562270099842),
#  ('Nigeria', 218541216.0, 267188.0, 3155.0, 0.001222597754741147, 0.011808165037351976),
#  ('Niue', 1952.0, 1059.0, None, 0.5425204918032787, None),
#  ('North Korea', 26069416.0, None, None, None, None),
#  ('North Macedonia', 2093606.0, 350579.0, 9977.0, 0.16745223313269067, 0.028458635571440388),
#  ('Northern Cyprus', 382836.0, None, None, None, None),
#  ('Northern Ireland', 1896000.0, None, None, None, None),
#  ('Northern Mariana Islands', 49574.0, 14594.0, 41.0, 0.2943881873562755, 0.0028093737152254353),
#  ('Norway', 5434324.0, 1507196.0, 5732.0, 0.27734746768871343, 0.003803088649386012),
#  ('Oman', 4576300.0, 399449.0, 4628.0, 0.0872864541223259, 0.011585959659430866),
#  ('Pakistan', 235824864.0, 1580631.0, 30656.0, 0.006702562966388481, 0.019394786006348096),
#  ('Palau', 18084.0, 6290.0, 10.0, 0.34782127847821276, 0.001589825119236884),
#  ('Palestine', 5250076.0, 703228.0, 5708.0, 0.13394625144474098, 0.008116855415313384),
#  ('Panama', 4408582.0, 1044303.0, 8703.0, 0.23687956807880628, 0.00833378818216552),
#  ('Papua New Guinea', 10142625.0, 46864.0, 670.0, 0.004620500117080145, 0.014296688289518607),
#  ('Paraguay', 6780745.0, 735759.0, 19880.0, 0.10850710357047788, 0.02701971705408972),
#  ('Peru', 34049588.0, 4524748.0, 220831.0, 0.13288701173124326, 0.04880514892763089),
#  ('Philippines', 115559008.0, 4173631.0, 66864.0, 0.036116881515632256, 0.016020582557490108),
#  ('Pitcairn', 47.0, 4.0, None, 0.0851063829787234, None),
#  ('Poland', 39857144.0, 6662019.0, 120706.0, 0.16714742531476917, 0.018118531334119583),
#  ('Portugal', 10270857.0, 5643119.0, 28128.0, 0.5494301984732141, 0.004984477555763045),
#  ('Puerto Rico', 3252412.0, 1252713.0, 5938.0, 0.38516430267752055, 0.004740112060783276),
#  ('Qatar', 2695131.0, 514524.0, 690.0, 0.19090871649652652, 0.001341045315670406),
#  ('Reunion', 974062.0, 494595.0, 921.0, 0.507765419449686, 0.0018621296212052284),
#  ('Romania', 19659270.0, 3526339.0, 68708.0, 0.1793728353087373, 0.019484229962008756),
#  ('Russia', 144713312.0, 24078278.0, 402520.0, 0.16638606129061576, 0.01671714231391464),
#  ('Rwanda', 13776702.0, 133220.0, 1468.0, 0.009669948584211229, 0.011019366461492269),
#  ('Saint Barthelemy', 10994.0, 5507.0, 5.0, 0.5009095870474805, 0.0009079353550027238),
#  ('Saint Helena', 5401.0, 2166.0, None, 0.4010368450286984, None),
#  ('Saint Kitts and Nevis', 47681.0, 6607.0, 46.0, 0.13856672469117678, 0.006962312698652944),
#  ('Saint Lucia', 179872.0, 30251.0, 410.0, 0.16818070628002135, 0.01355327096624905),
#  ('Saint Martin (French part)', 31816.0, 12324.0, 46.0, 0.3873522755846115, 0.003732554365465758),
#  ('Saint Pierre and Miquelon', 5885.0, 3426.0, 2.0, 0.5821580288870009, 0.0005837711617046118),
#  ('Saint Vincent and the Grenadines', 103959.0, 9674.0, 124.0, 0.09305591627468521, 0.012817862311350011),
#  ('Samoa', 222390.0, 17057.0, 31.0, 0.07669859256261523, 0.0018174356569150495),
#  ('San Marino', 33690.0, 25292.0, 126.0, 0.7507272187592757, 0.00498181243080816),
#  ('Sao Tome and Principe', 227393.0, 6749.0, 80.0, 0.0296798934004125, 0.01185360794191732),
#  ('Saudi Arabia', 36408824.0, 841469.0, 9646.0, 0.023111677542784682, 0.011463286229201551),
#  ('Scotland', 5466000.0, None, None, None, None),
#  ('Senegal', 17316452.0, 89058.0, 1971.0, 0.005142970396014149, 0.02213164454625076),
#  ('Serbia', 6871547.0, 2583470.0, 18057.0, 0.37596628532119475, 0.006989436687865545),
#  ('Seychelles', 107135.0, 51831.0, 172.0, 0.48379147804172307, 0.0033184773591094134),
#  ('Sierra Leone', 8605723.0, 7794.0, 126.0, 0.0009056763737340837, 0.016166281755196306),
#  ('Singapore', 5637022.0, 3006155.0, 2024.0, 0.5332877891908174, 0.0006732853096397225),
#  ('Sint Maarten (Dutch part)', 44192.0, 11051.0, 92.0, 0.2500678855901521, 0.008325038458058095),
#  ('Slovakia', 5643455.0, 1877687.0, 21225.0, 0.33271940681727774, 0.011303800899723968),
#  ('Slovenia', 2119843.0, 1355844.0, 10049.0, 0.6395964229426424, 0.007411619625856662),
#  ('Solomon Islands', 724272.0, 25954.0, 199.0, 0.035834603574347756, 0.007667411574323804),
#  ('Somalia', 17597508.0, 27334.0, 1361.0, 0.0015532881132942233, 0.04979146850076827),
#  ('South Africa', 59893884.0, 4072648.0, 102595.0, 0.0679977274474302, 0.02519122693638144),
#  ('South Korea', 51815808.0, 34571873.0, 35934.0, 0.6672070615978815, 0.0010393998612687255),
#  ('South Sudan', 10913172.0, 18820.0, 147.0, 0.0017245215231648508, 0.007810839532412328),
#  ('Spain', 47558632.0, 13980340.0, 121852.0, 0.29396009540392165, 0.008715953975368267),
#  ('Sri Lanka', 21832150.0, 672754.0, 16899.0, 0.030814830422106847, 0.02511913715860478),
#  ('Sudan', 46874200.0, 63993.0, 5046.0, 0.001365207299537912, 0.07885237447845858),
#  ('Suriname', 618046.0, 82496.0, 1405.0, 0.13347873782857586, 0.01703112878200155),
#  ('Sweden', 10549349.0, 2751440.0, 27257.0, 0.2608160939599211, 0.009906448986712413),
#  ('Switzerland', 8740471.0, 4453191.0, 14188.0, 0.5094909645029427, 0.0031860299726645456),
#  ('Syria', 22125242.0, 57423.0, 3163.0, 0.0025953614428262527, 0.055082458248437036),
#  ('Taiwan', 23893396.0, None, None, None, None),
#  ('Tajikistan', 9952789.0, 17786.0, 125.0, 0.001787036779338937, 0.0070279995502080285),
#  ('Tanzania', 65497752.0, 43223.0, 846.0, 0.0006599157784835119, 0.01957291256969669),
#  ('Thailand', 71697024.0, 4770005.0, 34583.0, 0.06653002780143287, 0.007250097222120312),
#  ('Timor', 1341298.0, 23460.0, 138.0, 0.01749052037653079, 0.0058823529411764705),
#  ('Togo', 8848700.0, 39528.0, 290.0, 0.004467096861685897, 0.007336571544221818),
#  ('Tokelau', 1893.0, 80.0, None, 0.04226096143687269, None),
#  ('Tonga', 106867.0, 16958.0, 12.0, 0.15868322307166852, 0.000707630616818021),
#  ('Trinidad and Tobago', 1531043.0, 191496.0, 4390.0, 0.12507552041320852, 0.02292476083051343),
#  ('Tunisia', 12356116.0, 1153361.0, 29423.0, 0.09334332892310172, 0.02551065971538833),
#  ('Turkey', 85341248.0, 17004714.0, 101419.0, 0.1992555112388326, 0.00596416970023724),
#  ('Turkmenistan', 6430777.0, None, None, None, None),
#  ('Turks and Caicos Islands', 45726.0, 6754.0, 40.0, 0.14770590036303197, 0.005922416345869114),
#  ('Tuvalu', 11335.0, 2943.0, 1.0, 0.2596382884869872, 0.0003397893306150187),
#  ('Uganda', 47249588.0, 172149.0, 3632.0, 0.0036433968482434175, 0.021098002311950696),
#  ('Ukraine', 39701744.0, 5532832.0, 109920.0, 0.1393599233323352, 0.019866860226372317),
#  ('United Arab Emirates', 9441138.0, 1067030.0, 2349.0, 0.1130192144209734, 0.002201437635305474),
#  ('United Kingdom', 67508936.0, 24915266.0, 232112.0, 0.3690661929555518, 0.009316055465753406),
#  ('United States', 338289856.0, 103436829.0, 1184148.0, 0.3057639097519968, 0.01144803075894757),
#  ('United States Virgin Islands', 99479.0, 25389.0, 132.0, 0.2552196946089124, 0.005199101973295522),
#  ('Uruguay', 3422796.0, 1037893.0, 7625.0, 0.3032295818973728, 0.007346614728107811),
#  ('Uzbekistan', 34627648.0, 175081.0, 1016.0, 0.005056104301395232, 0.005803028312609592),
#  ('Vanuatu', 326744.0, 12019.0, 14.0, 0.03678414905859021, 0.0011648223645894002),
#  ('Vatican', 808.0, 26.0, None, 0.03217821782178218, None),
#  ('Venezuela', 28301700.0, 552695.0, 5856.0, 0.019528685555991337, 0.010595355485394295),
#  ('Vietnam', 98186856.0, 11624000.0, 43206.0, 0.11838651804881094, 0.0037169649002064694),
#  ('Wales', 3170000.0, None, None, None, None),
#  ('Wallis and Futuna', 11596.0, 3760.0, 9.0, 0.32424974129010004, 0.0023936170212765957),
#  ('Western Sahara', 576005.0, None, None, None, None),
#  ('Yemen', 33696612.0, 11945.0, 2159.0, 0.00035448667658339065, 0.18074508162411052),
#  ('Zambia', 20017670.0, 349558.0, 4069.0, 0.017462471906070986, 0.01164041446626883),
#  ('Zimbabwe', 16320539.0, 266359.0, 5740.0, 0.0163204781410712, 0.021549863154614636)]

# %% [markdown]
# **COVID-19 Impact Across Countries**
#
# **Countries with Highest COVID-19 Cases**
# 1. **United States**: Leading with approximately 166 million cases.
# 2. **India**: Following closely with around 45 million cases.
# 3. **Brazil**: Third highest with about 38 million cases.
#
# **Countries with Highest Death Counts**
# 1. **United States**: Highest death toll with around 4 million deaths.
# 2. **Brazil**: Second highest with approximately 702,000 deaths.
# 3. **India**: Third highest with about 533,000 deaths.
#
# **Countries with Highest COVID-19 Percentages (Cases/Population)**
# 1. **Gibraltar**: Highest COVID-19 percentage at 77.07%, indicating a significant impact on its population.
# 2. **Montenegro**: Second highest at 40.07%.
# 3. **Andorra**: Third highest with 60.14%.
#
# **Countries with Highest Death Percentages (Deaths/Cases)**
# 1. **Yemen**: Highest death percentage at 37.35%, indicating a high mortality rate among reported cases.
# 2. **Mexico**: Second highest at 34.45%.
# 3. **Syria**: Third highest with 29.16%.
#
# **Geographic Patterns**
# - **Europe**: Many European countries like France, Belgium, Italy, and Spain have relatively high COVID-19 percentages, indicating widespread infections.
# - **Latin America**: Countries like Brazil, Mexico, and Peru have high death percentages, suggesting challenges in managing severe cases.
# - **Asia**: Countries like India and Indonesia, with large populations, show significant case numbers but relatively lower death percentages compared to the US and Brazil.
#
# **Conclusion**
# - The dataset highlights the global impact of COVID-19, with some regions experiencing higher infection rates and mortality.
# - Vaccination rates and healthcare infrastructure likely contribute to the variation in death percentages.
# - Ongoing monitoring and effective public health measures remain crucial to managing the pandemic.
#
# This analysis provides a snapshot of the COVID-19 situation globally, highlighting the varied impacts on different countries and regions.

# %% [markdown]
# ### Vaccination Insights

# %%
# %%sql
# SELECT
#   location,
#   MAX(population) AS population,
#   MAX(total_vaccinations) AS total_vaccinations,
#   MAX(people_vaccinated) AS people_vaccinated,
#   MAX(people_fully_vaccinated) AS people_fully_vaccinated,
#   MAX(people_vaccinated) / MAX(population) AS vaccinated_percentage,
#   MAX(people_fully_vaccinated) / MAX(population) AS fully_vaccinated_percentage,
#   MAX(total_vaccinations) / MAX(people_vaccinated) AS avg_vaccination
# FROM COVID_COMBINE_VIEW
# WHERE continent IS NOT NULL
# GROUP BY location
# ORDER BY location
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Afghanistan', 41128772.0, 22606931.0, 18896999.0, 18115861.0, 0.4594593536612277, 0.44046685857773726, 1.196323871319462),
#  ('Albania', 2842318.0, 3088966.0, 1349255.0, 1279333.0, 0.4747023380212911, 0.45010199421739583, 2.2893863650681303),
#  ('Algeria', 44903228.0, 15267442.0, 7840131.0, 6481186.0, 0.17460061000514263, 0.14433675013297484, 1.9473452675726974),
#  ('American Samoa', 44295.0, None, None, None, None, None, None),
#  ('Andorra', 79843.0, 157072.0, 57913.0, 53501.0, 0.7253359718447453, 0.6700775271470261, 2.7122062403950755),
#  ('Angola', 35588996.0, 27722924.0, 16522932.0, 9591203.0, 0.4642708099998101, 0.26949911708664104, 1.677845312200038),
#  ('Anguilla', 15877.0, 24604.0, 10854.0, 10380.0, 0.6836304087673993, 0.6537759022485357, 2.2668140777593515),
#  ('Antigua and Barbuda', 93772.0, 136512.0, 64290.0, 62384.0, 0.6855991127415433, 0.6652732158853389, 2.1233784414372376),
#  ('Argentina', 45510324.0, 116978521.0, 41529058.0, 34900613.0, 0.9125194977737359, 0.7668724353621389, 2.816787248099873),
#  ('Armenia', 2780472.0, 2256919.0, 1150915.0, 1030758.0, 0.4139279230288958, 0.37071331773885874, 1.960978004457323),
#  ('Aruba', 106459.0, 174914.0, 90546.0, 84368.0, 0.8505246151100424, 0.7924928845846758, 1.9317694873324056),
#  ('Australia', 26177410.0, 69306345.0, 22231734.0, 21647523.0, 0.8492717193946995, 0.8269543472788179, 3.117451162378967),
#  ('Austria', 8939617.0, 20468731.0, 6899873.0, 6683263.0, 0.7718309408557436, 0.7476005963119001, 2.9665373551078402),
#  ('Azerbaijan', 10358078.0, 13857111.0, 5373253.0, 4862494.0, 0.5187500036203627, 0.46943979375324263, 2.578905367009519),
#  ('Bahamas', 409989.0, 366359.0, 174810.0, 166972.0, 0.4263772930493257, 0.40725970696774794, 2.0957553915679883),
#  ('Bahrain', 1472237.0, 3476633.0, 1241174.0, 1226796.0, 0.8430531225611094, 0.8332870319113024, 2.801084295997177),
#  ('Bangladesh', 171186368.0, 361710676.0, 151506403.0, 142198622.0, 0.8850377794100989, 0.8306655702865312, 2.3874283121882316),
#  ('Barbados', 281646.0, 381743.0, 163853.0, 155045.0, 0.5817693132513865, 0.550496012725194, 2.3297895064478524),
#  ('Belarus', 9534956.0, 22511000.0, 6536392.0, 6414996.0, 0.685518842457165, 0.672787163359747, 3.4439488941299725),
#  ('Belgium', 11655923.0, 31469387.0, 9261641.0, 9170945.0, 0.7945866663669621, 0.7868055579982812, 3.397819781613215),
#  ('Belize', 405285.0, 510717.0, 258473.0, 221402.0, 0.6377561469089653, 0.5462871806259793, 1.9759007710669974),
#  ('Benin', 13352864.0, 4232541.0, 3697190.0, 2742837.0, 0.2768836707990136, 0.20541188766694546, 1.144799428755352),
#  ('Bermuda', 64207.0, 132042.0, 48554.0, 47657.0, 0.7562103820455713, 0.742239942685377, 2.7194875808378303),
#  ('Bhutan', 782457.0, 2011426.0, 699116.0, 677669.0, 0.8934880766610817, 0.8660782637256744, 2.8770990794088536),
#  ('Bolivia', 12224114.0, 14690530.0, 7361008.0, 6160585.0, 0.6021710857735784, 0.5039698582653925, 1.995722596687845),
#  ('Bonaire Sint Eustatius and Saba', 27052.0, 35845.0, 19109.0, 16736.0, 0.706380304598551, 0.6186603578293657, 1.8758176775341462),
#  ('Bosnia and Herzegovina', 3233530.0, 1924950.0, 943394.0, 846080.0, 0.2917535943690023, 0.26165831150476415, 2.0404518154662843),
#  ('Botswana', 2630300.0, 3171667.0, 1951054.0, 1663490.0, 0.7417610158537049, 0.6324335627114778, 1.6256172304815757),
#  ('Brazil', 215313504.0, 486436436.0, 189643431.0, 176164186.0, 0.8807781559302477, 0.8181752780355105, 2.565005460168035),
#  ('British Virgin Islands', 31332.0, 41453.0, 19466.0, 18261.0, 0.6212817566704966, 0.5828226733052471, 2.1295078598582142),
#  ('Brunei', 449002.0, 1293100.0, 451149.0, 446714.0, 1.0047817158943613, 0.9949042543240342, 2.86623709683497),
#  ('Bulgaria', 6781955.0, 4726416.0, 2108544.0, 2078005.0, 0.3109050413929317, 0.3064020625321165, 2.241554361682754),
#  ('Burkina Faso', 22673764.0, 7893609.0, 6089089.0, 5232347.0, 0.26855219098161204, 0.23076658114638576, 1.2963530340909781),
#  ('Burundi', 12889583.0, 41538.0, 36909.0, 36321.0, 0.0028634751023365146, 0.0028178568693804913, 1.125416565065431),
#  ('Cambodia', 16767851.0, 47795644.0, 15315251.0, 14691716.0, 0.9133699363144389, 0.8761835968127341, 3.1207875078247165),
#  ('Cameroon', 27914542.0, 4880572.0, 3753733.0, 3197286.0, 0.13447231195840506, 0.11453836498553335, 1.3001915692991484),
#  ('Canada', 38454328.0, 102470460.0, 34742937.0, 31758251.0, 0.9034857402787015, 0.8258693533794167, 2.949389684585388),
#  ('Cape Verde', 593162.0, 859940.0, 356734.0, 308720.0, 0.6014107444509257, 0.5204648982908547, 2.410591645315557),
#  ('Cayman Islands', 68722.0, 151970.0, 62113.0, 60688.0, 0.9038299234597363, 0.8830942056401152, 2.44666977927326),
#  ('Central African Republic', 5579148.0, 3342248.0, 2600389.0, 2484985.0, 0.4660907005872581, 0.44540582182082283, 1.2852877011862456),
#  ('Chad', 17723312.0, 9148883.0, 5146338.0, 5019031.0, 0.2903711225080278, 0.28318809712315623, 1.7777462343126316),
#  ('Chile', 19603736.0, 66860038.0, 18088517.0, 17700117.0, 0.9227076410333214, 0.9028950910173449, 3.6962697384202365),
#  ('China', 1425887360.0, 3491077000.0, 1310292000.0, 1276760000.0, 0.9189309315428674, 0.8954143474558888, 2.6643503890735807),
#  ('Colombia', 51874028.0, 90506612.0, 43012174.0, 37019801.0, 0.8291658785394495, 0.7136480899458973, 2.104209194355068),
#  ('Comoros', 836783.0, 835021.0, 438825.0, 397080.0, 0.524419114633065, 0.47453162886913336, 1.902856491767789),
#  ('Congo', 5970430.0, 833210.0, 695760.0, 654119.0, 0.11653431997360324, 0.10955978045132428, 1.1975537541681038),
#  ('Cook Islands', 17032.0, 40854.0, 15112.0, 14728.0, 0.8872710192578676, 0.864725223109441, 2.703414505029116),
#  ('Costa Rica', 5180836.0, 13576935.0, 4650636.0, 4369784.0, 0.8976613040829704, 0.8434515201793688, 2.919371673035688),
#  ("Cote d'Ivoire", 28160548.0, 25263932.0, 13568372.0, 12164304.0, 0.48182201567952443, 0.43196261663657964, 1.8619722395582905),
#  ('Croatia', 4030361.0, 5374628.0, 2323025.0, 2251809.0, 0.5763813712965166, 0.558711490112176, 2.313633301406571),
#  ('Cuba', 11212198.0, 45995747.0, 10805570.0, 10053658.0, 0.9637334267553962, 0.8966714644175924, 4.25667012475973),
#  ('Curacao', 191173.0, 260324.0, 108601.0, 100885.0, 0.5680770820147196, 0.5277157339164004, 2.3970681669597886),
#  ('Cyprus', 896007.0, 1798610.0, 671193.0, 646142.0, 0.7490934780643455, 0.7211349911328818, 2.6797210340393898),
#  ('Czechia', 10493990.0, 19047737.0, 6982252.0, 6896048.0, 0.6653572187509231, 0.6571426121046428, 2.728021990612771),
#  ('Democratic Republic of Congo', 99010216.0, 18808671.0, 17045721.0, 14399520.0, 0.1721612343518168, 0.14543468928499256, 1.103424783263788),
#  ('Denmark', 5882259.0, 14961517.0, 4746522.0, 4712002.0, 0.8069216265383758, 0.8010531328185311, 3.1521010542034777),
#  ('Djibouti', 1120851.0, 442199.0, 421573.0, 401208.0, 0.376118681252013, 0.35794945090828306, 1.0489262832297135),
#  ('Dominica', 72758.0, 67647.0, 32995.0, 30659.0, 0.45348965062261193, 0.4213832155914126, 2.0502197302621608),
#  ('Dominican Republic', 11228821.0, 16430339.0, 7367193.0, 6130377.0, 0.6560967531675854, 0.5459501937024377, 2.230203416688011),
#  ('Ecuador', 18001002.0, 39564195.0, 15333873.0, 14240587.0, 0.8518344145509233, 0.7910996843397939, 2.580182775741002),
#  ('Egypt', 110990096.0, 112673535.0, 56907319.0, 42337175.0, 0.5127242974904715, 0.38145002595546906, 1.9799480449957587),
#  ('El Salvador', 6336393.0, 11289175.0, 4652597.0, 4344286.0, 0.7342658512500724, 0.6856086735781698, 2.426424424896461),
#  ('England', 56550000.0, 149398324.0, 45417090.0, 42951064.0, 0.8031315649867374, 0.7595236781609196, 3.2894737201348656),
#  ('Equatorial Guinea', 1674916.0, 488738.0, 270109.0, 214032.0, 0.16126719190693742, 0.12778670691545127, 1.809410275111159),
#  ('Eritrea', 3684041.0, None, None, None, None, None, None),
#  ('Estonia', 1326064.0, 2170995.0, 870166.0, 862696.0, 0.6562021139251197, 0.6505689016518057, 2.4949205094200417),
#  ('Eswatini', 1201680.0, 870205.0, 526050.0, 427335.0, 0.4377621330137807, 0.3556146395046934, 1.654224883566201),
#  ('Ethiopia', 123379928.0, 68856793.0, 52489512.0, 43653006.0, 0.4254299127164347, 0.35380962452822956, 1.3118200260653976),
#  ('Faeroe Islands', 53117.0, 103894.0, 41715.0, 40895.0, 0.785341792646422, 0.7699041738049965, 2.4905669423468777),
#  ('Falkland Islands', 3801.0, 4407.0, 2632.0, 1775.0, 0.6924493554327809, 0.4669823730597211, 1.6743920972644377),
#  ('Fiji', 929769.0, 1555182.0, 712025.0, 641194.0, 0.7658084965190278, 0.6896272084786651, 2.1841676907411958),
#  ('Finland', 5540745.0, 13327120.0, 4524288.0, 4347113.0, 0.8165486771183298, 0.7845719303090108, 2.945683387087648),
#  ('France', 67813000.0, 154493266.0, 54677678.0, 53192478.0, 0.8063008272750063, 0.7843994219397461, 2.825527192284939),
#  ('French Guiana', 304568.0, None, None, None, None, None, None),
#  ('French Polynesia', 306292.0, 502952.0, 190908.0, 186803.0, 0.6232875817847022, 0.60988533817403, 2.6345255306220796),
#  ('Gabon', 2388997.0, 572672.0, 311244.0, 257471.0, 0.13028229001543326, 0.1077736807538896, 1.8399455089897316),
#  ('Gambia', 2705995.0, 1444492.0, 674314.0, 539186.0, 0.2491926260026349, 0.1992560961864305, 2.1421652227300636),
#  ('Georgia', 3744385.0, 2930677.0, 1654504.0, 1276173.0, 0.44186268238976495, 0.34082312582707175, 1.7713326773462017),
#  ('Germany', 83369840.0, 192221468.0, 64876299.0, 63563414.0, 0.7781746852338928, 0.7624269639956128, 2.9628920108405072),
#  ('Ghana', 33475870.0, 25624828.0, 13864186.0, 10780003.0, 0.41415461345739485, 0.32202308707734856, 1.8482749726525596),
#  ('Gibraltar', 32677.0, 132810.0, 42175.0, 41465.0, 1.2906631575726046, 1.2689353367812222, 3.149021932424422),
#  ('Greece', 10384972.0, 22466648.0, 7937882.0, 7647054.0, 0.7643623882664297, 0.7363576907092286, 2.8303076311791986),
#  ('Greenland', 56494.0, 79738.0, 41227.0, 38511.0, 0.7297589124508798, 0.6816830105851949, 1.9341208431367793),
#  ('Grenada', 125459.0, 90686.0, 44241.0, 39034.0, 0.35263313114244493, 0.31112953235718444, 2.049818042087656),
#  ('Guadeloupe', 395762.0, None, None, None, None, None, None),
#  ('Guam', 171783.0, None, None, None, None, None, None),
#  ('Guatemala', 17843914.0, 20362104.0, 8933623.0, 7126305.0, 0.5006537803309297, 0.39936893889984004, 2.2792660939464313),
#  ('Guernsey', 63329.0, 178525.0, 54223.0, 52710.0, 0.8562112144515152, 0.8323201061125235, 3.2924220349298268),
#  ('Guinea', 13859349.0, 12049511.0, 8715641.0, 5853990.0, 0.6288636645198847, 0.422385640191325, 1.3825157552955658),
#  ('Guinea-Bissau', 2105580.0, 920752.0, 747057.0, 547637.0, 0.35479867779899127, 0.2600884316910305, 1.2325056856437997),
#  ('Guyana', 808727.0, 960133.0, 495285.0, 381984.0, 0.6124254538305263, 0.4723274974126003, 1.9385464934330738),
#  ('Haiti', 11585003.0, 669130.0, 521396.0, 355379.0, 0.04500611696000424, 0.030675779712789026, 1.2833431786971898),
#  ('Honduras', 10432858.0, 17074861.0, 6596213.0, 5853689.0, 0.6322536930915766, 0.5610820160688471, 2.5885854504698376),
#  ('Hong Kong', 7488863.0, 20997331.0, 6919434.0, 6802885.0, 0.9239632237897796, 0.9084002471403202, 3.034544588473566),
#  ('Hungary', 9967304.0, 16701238.0, 6420813.0, 6207249.0, 0.6441875355662875, 0.622761079625945, 2.6011095479653434),
#  ('Iceland', 372903.0, 805469.0, 309770.0, 290193.0, 0.8306985999039965, 0.7781996926814748, 2.600216289505117),
#  ('India', 1417173120.0, 2206866236.0, 1027438438.0, 951990130.0, 0.724991480222261, 0.6717528836561619, 2.1479303814015958),
#  ('Indonesia', 275501344.0, 448199860.0, 204419394.0, 174965137.0, 0.7419905508700531, 0.6350790687975736, 2.19255057570516),
#  ('Iran', 88550568.0, 155461757.0, 65199831.0, 58585264.0, 0.7363005395967647, 0.6616023513254031, 2.3843889564683076),
#  ('Iraq', 44496124.0, 19557364.0, 11332925.0, 7944775.0, 0.25469465610083253, 0.1785498215529964, 1.7257119410919952),
#  ('Ireland', 5023108.0, 11146000.0, 4111392.0, 4065378.0, 0.818495640547645, 0.8093351765480654, 2.7110039616752672),
#  ('Isle of Man', 84534.0, 189994.0, 69560.0, 67106.0, 0.8228641729954811, 0.7938344334823858, 2.7313686026451984),
#  ('Israel', 9449000.0, 18649248.0, 6723119.0, 6159825.0, 0.711516456767912, 0.6519023177055773, 2.773898245739812),
#  ('Italy', 59037472.0, 144608839.0, 50936719.0, 47947097.0, 0.8627862487065842, 0.8121468514098977, 2.8389900613739965),
#  ('Jamaica', 2827382.0, 1528445.0, 859773.0, 760132.0, 0.30408802206422764, 0.2688465867010542, 1.7777308661704891),
#  ('Japan', 123951696.0, 383747738.0, 104705133.0, 103380343.0, 0.8447252952472711, 0.8340373414495272, 3.6650327162088607),
#  ('Jersey', 110796.0, 266953.0, 84365.0, 81882.0, 0.7614444564785733, 0.7390339001407993, 3.1642624311029457),
#  ('Jordan', 11285875.0, 10057975.0, 4821579.0, 4558313.0, 0.42722243512355046, 0.403895400223731, 2.086033434275369),
#  ('Kazakhstan', 19397998.0, 38355605.0, 10858101.0, 10629063.0, 0.5597536921078144, 0.5479463911688206, 3.532441354155759),
#  ('Kenya', 54027484.0, 23750431.0, 14494372.0, 11090440.0, 0.2682777528563055, 0.20527404163406907, 1.6385967601769846),
#  ('Kiribati', 131237.0, 219980.0, 100900.0, 81474.0, 0.7688380563408185, 0.6208157760387696, 2.1801783944499507),
#  ('Kosovo', 1782115.0, 1837446.0, 906858.0, 825082.0, 0.508866150613176, 0.46297910067532116, 2.026167272053618),
#  ('Kuwait', 4268886.0, 8261221.0, 3457498.0, 3346176.0, 0.8099298037005439, 0.7838522743404251, 2.389363927325482),
#  ('Kyrgyzstan', 6630621.0, 3661335.0, 1736541.0, 1406016.0, 0.26189718881534624, 0.21204891668517925, 2.108406884720833),
#  ('Laos', 7529477.0, 11111066.0, 5888649.0, 5222417.0, 0.782079419327531, 0.6935962484512537, 1.8868616553644137),
#  ('Latvia', 1850654.0, 2895716.0, 1346184.0, 1305976.0, 0.7274098778053596, 0.705683504317933, 2.151055130650788),
#  ('Lebanon', 5489744.0, 5814699.0, 2740227.0, 2414223.0, 0.4991538767563661, 0.43976968689250356, 2.1219771208735625),
#  ('Lesotho', 2305826.0, 1339097.0, 1014073.0, 938088.0, 0.4397873039856433, 0.4068338200714191, 1.3205134147147197),
#  ('Liberia', 5302690.0, 4460668.0, 3903802.0, 3730967.0, 0.7361927625412762, 0.703598928091214, 1.1426470912203026),
#  ('Libya', 6812344.0, 3739158.0, 2316327.0, 1236102.0, 0.3400190888774848, 0.1814503201834787, 1.614261716933749),
#  ('Liechtenstein', 39355.0, 74337.0, 26771.0, None, 0.6802439334265024, None, 2.776773374173546),
#  ('Lithuania', 2750058.0, 4604719.0, 1958267.0, 1881100.0, 0.7120820724508355, 0.6840219369918743, 2.3514255206261456),
#  ('Luxembourg', 647601.0, 1374547.0, 481957.0, 462702.0, 0.7442190484573062, 0.7144862345796255, 2.8520116939892977),
#  ('Macao', 695180.0, 1802985.0, 679703.0, 642266.0, 0.9777367012859979, 0.9238844615782963, 2.6526070945692455),
#  ('Madagascar', 29611718.0, 3092063.0, 2710365.0, 2628849.0, 0.09153015032765069, 0.08877732119426505, 1.140829002735794),
#  ('Malawi', 20405318.0, 8503954.0, 5433538.0, 4288014.0, 0.26628048629283796, 0.21014198357506605, 1.5650859532039714),
#  ('Malaysia', 33938216.0, 72654764.0, 28138126.0, 27550983.0, 0.8290985595707211, 0.8117982100178749, 2.5820754374331822),
#  ('Maldives', 523798.0, 951764.0, 399308.0, 385167.0, 0.7623320440322414, 0.7353349955517203, 2.383533512977451),
#  ('Mali', 22593598.0, 5922585.0, 4354292.0, 3633589.0, 0.1927223809151601, 0.1608238316004383, 1.3601717569699046),
#  ('Malta', 533293.0, 1408793.0, 478953.0, 471565.0, 0.8981047941750595, 0.8842512465005166, 2.941401348357772),
#  ('Marshall Islands', 41593.0, None, None, None, None, None, None),
#  ('Martinique', 367512.0, None, None, None, None, None, None),
#  ('Mauritania', 4736146.0, 4075874.0, 2103754.0, 1540597.0, 0.44419112079737405, 0.32528494687452625, 1.9374289959757651),
#  ('Mauritius', 1299478.0, 2616012.0, 1123773.0, 1088142.0, 0.8647880148798209, 0.8373685433689527, 2.327882944331284),
#  ('Mayotte', 326113.0, None, None, None, None, None, None),
#  ('Mexico', 127504120.0, 223158993.0, 97179493.0, 81849962.0, 0.7621674734902684, 0.6419397428098794, 2.2963588933315386),
#  ('Micronesia (country)', 114178.0, None, None, None, None, None, None),
#  ('Moldova', 3272993.0, 2291436.0, 1109270.0, 1078813.0, 0.3389160930072261, 0.32961054301063275, 2.065715290235921),
#  ('Monaco', 36491.0, 65140.0, 28875.0, 25667.0, 0.791291003261078, 0.7033789153489901, 2.255930735930736),
#  ('Mongolia', 3398373.0, 5492919.0, 2272965.0, 2175617.0, 0.6688391768649292, 0.6401937044579862, 2.4166315803366967),
#  ('Montenegro', 627082.0, 679171.0, 292783.0, 284869.0, 0.46689747114412466, 0.45427711208422505, 2.3197077699183355),
#  ('Montserrat', 4413.0, 4619.0, 2104.0, 1952.0, 0.47677317017901655, 0.4423294810786313, 2.195342205323194),
#  ('Morocco', 37457976.0, 55389602.0, 25020168.0, 23521989.0, 0.6679530148665801, 0.6279567534561932, 2.2137981647445373),
#  ('Mozambique', 32969520.0, 34950858.0, 22869646.0, 21329745.0, 0.6936602656028963, 0.6469534588310658, 1.5282640579569968),
#  ('Myanmar', 54179312.0, 93477104.0, 41551927.0, 35937796.0, 0.766933456076371, 0.6633121513244761, 2.2496454616894184),
#  ('Namibia', 2567024.0, 1005937.0, 629767.0, 550978.0, 0.2453296112541215, 0.21463687133427659, 1.5973161502587465),
#  ('Nauru', 12691.0, 32157.0, 13106.0, 11346.0, 1.0327003388227878, 0.8940193838153022, 2.4536090340302152),
#  ('Nepal', 30547586.0, 62627629.0, 27883196.0, 24471043.0, 0.9127790326869036, 0.8010794371771308, 2.2460706799894816),
#  ('Netherlands', 17564020.0, 39764182.0, 12582081.0, 11768644.0, 0.7163554243276881, 0.6700427350913971, 3.1603819749690056),
#  ('New Caledonia', 289959.0, 480702.0, 192375.0, 184816.0, 0.6634558678985649, 0.6373866650112602, 2.498775828460039),
#  ('New Zealand', 5185289.0, 13075286.0, 4302330.0, 4291717.0, 0.8297184592797046, 0.8276717074014582, 3.039117408474013),
#  ('Nicaragua', 6948395.0, 15507763.0, 6404524.0, 6126708.0, 0.9217271038851418, 0.8817443452768589, 2.4213763583367007),
#  ('Niger', 26207982.0, 7372208.0, 6248483.0, 5483001.0, 0.23841908163703715, 0.20921110980616517, 1.179839650680013),
#  ('Nigeria', 218541216.0, 133048021.0, 93829435.0, 81297808.0, 0.4293443439062772, 0.3720021764681679, 1.4179774289379448),
#  ('Niue', 1952.0, 4923.0, 1638.0, 1635.0, 0.8391393442622951, 0.8376024590163934, 3.0054945054945055),
#  ('North Korea', 26069416.0, None, None, None, None, None, None),
#  ('North Macedonia', 2093606.0, 1862987.0, 854570.0, 838181.0, 0.4081809089198254, 0.40035278844252453, 2.1800285523713683),
#  ('Northern Cyprus', 382836.0, 861519.0, 301673.0, 313067.0, 0.7879953818345192, 0.8177574731738917, 2.8558041322889354),
#  ('Northern Ireland', 1896000.0, 4600649.0, 1430694.0, 1361003.0, 0.7545854430379747, 0.7178285864978903, 3.21567644793366),
#  ('Northern Mariana Islands', 49574.0, None, None, None, None, None, None),
#  ('Norway', 5434324.0, 12145560.0, 4346995.0, 4054726.0, 0.7999145799919181, 0.746132545648732, 2.7940128755611635),
#  ('Oman', 4576300.0, 7108547.0, 3279632.0, 3048826.0, 0.7166558136485808, 0.6662207460175251, 2.1674831200573723),
#  ('Pakistan', 235824864.0, 340974144.0, 165567890.0, 140475871.0, 0.7020798705941372, 0.5956787957693893, 2.0594219325981626),
#  ('Palau', 18084.0, None, None, None, None, None, None),
#  ('Palestine', 5250076.0, 3748571.0, 2012767.0, 1776973.0, 0.3833786406139644, 0.3384661479186206, 1.8623968894561567),
#  ('Panama', 4408582.0, 8893001.0, 3533477.0, 3174155.0, 0.8014996658789606, 0.7199945469994661, 2.516784742054356),
#  ('Papua New Guinea', 10142625.0, 737695.0, 382020.0, 321192.0, 0.037664805708581356, 0.031667541686693536, 1.9310376420082718),
#  ('Paraguay', 6780745.0, 9745545.0, 3993938.0, 3546685.0, 0.5890116793951107, 0.5230524079581226, 2.440084197601465),
#  ('Peru', 34049588.0, 91412580.0, 30563708.0, 28709644.0, 0.897623430862071, 0.8431715532064588, 2.9908864461079134),
#  ('Philippines', 115559008.0, 189317158.0, 82684774.0, 78443972.0, 0.7155199359274528, 0.6788217842783836, 2.289625391006088),
#  ('Pitcairn', 47.0, 117.0, 47.0, 47.0, 1.0, 1.0, 2.4893617021276597),
#  ('Poland', 39857144.0, 58032403.0, 22877472.0, 22649355.0, 0.573986736229771, 0.568263370802484, 2.5366615244901185),
#  ('Portugal', 10270857.0, 28314797.0, 9821414.0, 8909769.0, 0.9562409446456124, 0.8674805812212165, 2.882965426363251),
#  ('Puerto Rico', 3252412.0, None, None, None, None, None, None),
#  ('Qatar', 2695131.0, 7609178.0, 2852178.0, 2852178.0, 1.0582706369374995, 1.0582706369374995, 2.6678482198516362),
#  ('Reunion', 974062.0, None, None, None, None, None, None),
#  ('Romania', 19659270.0, 16827486.0, 8188146.0, 8114769.0, 0.4165030542843147, 0.41277061660987413, 2.055103316428408),
#  ('Russia', 144713312.0, 187374508.0, 89081596.0, 79702396.0, 0.6155729197877802, 0.5507606376944784, 2.103403131663694),
#  ('Rwanda', 13776702.0, 27322059.0, 10884714.0, 10399665.0, 0.7900812545702157, 0.7548733361583926, 2.510131088423637),
#  ('Saint Barthelemy', 10994.0, None, None, None, None, None, None),
#  ('Saint Helena', 5401.0, 7892.0, 4361.0, 3531.0, 0.8074430660988706, 0.6537678207739308, 1.8096766796606283),
#  ('Saint Kitts and Nevis', 47681.0, 64297.0, 33794.0, 27000.0, 0.708751913760198, 0.5662632914578134, 1.9026158489672722),
#  ('Saint Lucia', 179872.0, 122977.0, 60140.0, 54971.0, 0.33434887030777444, 0.3056117683686177, 2.044845360824742),
#  ('Saint Martin (French part)', 31816.0, None, None, None, None, None, None),
#  ('Saint Pierre and Miquelon', 5885.0, None, None, None, None, None, None),
#  ('Saint Vincent and the Grenadines', 103959.0, 73443.0, 37532.0, 31632.0, 0.36102694331419116, 0.30427380024817474, 1.9568101886390281),
#  ('Samoa', 222390.0, 453083.0, 191403.0, 177954.0, 0.860663698907325, 0.8001888574126534, 2.3671677037455003),
#  ('San Marino', 33690.0, 69338.0, 26357.0, 23633.0, 0.7823389729890176, 0.7014841199168893, 2.6307242857684865),
#  ('Sao Tome and Principe', 227393.0, 263863.0, 140256.0, 111986.0, 0.6167999894455855, 0.49247778075842263, 1.8812956308464521),
#  ('Saudi Arabia', 36408824.0, 68534631.0, 27041364.0, 25433941.0, 0.7427145683145383, 0.6985652983463569, 2.534436909321586),
#  ('Scotland', 5466000.0, 13014285.0, 4549556.0, 4285946.0, 0.8323373582144163, 0.7841101353823637, 2.8605615580948998),
#  ('Senegal', 17316452.0, 3179647.0, 2684696.0, 1546628.0, 0.15503730209860542, 0.08931552491237812, 1.1843601659182268),
#  ('Serbia', 6871547.0, 8534688.0, 3354075.0, 3278198.0, 0.48811061031817143, 0.4770684097773034, 2.5445727957782696),
#  ('Seychelles', 107135.0, 224558.0, 88520.0, 83565.0, 0.8262472581322631, 0.7799971997946517, 2.5368052417532763),
#  ('Sierra Leone', 8605723.0, 9155936.0, 5676123.0, 4961886.0, 0.6595753779200191, 0.576579794632014, 1.6130615915123756),
#  ('Singapore', 5637022.0, 14727569.0, 5160551.0, 5120969.0, 0.9154746956815141, 0.908452902968979, 2.8538752935490805),
#  ('Sint Maarten (Dutch part)', 44192.0, 66829.0, 29788.0, 26773.0, 0.6740586531498913, 0.6058336350470673, 2.243487310326306),
#  ('Slovakia', 5643455.0, 5754313.0, 2595901.0, 2577827.0, 0.45998435355646494, 0.4567817055332239, 2.2166920079001473),
#  ('Slovenia', 2119843.0, 2996643.0, 1265802.0, 1222225.0, 0.5971206358206717, 0.576563924781222, 2.3673868424919537),
#  ('Solomon Islands', 724272.0, 625956.0, 343821.0, 254352.0, 0.47471253893564846, 0.3511829809795215, 1.8205868751472423),
#  ('Somalia', 17597508.0, 10555834.0, 8972167.0, 7666835.0, 0.5098544066580336, 0.43567731294681045, 1.1765088634663177),
#  ('South Africa', 59893884.0, 41798812.0, 24210953.0, 21038797.0, 0.404230805936713, 0.3512678690198151, 1.726442242897254),
#  ('South Korea', 51815808.0, 129647782.0, 44784499.0, 44372679.0, 0.8643018555264061, 0.8563540879262174, 2.8949253624563265),
#  ('South Sudan', 10913172.0, 4365547.0, 4315127.0, 4273253.0, 0.39540538717799006, 0.39156837260514177, 1.0116844764939712),
#  ('Spain', 47558632.0, 105840320.0, 41351234.0, 40739123.0, 0.8694790464115957, 0.8566083860444094, 2.559544414079638),
#  ('Sri Lanka', 21832150.0, 40116590.0, 17143761.0, 14752827.0, 0.7852529869939516, 0.6757386240017589, 2.3400110395846045),
#  ('Sudan', 46874200.0, 22598737.0, 15207452.0, 13416394.0, 0.3244311796254656, 0.2862212901766857, 1.486030467168333),
#  ('Suriname', 618046.0, 505699.0, 267820.0, 237879.0, 0.4333334412001696, 0.38488882704523614, 1.8882047643939959),
#  ('Sweden', 10549349.0, 28312817.0, 7775726.0, 7593676.0, 0.7370811222569279, 0.7198241332237657, 3.641179871821615),
#  ('Switzerland', 8740471.0, 16940716.0, 6096911.0, None, 0.6975494798850085, None, 2.778573608832407),
#  ('Syria', 22125242.0, 5090630.0, 3295630.0, 2358365.0, 0.14895339901818927, 0.10659160247829154, 1.5446606566877956),
#  ('Taiwan', 23893396.0, 68158988.0, 21899240.0, 20793089.0, 0.9165394488083652, 0.8702441879756231, 3.11239056697858),
#  ('Tajikistan', 9952789.0, 20525784.0, 5328277.0, 5191919.0, 0.5353551652707598, 0.5216546839282938, 3.8522366611195324),
#  ('Tanzania', 65497752.0, 39392419.0, 34434933.0, 32165791.0, 0.5257422117327019, 0.4910976333966393, 1.143966767700695),
#  ('Thailand', 71697024.0, 142635014.0, 57005497.0, 53486086.0, 0.7950887473376859, 0.7460014797824802, 2.502127365015342),
#  ('Timor', 1341298.0, 2028798.0, 886838.0, 801759.0, 0.6611789475567696, 0.5977485987453944, 2.2876759904289172),
#  ('Togo', 8848700.0, 3423181.0, 2255579.0, 1554066.0, 0.254905127306836, 0.1756264762055443, 1.517650678606247),
#  ('Tokelau', 1893.0, 5374.0, 2203.0, 2203.0, 1.1637612255678818, 1.1637612255678818, 2.439400817067635),
#  ('Tonga', 106867.0, 203208.0, 87342.0, 77360.0, 0.817296265451449, 0.72389044326125, 2.3265782784914473),
#  ('Trinidad and Tobago', 1531043.0, 1580898.0, 753588.0, 716898.0, 0.4922056402073619, 0.4682415843317268, 2.0978279908915747),
#  ('Tunisia', 12356116.0, 13253317.0, 7218871.0, 6401841.0, 0.5842346413711235, 0.5181111119384118, 1.8359265597071897),
#  ('Turkey', 85341248.0, 152543341.0, 57941051.0, 53176961.0, 0.6789337203036918, 0.6231097182923784, 2.6327334138277885),
#  ('Turkmenistan', 6430777.0, 16775970.0, 4614869.0, 4568901.0, 0.7176223028725767, 0.7104741775371779, 3.6351996123833636),
#  ('Turks and Caicos Islands', 45726.0, 73907.0, 32815.0, 30710.0, 0.7176442286664042, 0.6716091501552727, 2.2522322108791712),
#  ('Tuvalu', 11335.0, 26783.0, 9763.0, 9505.0, 0.8613145125716807, 0.8385531539479488, 2.7433166035030214),
#  ('Uganda', 47249588.0, 26406936.0, 20033189.0, 13061126.0, 0.4239865329619382, 0.27642835742821714, 1.3181593804161684),
#  ('Ukraine', 39701744.0, 31668577.0, 15774300.0, 15153577.0, 0.3973200774253141, 0.38168542419698237, 2.0076058525576412),
#  ('United Arab Emirates', 9441138.0, 24922054.0, 9991089.0, 9792266.0, 1.0582504990394166, 1.0371912792716302, 2.494428184955614),
#  ('United Kingdom', 67508936.0, 151248820.0, 53813491.0, 50762968.0, 0.7971313753189652, 0.7519444240685411, 2.8106115620709313),
#  ('United States', 338289856.0, 676728782.0, 270227181.0, 230637348.0, 0.7988036774002469, 0.6817743538842619, 2.5042957540233526),
#  ('United States Virgin Islands', 99479.0, None, None, None, None, None, None),
#  ('Uruguay', 3422796.0, 9036273.0, 3010451.0, 2903089.0, 0.879529776241412, 0.8481630222776935, 3.001634306620503),
#  ('Uzbekistan', 34627648.0, 82204584.0, 22087857.0, 18445168.0, 0.637867665745014, 0.5326716963277437, 3.721709353696015),
#  ('Vanuatu', 326744.0, 366638.0, 176624.0, 162250.0, 0.540557745513307, 0.49656611904120657, 2.07581076184437),
#  ('Vatican', 808.0, None, None, None, None, None, None),
#  ('Venezuela', 28301700.0, 37860994.0, 22157232.0, 14966671.0, 0.7828940311006053, 0.5288258655840462, 1.7087420486457876),
#  ('Vietnam', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Wales', 3170000.0, 8932482.0, 2592226.0, 2477109.0, 0.8177369085173501, 0.7814223974763407, 3.4458731607506445),
#  ('Wallis and Futuna', 11596.0, 18058.0, 7150.0, 6803.0, 0.6165919282511211, 0.5866678164884442, 2.5255944055944055),
#  ('Western Sahara', 576005.0, None, None, None, None, None, None),
#  ('Yemen', 33696612.0, 1298447.0, 1050112.0, 806967.0, 0.03116372648977292, 0.023948015901420594, 1.2364842988176499),
#  ('Zambia', 20017670.0, 13454213.0, 11711565.0, 9213802.0, 0.585061348298778, 0.46028343958113005, 1.1487971932017624),
#  ('Zimbabwe', 16320539.0, 12222754.0, 6437808.0, 4751270.0, 0.39446050158024804, 0.29112212531706216, 1.8985893956452258)]

# %% [markdown]
# **COVID-19 Vaccinations Across Countries**
#
# 1. **Vaccination Status by Country:**
#    - Most countries have a higher percentage of people vaccinated compared to fully vaccinated, indicating ongoing vaccination efforts.
#    - Countries with high vaccination percentages: Gibraltar (129.07%), Macao (97.77%), Iceland (83.07%), Hong Kong (92.40%).
#    - Countries with low vaccination percentages: Burundi (0.28%), Haiti (0.05%), Guinea (0.63%), Democratic Republic of Congo (0.16%).
#
# 2. **Vaccination Rates:**
#    - The overall average vaccination rate across all locations is approximately 2.25.
#    - Countries with high average vaccination rates: Gibraltar (3.15), England (3.29), Belgium (3.40), Chile (3.70).
#    - Countries with low average vaccination rates: Burundi (1.13), Mali (1.36), Central African Republic (1.29), Guinea-Bissau (1.23).
#
# 3. **Population vs. Vaccination:**
#    - Larger populations generally have higher total vaccination numbers.
#    - Some larger countries have lower vaccination percentages due to the challenges of vaccinating a large population.
#    - Smaller countries like Gibraltar and Macao have achieved very high vaccination rates, likely due to their smaller populations and efficient vaccination programs.
#
# 4. **Fully Vaccinated Percentage:**
#    - The average fully vaccinated percentage is 39.69%, indicating that, on average, about 40% of the population across these countries is fully vaccinated.
#    - Fully vaccinated percentages range from 0% (some countries with missing data) to over 90% in Gibraltar and Macao.
#
# 5. **Average Vaccination Rate:**
#    - The average vaccination rate per location is 2.25, indicating the average number of doses administered per person.
#    - This metric helps understand the pace of vaccination efforts in each country.
#
# 6. **Countries with Missing Data:**
#    - Some countries have missing data for vaccination metrics, such as American Samoa, Eritrea, French Guiana, Guam, Marshall Islands, Mayotte, Micronesia, Montserrat, Nauru, Northern Cyprus, Palau, Papua New Guinea, Puerto Rico, Solomon Islands, South Sudan, Syria, Timor, Tonga, Tuvalu, Vanuatu, Vatican City, Venezuela, Wallis and Futuna, Western Sahara, and Yemen.
#
# 7. **Geographical Disparities:**
#    - Vaccination rates vary widely by region, likely influenced by factors such as access to vaccines, distribution infrastructure, and public health campaigns.
#
# **Conclusion:**
# - The data provides a snapshot of global COVID-19 vaccination efforts.
# - While some countries have achieved high vaccination rates, others lag due to various challenges.
# - Ongoing efforts to improve vaccination access and education are crucial for achieving global immunity.
#
# This analysis provides a broad overview, and deeper insights can be gained by analyzing specific regions or comparing countries with similar population sizes or geographical locations.

# %% [markdown]
# ## COVID-19 Trends in Vietnam

# %% [markdown]
# After analyzing the global, continental, and individual country numbers, let's shift our focus to the cases and deaths specifically in Vietnam. Here, we delve into key metrics including total cases, deaths, vaccinations, and percentages related to the COVID-19 situation in Vietnam.

# %% [markdown]
# ### COVID-19 Insights

# %%
# %%sql
# SELECT
#   location,
#   date,
#   population,
#   total_cases,
#   total_deaths,
#   total_cases / population AS covid_percentage,
#   total_deaths / total_cases AS death_percentage
# FROM COVID_COMBINE_VIEW
# WHERE continent IS NOT NULL
#   AND location == 'Vietnam'
#   AND NOT (new_cases == 0 AND new_deaths == 0)
# ORDER BY location, date
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Vietnam', '2020-01-26', 98186856.0, 2.0, None, 2.0369325197661894e-08, None),
#  ('Vietnam', '2020-02-02', 98186856.0, 6.0, None, 6.110797559298569e-08, None),
#  ('Vietnam', '2020-02-09', 98186856.0, 13.0, None, 1.324006137848023e-07, None),
#  ('Vietnam', '2020-02-16', 98186856.0, 16.0, None, 1.6295460158129515e-07, None),
#  ('Vietnam', '2020-03-08', 98186856.0, 20.0, None, 2.0369325197661894e-07, None),
#  ('Vietnam', '2020-03-15', 98186856.0, 53.0, None, 5.397871177380402e-07, None),
#  ('Vietnam', '2020-03-22', 98186856.0, 94.0, None, 9.57358284290109e-07, None),
#  ('Vietnam', '2020-03-29', 98186856.0, 174.0, None, 1.7721312921965849e-06, None),
#  ('Vietnam', '2020-04-05', 98186856.0, 240.0, None, 2.4443190237194276e-06, None),
#  ('Vietnam', '2020-04-12', 98186856.0, 258.0, None, 2.6276429504983842e-06, None),
#  ('Vietnam', '2020-04-19', 98186856.0, 268.0, None, 2.729489576486694e-06, None),
#  ('Vietnam', '2020-04-26', 98186856.0, 270.0, None, 2.7498589016843556e-06, None),
#  ('Vietnam', '2020-05-10', 98186856.0, 288.0, None, 2.9331828284633127e-06, None),
#  ('Vietnam', '2020-05-17', 98186856.0, 318.0, None, 3.2387227064282412e-06, None),
#  ('Vietnam', '2020-05-24', 98186856.0, 325.0, None, 3.310015344620058e-06, None),
#  ('Vietnam', '2020-05-31', 98186856.0, 328.0, None, 3.340569332416551e-06, None),
#  ('Vietnam', '2020-06-07', 98186856.0, 329.0, None, 3.3507539950153815e-06, None),
#  ('Vietnam', '2020-06-14', 98186856.0, 334.0, None, 3.4016773080095366e-06, None),
#  ('Vietnam', '2020-06-21', 98186856.0, 349.0, None, 3.554447246992001e-06, None),
#  ('Vietnam', '2020-06-28', 98186856.0, 355.0, None, 3.6155552225849865e-06, None),
#  ('Vietnam', '2020-07-12', 98186856.0, 370.0, None, 3.7683251615674503e-06, None),
#  ('Vietnam', '2020-07-19', 98186856.0, 382.0, None, 3.890541112753422e-06, None),
#  ('Vietnam', '2020-07-26', 98186856.0, 418.0, None, 4.257188966311336e-06, None),
#  ('Vietnam', '2020-08-02', 98186856.0, 590.0, 3.0, 6.008950933310259e-06, 0.005084745762711864),
#  ('Vietnam', '2020-08-09', 98186856.0, 812.0, 10.0, 8.269946030250729e-06, 0.012315270935960592),
#  ('Vietnam', '2020-08-16', 98186856.0, 951.0, 23.0, 9.68561413148823e-06, 0.024185068349106203),
#  ('Vietnam', '2020-08-23', 98186856.0, 1014.0, 26.0, 1.032724787521458e-05, 0.02564102564102564),
#  ('Vietnam', '2020-08-30', 98186856.0, 1040.0, 32.0, 1.0592049102784186e-05, 0.03076923076923077),
#  ('Vietnam', '2020-09-06', 98186856.0, 1049.0, 35.0, 1.0683711066173664e-05, 0.03336510962821735),
#  ('Vietnam', '2020-09-13', 98186856.0, 1060.0, 35.0, 1.0795742354760804e-05, 0.0330188679245283),
#  ('Vietnam', '2020-09-20', 98186856.0, 1068.0, 35.0, 1.0877219655551451e-05, 0.03277153558052434),
#  ('Vietnam', '2020-09-27', 98186856.0, 1069.0, 35.0, 1.0887404318150282e-05, 0.03274087932647334),
#  ('Vietnam', '2020-10-04', 98186856.0, 1096.0, 35.0, 1.1162390208318718e-05, 0.03193430656934307),
#  ('Vietnam', '2020-10-11', 98186856.0, 1107.0, 35.0, 1.1274421496905859e-05, 0.031616982836495035),
#  ('Vietnam', '2020-10-18', 98186856.0, 1126.0, 35.0, 1.1467930086283646e-05, 0.03108348134991119),
#  ('Vietnam', '2020-10-25', 98186856.0, 1160.0, 35.0, 1.18142086146439e-05, 0.03017241379310345),
#  ('Vietnam', '2020-11-01', 98186856.0, 1180.0, 35.0, 1.2017901866620518e-05, 0.029661016949152543),
#  ('Vietnam', '2020-11-08', 98186856.0, 1213.0, 35.0, 1.2353995732381939e-05, 0.028854080791426217),
#  ('Vietnam', '2020-11-15', 98186856.0, 1265.0, 35.0, 1.2883598187521149e-05, 0.02766798418972332),
#  ('Vietnam', '2020-11-22', 98186856.0, 1306.0, 35.0, 1.3301169354073217e-05, 0.02679938744257274),
#  ('Vietnam', '2020-11-29', 98186856.0, 1341.0, 35.0, 1.36576325450323e-05, 0.02609992542878449),
#  ('Vietnam', '2020-12-06', 98186856.0, 1365.0, 35.0, 1.3902064447404243e-05, 0.02564102564102564),
#  ('Vietnam', '2020-12-13', 98186856.0, 1395.0, 35.0, 1.4207604325369172e-05, 0.025089605734767026),
#  ('Vietnam', '2020-12-20', 98186856.0, 1411.0, 35.0, 1.4370558926950466e-05, 0.024805102763997167),
#  ('Vietnam', '2020-12-27', 98186856.0, 1440.0, 35.0, 1.4665914142316564e-05, 0.024305555555555556),
#  ('Vietnam', '2021-01-03', 98186856.0, 1494.0, 35.0, 1.5215885922653435e-05, 0.023427041499330656),
#  ('Vietnam', '2021-01-10', 98186856.0, 1514.0, 35.0, 1.5419579174630055e-05, 0.023117569352708058),
#  ('Vietnam', '2021-01-17', 98186856.0, 1537.0, 35.0, 1.5653826414403165e-05, 0.02277163305139883),
#  ('Vietnam', '2021-01-24', 98186856.0, 1548.0, 35.0, 1.5765857702990305e-05, 0.02260981912144703),
#  ('Vietnam', '2021-01-31', 98186856.0, 1819.0, 35.0, 1.8525901267273492e-05, 0.019241341396371632),
#  ('Vietnam', '2021-02-07', 98186856.0, 2005.0, 35.0, 2.0420248510656048e-05, 0.017456359102244388),
#  ('Vietnam', '2021-02-14', 98186856.0, 2229.0, 35.0, 2.2701612932794182e-05, 0.01570210856886496),
#  ('Vietnam', '2021-02-21', 98186856.0, 2383.0, 35.0, 2.4270050973014146e-05, 0.014687368862778011),
#  ('Vietnam', '2021-02-28', 98186856.0, 2448.0, 35.0, 2.493205404193816e-05, 0.014297385620915032),
#  ('Vietnam', '2021-03-07', 98186856.0, 2512.0, 35.0, 2.5583872448263338e-05, 0.01393312101910828),
#  ('Vietnam', '2021-03-14', 98186856.0, 2554.0, 35.0, 2.601162827741424e-05, 0.01370399373531715),
#  ('Vietnam', '2021-03-21', 98186856.0, 2572.0, 35.0, 2.6194952204193197e-05, 0.013608087091757388),
#  ('Vietnam', '2021-03-28', 98186856.0, 2591.0, 35.0, 2.6388460793570986e-05, 0.013508297954457738),
#  ('Vietnam', '2021-04-04', 98186856.0, 2631.0, 35.0, 2.6795847297524223e-05, 0.01330292664386165),
#  ('Vietnam', '2021-04-11', 98186856.0, 2696.0, 35.0, 2.7457850366448235e-05, 0.01298219584569733),
#  ('Vietnam', '2021-04-18', 98186856.0, 2785.0, 35.0, 2.8364285337744187e-05, 0.012567324955116697),
#  ('Vietnam', '2021-04-25', 98186856.0, 2846.0, 35.0, 2.8985549756272875e-05, 0.012297962052002811),
#  ('Vietnam', '2021-05-02', 98186856.0, 2962.0, 35.0, 3.0166970617737265e-05, 0.011816340310600946),
#  ('Vietnam', '2021-05-09', 98186856.0, 3412.0, 35.0, 3.4750068787211195e-05, 0.010257913247362251),
#  ('Vietnam', '2021-05-16', 98186856.0, 4212.0, 37.0, 4.289779886627595e-05, 0.008784425451092117),
#  ('Vietnam', '2021-05-23', 98186856.0, 5275.0, 42.0, 5.3724095208833245e-05, 0.007962085308056872),
#  ('Vietnam', '2021-05-30', 98186856.0, 7168.0, 47.0, 7.300366150842023e-05, 0.006556919642857143),
#  ('Vietnam', '2021-06-06', 98186856.0, 8791.0, 53.0, 8.953336890632286e-05, 0.006028893186213173),
#  ('Vietnam', '2021-06-13', 98186856.0, 10630.0, 60.0, 0.00010826296342557298, 0.005644402634054563),
#  ('Vietnam', '2021-06-20', 98186856.0, 13258.0, 67.0, 0.0001350282567353007, 0.005053552572031981),
#  ('Vietnam', '2021-06-27', 98186856.0, 15740.0, 80.0, 0.00016030658930559912, 0.005082592121982211),
#  ('Vietnam', '2021-07-04', 98186856.0, 20261.0, 99.0, 0.00020635144891491383, 0.004886234637974433),
#  ('Vietnam', '2021-07-11', 98186856.0, 30478.0, 162.0, 0.0003104081466871696, 0.0053153094035041665),
#  ('Vietnam', '2021-07-18', 98186856.0, 55845.0, 254.0, 0.0005687624828317143, 0.00454830333960068),
#  ('Vietnam', '2021-07-25', 98186856.0, 101173.0, 370.0, 0.0010304128691115235, 0.0036571021912960968),
#  ('Vietnam', '2021-08-01', 98186856.0, 157507.0, 1306.0, 0.001604155651954066, 0.008291694972286946),
#  ('Vietnam', '2021-08-08', 98186856.0, 215560.0, 3397.0, 0.002195405869803999, 0.01575895342364075),
#  ('Vietnam', '2021-08-15', 98186856.0, 275044.0, 5774.0, 0.002801230339832859, 0.02099300475560274),
#  ('Vietnam', '2021-08-22', 98186856.0, 348059.0, 8277.0, 0.0035448634794865005, 0.023780451015488754),
#  ('Vietnam', '2021-08-29', 98186856.0, 435265.0, 10749.0, 0.004433027166080152, 0.024695300564024216),
#  ('Vietnam', '2021-09-05', 98186856.0, 524307.0, 13074.0, 0.005339889893205258, 0.02493577236237548),
#  ('Vietnam', '2021-09-12', 98186856.0, 613375.0, 15279.0, 0.006247017421557932, 0.024909720807010392),
#  ('Vietnam', '2021-09-19', 98186856.0, 687063.0, 17090.0, 0.006997504839140588, 0.0248739926324078),
#  ('Vietnam', '2021-09-26', 98186856.0, 756689.0, 18584.0, 0.007706622157246791, 0.02455962753522253),
#  ('Vietnam', '2021-10-03', 98186856.0, 808578.0, 19715.0, 0.00823509411483753, 0.024382310673800176),
#  ('Vietnam', '2021-10-10', 98186856.0, 839662.0, 20555.0, 0.00855167416705959, 0.02448008841652951),
#  ('Vietnam', '2021-10-17', 98186856.0, 864053.0, 21194.0, 0.008800088272507677, 0.024528587945415386),
#  ('Vietnam', '2021-10-24', 98186856.0, 888940.0, 21673.0, 0.009053553970604783, 0.024380723108421265),
#  ('Vietnam', '2021-10-31', 98186856.0, 921122.0, 22083.0, 0.00938131678236036, 0.023974022985011757),
#  ('Vietnam', '2021-11-07', 98186856.0, 968684.0, 22531.0, 0.009865719704885957, 0.023259391091418873),
#  ('Vietnam', '2021-11-14', 98186856.0, 1026522.0, 23082.0, 0.010454780220277142, 0.02248563596298959),
#  ('Vietnam', '2021-11-21', 98186856.0, 1094514.0, 23761.0, 0.011147255799696856, 0.02170917868569977),
#  ('Vietnam', '2021-11-28', 98186856.0, 1210340.0, 24882.0, 0.01232690452986905, 0.020557859774939274),
#  ('Vietnam', '2021-12-05', 98186856.0, 1309092.0, 26260.0, 0.013332660330828803, 0.020059705505800968),
#  ('Vietnam', '2021-12-12', 98186856.0, 1413051.0, 27839.0, 0.014391447669940669, 0.01970134128209102),
#  ('Vietnam', '2021-12-19', 98186856.0, 1540478.0, 29566.0, 0.0156892486709219, 0.019192744070346997),
#  ('Vietnam', '2021-12-26', 98186856.0, 1651673.0, 31214.0, 0.016821732228598906, 0.01889841391122819),
#  ('Vietnam', '2022-01-02', 98186856.0, 1763040.0, 32831.0, 0.017955967548242913, 0.018621812324167347),
#  ('Vietnam', '2022-01-09', 98186856.0, 1899575.0, 34319.0, 0.019346530456174297, 0.01806667280839135),
#  ('Vietnam', '2022-01-16', 98186856.0, 2023546.0, 35609.0, 0.02060913326321397, 0.017597326673077854),
#  ('Vietnam', '2022-01-23', 98186856.0, 2141422.0, 36719.0, 0.021809660551713766, 0.01714701726236118),
#  ('Vietnam', '2022-01-30', 98186856.0, 2263053.0, 37668.0, 0.02304843124827217, 0.016644771465803055),
#  ('Vietnam', '2022-02-06', 98186856.0, 2341971.0, 38324.0, 0.023852184451246712, 0.01636399425953609),
#  ('Vietnam', '2022-02-13', 98186856.0, 2510860.0, 38946.0, 0.025572261932900672, 0.015511020128561528),
#  ('Vietnam', '2022-02-20', 98186856.0, 2787493.0, 39501.0, 0.028389675701603074, 0.014170797917698806),
#  ('Vietnam', '2022-02-27', 98186856.0, 3321005.0, 40144.0, 0.03382331541403057, 0.012087907124499963),
#  ('Vietnam', '2022-03-06', 98186856.0, 4434700.0, 40813.0, 0.0451659232270356, 0.009203102802895349),
#  ('Vietnam', '2022-03-13', 98186856.0, 6112648.0, 41385.0, 0.062255257465418795, 0.006770388218003065),
#  ('Vietnam', '2022-03-20', 98186856.0, 7958048.0, 41880.0, 0.08105003382530142, 0.005262597058977277),
#  ('Vietnam', '2022-03-27', 98186856.0, 9011473.0, 42306.0, 0.09177881202347492, 0.004694681990391582),
#  ('Vietnam', '2022-04-03', 98186856.0, 9818328.0, 42600.0, 0.09999635796465466, 0.004338824288616147),
#  ('Vietnam', '2022-04-10', 98186856.0, 10198236.0, 42813.0, 0.10386559276325133, 0.0041980789618910564),
#  ('Vietnam', '2022-04-17', 98186856.0, 10432547.0, 42944.0, 0.106251971241446, 0.004116348577197879),
#  ('Vietnam', '2022-04-24', 98186856.0, 10563502.0, 43013.0, 0.1075857037320759, 0.004071850414758288),
#  ('Vietnam', '2022-05-01', 98186856.0, 10653526.0, 43042.0, 0.10850256779787307, 0.004040164730437603),
#  ('Vietnam', '2022-05-08', 98186856.0, 10676184.0, 43056.0, 0.10873333188303738, 0.004032901643508579),
#  ('Vietnam', '2022-05-15', 98186856.0, 10696630.0, 43065.0, 0.10894156749453307, 0.004026034367833608),
#  ('Vietnam', '2022-05-22', 98186856.0, 10708887.0, 43075.0, 0.10906640090400695, 0.004022360120150675),
#  ('Vietnam', '2022-05-29', 98186856.0, 10717251.0, 43078.0, 0.10915158542198357, 0.004019500896265283),
#  ('Vietnam', '2022-06-05', 98186856.0, 10725239.0, 43081.0, 0.10923294050682303, 0.004016786945260614),
#  ('Vietnam', '2022-06-12', 98186856.0, 10731812.0, 43083.0, 0.10929988429408515, 0.004014513112976634),
#  ('Vietnam', '2022-06-19', 98186856.0, 10737640.0, 43083.0, 0.10935924050771113, 0.004012334181440242),
#  ('Vietnam', '2022-06-26', 98186856.0, 10743448.0, 43084.0, 0.10941839302808515, 0.004010258159205499),
#  ('Vietnam', '2022-07-03', 98186856.0, 10748127.0, 43088.0, 0.10946604706438508, 0.0040088845247176555),
#  ('Vietnam', '2022-07-10', 98186856.0, 10754348.0, 43089.0, 0.1095294058504124, 0.004006658516164811),
#  ('Vietnam', '2022-07-17', 98186856.0, 10759850.0, 43091.0, 0.10958544186403117, 0.0040047956058866995),
#  ('Vietnam', '2022-07-24', 98186856.0, 10767200.0, 43092.0, 0.10966029913413258, 0.004002154692027639),
#  ('Vietnam', '2022-07-31', 98186856.0, 10774679.0, 43093.0, 0.10973647022570923, 0.003999469496956708),
#  ('Vietnam', '2022-08-07', 98186856.0, 11346137.0, 43094.0, 0.11555657714511197, 0.003798120893481191),
#  ('Vietnam', '2022-08-14', 98186856.0, 11364355.0, 43098.0, 0.11574212132833747, 0.0037923841696251128),
#  ('Vietnam', '2022-08-21', 98186856.0, 11382258.0, 43106.0, 0.11592445734284434, 0.003787122027984254),
#  ('Vietnam', '2022-08-28', 98186856.0, 11401597.0, 43113.0, 0.11612141853284313, 0.0037813123898345117),
#  ('Vietnam', '2022-09-04', 98186856.0, 11417503.0, 43122.0, 0.11628341577614014, 0.003776832815371277),
#  ('Vietnam', '2022-09-11', 98186856.0, 11437970.0, 43130.0, 0.11649186526555041, 0.0037707740097237532),
#  ('Vietnam', '2022-09-18', 98186856.0, 11456558.0, 43141.0, 0.11668117777393748, 0.003765616164994757),
#  ('Vietnam', '2022-09-25', 98186856.0, 11471340.0, 43146.0, 0.1168317274564734, 0.003761199650607514),
#  ('Vietnam', '2022-10-02', 98186856.0, 11480028.0, 43151.0, 0.11692021180513204, 0.0037587887416302467),
#  ('Vietnam', '2022-10-09', 98186856.0, 11485361.0, 43153.0, 0.11697452661077161, 0.0037572175572017285),
#  ('Vietnam', '2022-10-16', 98186856.0, 11492273.0, 43155.0, 0.11704492299865472, 0.003755131817700467),
#  ('Vietnam', '2022-10-23', 98186856.0, 11496829.0, 43159.0, 0.117091324321455, 0.0037539916441307426),
#  ('Vietnam', '2022-10-30', 98186856.0, 11502169.0, 43163.0, 0.11714571041973276, 0.0037525965754806765),
#  ('Vietnam', '2022-11-06', 98186856.0, 11505608.0, 43166.0, 0.11718073547441014, 0.003751735675333281),
#  ('Vietnam', '2022-11-13', 98186856.0, 11508447.0, 43166.0, 0.11720964973152823, 0.0037508101657851836),
#  ('Vietnam', '2022-11-20', 98186856.0, 11511178.0, 43169.0, 0.11723746404508563, 0.003750180911110922),
#  ('Vietnam', '2022-11-27', 98186856.0, 11514174.0, 43170.0, 0.11726797729423173, 0.003749291959631668),
#  ('Vietnam', '2022-12-04', 98186856.0, 11517517.0, 43177.0, 0.11730202462129961, 0.0037488114842808566),
#  ('Vietnam', '2022-12-11', 98186856.0, 11520445.0, 43179.0, 0.117331845313389, 0.0037480323025716454),
#  ('Vietnam', '2022-12-18', 98186856.0, 11522750.0, 43180.0, 0.1173553209606793, 0.0037473693345772495),
#  ('Vietnam', '2022-12-25', 98186856.0, 11524202.0, 43184.0, 0.1173701090907728, 0.0037472442777382762),
#  ('Vietnam', '2023-01-01', 98186856.0, 11525231.0, 43186.0, 0.117380589108587, 0.0037470832471817703),
#  ('Vietnam', '2023-01-08', 98186856.0, 11525711.0, 43186.0, 0.11738547774663444, 0.003746927196074932),
#  ('Vietnam', '2023-01-15', 98186856.0, 11526118.0, 43186.0, 0.11738962290431217, 0.0037467948879232366),
#  ('Vietnam', '2023-01-22', 98186856.0, 11526318.0, 43186.0, 0.11739165983683193, 0.003746729875056371),
#  ('Vietnam', '2023-01-29', 98186856.0, 11526395.0, 43186.0, 0.11739244405585204, 0.0037467048457041426),
#  ('Vietnam', '2023-02-05', 98186856.0, 11526566.0, 43186.0, 0.11739418563315644, 0.003746649262234737),
#  ('Vietnam', '2023-02-12', 98186856.0, 11526651.0, 43186.0, 0.11739505132947733, 0.0037466216336384263),
#  ('Vietnam', '2023-02-19', 98186856.0, 11526806.0, 43186.0, 0.11739662995218016, 0.0037465712531294447),
#  ('Vietnam', '2023-02-26', 98186856.0, 11526891.0, 43186.0, 0.11739749564850106, 0.0037465436256836297),
#  ('Vietnam', '2023-03-05', 98186856.0, 11526950.0, 43186.0, 0.11739809654359439, 0.0037465244492255107),
#  ('Vietnam', '2023-03-12', 98186856.0, 11527033.0, 43186.0, 0.11739894187059009, 0.003746497472506585),
#  ('Vietnam', '2023-03-19', 98186856.0, 11527116.0, 43186.0, 0.1173997871975858, 0.0037464704961761466),
#  ('Vietnam', '2023-03-26', 98186856.0, 11527203.0, 43186.0, 0.11740067326323189, 0.0037464422201986033),
#  ('Vietnam', '2023-04-02', 98186856.0, 11527316.0, 43186.0, 0.11740182413010557, 0.0037464054945661246),
#  ('Vietnam', '2023-04-09', 98186856.0, 11527701.0, 43186.0, 0.11740574522520611, 0.0037462803728167482),
#  ('Vietnam', '2023-04-16', 98186856.0, 11530356.0, 43186.0, 0.117432785504406, 0.0037454177477260894),
#  ('Vietnam', '2023-04-23', 98186856.0, 11543060.0, 43187.0, 0.11756217145806155, 0.003741382267786878),
#  ('Vietnam', '2023-04-30', 98186856.0, 11559862.0, 43191.0, 0.11773329415904711, 0.0037362902775136936),
#  ('Vietnam', '2023-05-07', 98186856.0, 11573931.0, 43196.0, 0.11787658217715007, 0.0037321805357229104),
#  ('Vietnam', '2023-05-14', 98186856.0, 11589567.0, 43201.0, 0.11803582956154539, 0.0037275767075681085),
#  ('Vietnam', '2023-05-21', 98186856.0, 11601759.0, 43203.0, 0.11816000096795033, 0.003723831877562704),
#  ('Vietnam', '2023-05-28', 98186856.0, 11609537.0, 43206.0, 0.11823921727364405, 0.0037215954434703124),
#  ('Vietnam', '2023-06-04', 98186856.0, 11614583.0, 43206.0, 0.11829060908111774, 0.00371997858209804),
#  ('Vietnam', '2023-06-11', 98186856.0, 11617497.0, 43206.0, 0.11832028718793074, 0.003719045505240931),
#  ('Vietnam', '2023-06-18', 98186856.0, 11619267.0, 43206.0, 0.11833831404073067, 0.003718478971177786),
#  ('Vietnam', '2023-06-25', 98186856.0, 11620047.0, 43206.0, 0.11834625807755775, 0.003718229366886382),
#  ('Vietnam', '2023-07-02', 98186856.0, 11620596.0, 43206.0, 0.1183518494573245, 0.0037180537039580414),
#  ('Vietnam', '2023-07-09', 98186856.0, 11621033.0, 43206.0, 0.1183563001548802, 0.003717913889410692),
#  ('Vietnam', '2023-07-16', 98186856.0, 11621320.0, 43206.0, 0.11835922315304606, 0.00371782207184726),
#  ('Vietnam', '2023-07-23', 98186856.0, 11621599.0, 43206.0, 0.11836206467391114, 0.0037177328180055084),
#  ('Vietnam', '2023-07-30', 98186856.0, 11621798.0, 43206.0, 0.1183640914217683, 0.00371766915928155),
#  ('Vietnam', '2023-08-06', 98186856.0, 11621978.0, 43206.0, 0.1183659246610361, 0.0037176115804039554),
#  ('Vietnam', '2023-08-13', 98186856.0, 11622204.0, 43206.0, 0.11836822639478344, 0.0037175392894497465),
#  ('Vietnam', '2023-08-20', 98186856.0, 11622404.0, 43206.0, 0.1183702633273032, 0.0037174753174988584),
#  ('Vietnam', '2023-08-27', 98186856.0, 11622683.0, 43206.0, 0.11837310484816828, 0.00371738608030521),
#  ('Vietnam', '2023-09-03', 98186856.0, 11622912.0, 43206.0, 0.1183754371359034, 0.0037173128386414696),
#  ('Vietnam', '2023-09-10', 98186856.0, 11623182.0, 43206.0, 0.11837818699480508, 0.0037172264875487623),
#  ('Vietnam', '2023-09-17', 98186856.0, 11623372.0, 43206.0, 0.11838012208069887, 0.00371716572436983),
#  ('Vietnam', '2023-09-24', 98186856.0, 11623571.0, 43206.0, 0.11838214882855604, 0.003717102085064908),
#  ('Vietnam', '2023-10-01', 98186856.0, 11623698.0, 43206.0, 0.11838344228070609, 0.0037170614721752063),
#  ('Vietnam', '2023-10-08', 98186856.0, 11623845.0, 43206.0, 0.11838493942610812, 0.0037170144646629408),
#  ('Vietnam', '2023-10-15', 98186856.0, 11623987.0, 43206.0, 0.11838638564819715, 0.0037169690571746167),
#  ('Vietnam', '2023-10-22', 98186856.0, 11624000.0, 43206.0, 0.11838651804881094, 0.0037169649002064694)]

# %% [markdown]
# **COVID-19 Trends in Vietnam**
#
# 1. **COVID-19 Cases and Deaths**
#    - Vietnam experienced a gradual increase in COVID-19 cases over time. The first cases were recorded in January 2020, with only 2 cases, and peaked in March 2023 with 11,527,253 cases.
#    - Similarly, the number of deaths also increased steadily. Vietnam reported its first COVID-19 death in August 2020, with subsequent deaths rising to 43,186 by March 2023.
#
# 2. **COVID-19 Percentage Trends**
#    - The COVID-19 percentage relative to the population provides insights into the spread of the virus. In August 2020, Vietnam reached a peak COVID-19 percentage of 0.008%.
#    - Despite fluctuations, the COVID-19 percentage generally increased over time, indicating the virus's impact on the population.
#
# 3. **Death Percentage**
#    - The death percentage remained relatively low throughout the analyzed period. By March 2023, the death percentage stood at 0.004%, showing Vietnam's efforts in managing COVID-19 fatalities.
#
# **Detailed Analysis**
#
# **COVID-19 Cases Over Time**
# - Vietnam saw an initial rise in cases from January 2020 to August 2020, with cases reaching 808,578.
# - A more significant surge occurred from August 2021 to November 2021, where cases rose from 157,507 to 1,094,514.
# - The most substantial increase in cases was observed from November 2021 to March 2023, reaching a peak of 11,527,253 cases.
#
# **COVID-19 Deaths Over Time**
# - Deaths followed a similar pattern, with the first reported death in August 2020.
# - From August 2020 to August 2021, deaths remained relatively low, ranging from 3 to 370.
# - A notable increase in deaths occurred from August 2021 to March 2023, reaching a total of 43,186 deaths.
#
# **COVID-19 Percentage and Death Percentage Trends**
# - The COVID-19 percentage, which represents the proportion of cases relative to the population, steadily increased over time.
# - The death percentage remained relatively low but showed a slight increase in recent months, indicating a need for continued vigilance.
#
# **Conclusion**
#
# Vietnam has faced significant challenges due to the COVID-19 pandemic, with cases and deaths steadily increasing over time. The data highlights periods of surges and the country's efforts to manage the impact of the virus. Despite the challenges, Vietnam's death percentage has remained comparatively low, reflecting effective public health measures.

# %% [markdown]
# ### Vaccination Insights

# %%
# %%sql
# SELECT
#   location,
#   date,
#   population,
#   total_vaccinations AS total_vaccinations,
#   people_vaccinated AS people_vaccinated,
#   people_fully_vaccinated AS people_fully_vaccinated,
#   people_vaccinated / population AS vaccinated_percentage,
#   people_fully_vaccinated / population AS fully_vaccinated_percentage,
#   total_vaccinations / people_vaccinated AS avg_vaccination
# FROM COVID_COMBINE_VIEW
# WHERE continent IS NOT NULL
#   AND location == 'Vietnam'
#   AND NOT (new_cases == 0 AND new_deaths == 0)
# ORDER BY location, date
# Out:
#  * sqlite:///covid_data.db
# Done.
# [('Vietnam', '2020-01-26', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-02-02', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-02-09', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-02-16', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-03-08', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-03-15', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-03-22', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-03-29', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-04-05', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-04-12', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-04-19', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-04-26', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-05-10', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-05-17', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-05-24', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-05-31', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-06-07', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-06-14', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-06-21', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-06-28', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-07-12', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-07-19', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-07-26', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-08-02', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-08-09', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-08-16', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-08-23', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-08-30', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-09-06', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-09-13', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-09-20', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-09-27', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-10-04', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-10-11', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-10-18', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-10-25', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-11-01', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-11-08', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-11-15', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-11-22', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-11-29', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-12-06', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-12-13', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-12-20', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2020-12-27', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2021-01-03', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2021-01-10', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2021-01-17', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2021-01-24', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2021-01-31', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2021-02-07', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2021-02-14', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2021-02-21', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2021-02-28', 98186856.0, None, None, None, None, None, None),
#  ('Vietnam', '2021-03-07', 98186856.0, 0.0, 0.0, None, 0.0, None, None),
#  ('Vietnam', '2021-03-14', 98186856.0, 11605.0, 11605.0, None, 0.00011819300945943314, None, 1.0),
#  ('Vietnam', '2021-03-21', 98186856.0, 33891.0, 33891.0, None, 0.0003451684001369796, None, 1.0),
#  ('Vietnam', '2021-03-28', 98186856.0, 45140.0, 45140.0, None, 0.000459735669711229, None, 1.0),
#  ('Vietnam', '2021-04-04', 98186856.0, 52413.0, 52413.0, None, 0.0005338087207925265, None, 1.0),
#  ('Vietnam', '2021-04-11', 98186856.0, 58418.0, 58418.0, None, 0.0005949676196985063, None, 1.0),
#  ('Vietnam', '2021-04-18', 98186856.0, 79182.0, 79182.0, None, 0.0008064419539006321, None, 1.0),
#  ('Vietnam', '2021-04-25', 98186856.0, 209632.0, 209632.0, None, 0.0021350311899181293, None, 1.0),
#  ('Vietnam', '2021-05-02', 98186856.0, 519262.0, 532247.0, 9407.0, 0.005420756114239976, 9.580712106720272e-05, 0.975603432241046),
#  ('Vietnam', '2021-05-09', 98186856.0, 519262.0, 851513.0, 9407.0, 0.008672372603518337, 9.580712106720272e-05, 0.6098110069957828),
#  ('Vietnam', '2021-05-16', 98186856.0, 979238.0, 956677.0, 22561.0, 0.009743432461061794, 0.000229776172892225, 1.0235826721035417),
#  ('Vietnam', '2021-05-23', 98186856.0, 1027659.0, 998698.0, 28961.0, 0.01017140216812727, 0.00029495801352474307, 1.0289987563808078),
#  ('Vietnam', '2021-05-30', 98186856.0, 1034867.0, 1005906.0, 28961.0, 0.010244813216139643, 0.00029495801352474307, 1.0287909605867744),
#  ('Vietnam', '2021-06-06', 98186856.0, 1248559.0, 1214916.0, 33643.0, 0.012373509545921299, 0.0003426426038124696, 1.0276916264169704),
#  ('Vietnam', '2021-06-13', 98186856.0, 1498323.0, 1443058.0, 55265.0, 0.01469705884054379, 0.0005628553785243923, 1.0382971439817388),
#  ('Vietnam', '2021-06-20', 98186856.0, 2422643.0, 2300960.0, 121683.0, 0.023434501253406056, 0.0012393002990135462, 1.052883579027884),
#  ('Vietnam', '2021-06-27', 98186856.0, 3386607.0, 3229471.0, 157136.0, 0.03289107250770918, 0.0016003771421298997, 1.0486568852917397),
#  ('Vietnam', '2021-07-04', 98186856.0, 3890855.0, 3667519.0, 223336.0, 0.03735244358980188, 0.0022746018061725083, 1.060895662708223),
#  ('Vietnam', '2021-07-11', 98186856.0, 4051585.0, 3774138.0, 277447.0, 0.03843832213142664, 0.0028257040840578497, 1.0735126802464563),
#  ('Vietnam', '2021-07-18', 98186856.0, 4283906.0, 3977431.0, 306475.0, 0.04050879274513077, 0.0031213444699767145, 1.0770535051393726),
#  ('Vietnam', '2021-07-25', 98186856.0, 4613491.0, 4223628.0, 389863.0, 0.043016226122975156, 0.00397062311476803, 1.0923052408971623),
#  ('Vietnam', '2021-08-01', 98186856.0, 6415219.0, 5756155.0, 659064.0, 0.05862449654157375, 0.00671234447103592, 1.1144972642328081),
#  ('Vietnam', '2021-08-08', 98186856.0, 9405819.0, 8460013.0, 945806.0, 0.0861623779867236, 0.009632714993949904, 1.1117972277347565),
#  ('Vietnam', '2021-08-15', 98186856.0, 14666708.0, 13287434.0, 1379274.0, 0.1353280320942347, 0.014047440321339956, 1.1038028862457567),
#  ('Vietnam', '2021-08-22', 98186856.0, 17364569.0, 15530221.0, 1834348.0, 0.15817006097027894, 0.01868221546884035, 1.1181147389982409),
#  ('Vietnam', '2021-08-29', 98186856.0, 19710560.0, 17186153.0, 2524407.0, 0.1750351696768863, 0.025710233557127034, 1.1468861006881528),
#  ('Vietnam', '2021-09-05', 98186856.0, 22012123.0, 18673340.0, 3338783.0, 0.19018166749325388, 0.034004378345712585, 1.1787994541951252),
#  ('Vietnam', '2021-09-12', 98186856.0, 29280307.0, 23954248.0, 5326059.0, 0.24396593368872102, 0.05424411389646696, 1.22234298484344),
#  ('Vietnam', '2021-09-19', 98186856.0, 34553590.0, 27913529.0, 6640061.0, 0.28428987480768303, 0.06762678092065602, 1.2378796675977444),
#  ('Vietnam', '2021-09-26', 98186856.0, 39232772.0, 30946214.0, 8286558.0, 0.31517674830121867, 0.08439579733564338, 1.267772917229875),
#  ('Vietnam', '2021-10-03', 98186856.0, 45496123.0, 34622194.0, 10873929.0, 0.3526153643212692, 0.1107472979886432, 1.3140739434363982),
#  ('Vietnam', '2021-10-10', 98186856.0, 54279564.0, 38698136.0, 15581428.0, 0.39412745836367347, 0.15869158698797728, 1.4026402718725264),
#  ('Vietnam', '2021-10-17', 98186856.0, 63434180.0, 45281937.0, 18152243.0, 0.46118125016651923, 0.18487447036699087, 1.4008716102405248),
#  ('Vietnam', '2021-10-24', 98186856.0, 72929311.0, 51883474.0, 21045837.0, 0.5284156771452179, 0.2143447489549925, 1.4056366194754037),
#  ('Vietnam', '2021-10-31', 98186856.0, 81929875.0, 57332644.0, 21045837.0, 0.5839136350388895, 0.2143447489549925, 1.4290266292271467),
#  ('Vietnam', '2021-11-07', 98186856.0, 89620701.0, 60845405.0, 21045837.0, 0.6196899206142216, 0.2143447489549925, 1.4729247179799363),
#  ('Vietnam', '2021-11-14', 98186856.0, 99751224.0, 64467940.0, 21045837.0, 0.6565842173416776, 0.2143447489549925, 1.5472996965623533),
#  ('Vietnam', '2021-11-21', 98186856.0, 108915813.0, 66916471.0, 21045837.0, 0.6815216794394557, 0.2143447489549925, 1.6276383283870424),
#  ('Vietnam', '2021-11-28', 98186856.0, 120644108.0, 70958765.0, 21045837.0, 0.7226910799547345, 0.2143447489549925, 1.7002002219176164),
#  ('Vietnam', '2021-12-05', 98186856.0, 127828796.0, 73393169.0, 53224715.0, 0.7474846633239789, 0.5420757641939365, 1.7416988221342506),
#  ('Vietnam', '2021-12-12', 98186856.0, 132873501.0, 74907297.0, 56385381.0, 0.7629055461354216, 0.5742660809915331, 1.7738392162248224),
#  ('Vietnam', '2021-12-19', 98186856.0, 138772562.0, 75697403.0, 56385381.0, 0.7709525091627335, 0.5742660809915331, 1.833253936069643),
#  ('Vietnam', '2021-12-26', 98186856.0, 146335052.0, 77138616.0, 56385381.0, 0.7856307773007825, 0.5742660809915331, 1.8970401543112985),
#  ('Vietnam', '2022-01-02', 98186856.0, 153596950.0, 77796499.0, 68435813.0, 0.7923310936852892, 0.6969956650816888, 1.9743427014626969),
#  ('Vietnam', '2022-01-09', 98186856.0, 161277807.0, 78291624.0, 68435813.0, 0.7973737747545354, 0.6969956650816888, 2.0599624680157356),
#  ('Vietnam', '2022-01-16', 98186856.0, 165524173.0, 78527765.0, 71946807.0, 0.7997787911652859, 0.7327539543582086, 2.107842659217412),
#  ('Vietnam', '2022-01-23', 98186856.0, 176429307.0, 78894694.0, 71946807.0, 0.8035158392280124, 0.7327539543582086, 2.2362632777306923),
#  ('Vietnam', '2022-01-30', 98186856.0, 181280001.0, 79059864.0, 71946807.0, 0.8051980399494613, 0.7327539543582086, 2.292946026317475),
#  ('Vietnam', '2022-02-06', 98186856.0, 181665411.0, 79080967.0, 74187748.0, 0.8054129668842844, 0.7555771823470954, 2.2972077592323825),
#  ('Vietnam', '2022-02-13', 98186856.0, 186001127.0, 79216176.0, 76182386.0, 0.8067900249296097, 0.7758918973839024, 2.3480195130853074),
#  ('Vietnam', '2022-02-20', 98186856.0, 191667067.0, 79216176.0, 76182386.0, 0.8067900249296097, 0.7758918973839024, 2.419544551102795),
#  ('Vietnam', '2022-02-27', 98186856.0, 193625095.0, 79216176.0, 76799876.0, 0.8067900249296097, 0.7821808246920545, 2.444262078492655),
#  ('Vietnam', '2022-03-06', 98186856.0, 197910353.0, 79603926.0, 77454922.0, 0.8107391278523064, 0.7888522471887683, 2.48618834452964),
#  ('Vietnam', '2022-03-13', 98186856.0, 200179247.0, 79660025.0, 77601333.0, 0.8113104772394383, 0.7903433938245258, 2.5129197109842734),
#  ('Vietnam', '2022-03-20', 98186856.0, 201828138.0, 79696647.0, 77686643.0, 0.8116834599531326, 0.7912122473908321, 2.532454571144003),
#  ('Vietnam', '2022-03-27', 98186856.0, 205216774.0, 80001969.0, 77853733.0, 0.8147930615071329, 0.7929140026644707, 2.565146540330776),
#  ('Vietnam', '2022-04-03', 98186856.0, 206525077.0, 80054556.0, 77953607.0, 0.8153286423592176, 0.7939311856568664, 2.5798041650496444),
#  ('Vietnam', '2022-04-10', 98186856.0, 208525313.0, 80204811.0, 78397756.0, 0.816858938838005, 0.7984546933654745, 2.599910284683546),
#  ('Vietnam', '2022-04-17', 98186856.0, 209638138.0, 80281024.0, 78458405.0, 0.8176351425286497, 0.799072382967431, 2.611303737231852),
#  ('Vietnam', '2022-04-24', 98186856.0, 212600099.0, 80988198.0, 78558918.0, 0.8248374711173153, 0.8000960739592273, 2.625075063406152),
#  ('Vietnam', '2022-05-01', 98186856.0, 214991119.0, 81900697.0, 78619918.0, 0.834130965554086, 0.8007173383777559, 2.6250218481046628),
#  ('Vietnam', '2022-05-08', 98186856.0, 215743796.0, 82220083.0, 78641329.0, 0.8373838042028762, 0.8009354021886596, 2.623979301991218),
#  ('Vietnam', '2022-05-15', 98186856.0, 217039026.0, 82930237.0, 78674447.0, 0.8446164830860864, 0.8012726978446076, 2.617127767282276),
#  ('Vietnam', '2022-05-22', 98186856.0, 219119853.0, 83821858.0, 78738898.0, 0.8536973421371187, 0.8019291095337648, 2.614113528717056),
#  ('Vietnam', '2022-05-29', 98186856.0, 220779518.0, 84340713.0, 79046788.0, 0.8589817052498351, 0.8050648653013189, 2.617709883481777),
#  ('Vietnam', '2022-06-05', 98186856.0, 222072995.0, 84666253.0, 79411087.0, 0.8622972203122585, 0.8087751277014105, 2.6229222049073084),
#  ('Vietnam', '2022-06-12', 98186856.0, 223629992.0, 85085764.0, 79538300.0, 0.8665697983037567, 0.8100707491845955, 2.628289169501963),
#  ('Vietnam', '2022-06-19', 98186856.0, 225836499.0, 85545084.0, 79786295.0, 0.8712478175286517, 0.8125964945857926, 2.6399705095853316),
#  ('Vietnam', '2022-06-26', 98186856.0, 229854734.0, 86109082.0, 79786295.0, 0.8769919468650672, 0.8125964945857926, 2.669343682005575),
#  ('Vietnam', '2022-07-03', 98186856.0, 233534502.0, 86510260.0, 79786295.0, 0.881077809437141, 0.8125964945857926, 2.699500637265453),
#  ('Vietnam', '2022-07-10', 98186856.0, 234856999.0, 86785069.0, 80185029.0, 0.8838766463812631, 0.8166574658424749, 2.7061913034833216),
#  ('Vietnam', '2022-07-17', 98186856.0, 234856999.0, 86785069.0, 80185029.0, 0.8838766463812631, 0.8166574658424749, 2.7061913034833216),
#  ('Vietnam', '2022-07-24', 98186856.0, 241480787.0, 87717272.0, 81040637.0, 0.8933708194098811, 0.8253715446393355, 2.752944562617041),
#  ('Vietnam', '2022-07-31', 98186856.0, 241480787.0, 87717272.0, 81040637.0, 0.8933708194098811, 0.8253715446393355, 2.752944562617041),
#  ('Vietnam', '2022-08-07', 98186856.0, 247726474.0, 88433596.0, 82004318.0, 0.9006663376613261, 0.8351863104772395, 2.801271068972475),
#  ('Vietnam', '2022-08-14', 98186856.0, 247726474.0, 88433596.0, 82004318.0, 0.9006663376613261, 0.8351863104772395, 2.801271068972475),
#  ('Vietnam', '2022-08-21', 98186856.0, 253398589.0, 89255868.0, 82993225.0, 0.909040900545792, 0.8452579946138615, 2.839013217595957),
#  ('Vietnam', '2022-08-28', 98186856.0, 253398589.0, 89255868.0, 82993225.0, 0.909040900545792, 0.8452579946138615, 2.839013217595957),
#  ('Vietnam', '2022-09-04', 98186856.0, 257351937.0, 89618505.0, 83666271.0, 0.9127342360366443, 0.8521127410373543, 2.8716383630813747),
#  ('Vietnam', '2022-09-11', 98186856.0, 258223943.0, 89753472.0, 83849273.0, 0.9141088293936207, 0.8539765546622656, 2.8770356984072993),
#  ('Vietnam', '2022-09-18', 98186856.0, 259176472.0, 89880152.0, 84072281.0, 0.9153990224516406, 0.8562478158991057, 2.8835784790395103),
#  ('Vietnam', '2022-09-25', 98186856.0, 259794452.0, 89975153.0, 84234230.0, 0.9163665755831921, 0.8578972118223237, 2.8874021697968106),
#  ('Vietnam', '2022-10-02', 98186856.0, 260210114.0, 89975153.0, 84374202.0, 0.9163665755831921, 0.8593227794156073, 2.892021911871603),
#  ('Vietnam', '2022-10-09', 98186856.0, 260246761.0, 89975153.0, 84389728.0, 0.9163665755831921, 0.8594809064871167, 2.8924292132073397),
#  ('Vietnam', '2022-10-16', 98186856.0, 260375471.0, 90028108.0, 84393196.0, 0.9169059043911132, 0.8595162268970095, 2.8921575359553264),
#  ('Vietnam', '2022-10-23', 98186856.0, 261059430.0, 90044496.0, 84433722.0, 0.9170728106417828, 0.8599289705334897, 2.899226955526521),
#  ('Vietnam', '2022-10-30', 98186856.0, 261694006.0, 90063216.0, 84448184.0, 0.9172634675256329, 0.860076261123994, 2.9056702350047106),
#  ('Vietnam', '2022-11-06', 98186856.0, 262184598.0, 90067653.0, 84467885.0, 0.917308656873584, 0.8602769091618536, 2.9109740208285433),
#  ('Vietnam', '2022-11-13', 98186856.0, 262184598.0, 90067653.0, 84467885.0, 0.917308656873584, 0.8602769091618536, 2.9109740208285433),
#  ('Vietnam', '2022-11-20', 98186856.0, 263040545.0, 90156999.0, 84690714.0, 0.9182186157381391, 0.8625463473440885, 2.9175831928478453),
#  ('Vietnam', '2022-11-27', 98186856.0, 263040545.0, 90156999.0, 84690714.0, 0.9182186157381391, 0.8625463473440885, 2.9175831928478453),
#  ('Vietnam', '2022-12-04', 98186856.0, 264635919.0, 90156999.0, 85239151.0, 0.9182186157381391, 0.8681319931458036, 2.935278701989626),
#  ('Vietnam', '2022-12-11', 98186856.0, 264635919.0, 90156999.0, 85239151.0, 0.9182186157381391, 0.8681319931458036, 2.935278701989626),
#  ('Vietnam', '2022-12-18', 98186856.0, 265114272.0, 90156999.0, 85553108.0, 0.9182186157381391, 0.8713295392613447, 2.9405844797473795),
#  ('Vietnam', '2022-12-25', 98186856.0, 265336568.0, 90156999.0, 85705657.0, 0.9182186157381391, 0.8728831993561338, 2.9430501341332356),
#  ('Vietnam', '2023-01-01', 98186856.0, 265336568.0, 90156999.0, 85705657.0, 0.9182186157381391, 0.8728831993561338, 2.9430501341332356),
#  ('Vietnam', '2023-01-08', 98186856.0, 265536860.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.945271725382075),
#  ('Vietnam', '2023-01-15', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-01-22', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-01-29', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-02-05', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-02-12', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-02-19', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-02-26', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-03-05', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-03-12', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-03-19', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-03-26', 98186856.0, 265668329.0, 90156999.0, 85848363.0, 0.9182186157381391, 0.8743366118169625, 2.9467299482761176),
#  ('Vietnam', '2023-04-02', 98186856.0, 265980213.0, 90228395.0, 85861691.0, 0.9189457599090453, 0.8744723530000797, 2.947854863205757),
#  ('Vietnam', '2023-04-09', 98186856.0, 265980213.0, 90228395.0, 85861691.0, 0.9189457599090453, 0.8744723530000797, 2.947854863205757),
#  ('Vietnam', '2023-04-16', 98186856.0, 265980213.0, 90228395.0, 85861691.0, 0.9189457599090453, 0.8744723530000797, 2.947854863205757),
#  ('Vietnam', '2023-04-23', 98186856.0, 266128292.0, 90245924.0, 85908380.0, 0.9191242868597401, 0.8749478647121566, 2.9489231225556516),
#  ('Vietnam', '2023-04-30', 98186856.0, 266128292.0, 90245924.0, 85908380.0, 0.9191242868597401, 0.8749478647121566, 2.9489231225556516),
#  ('Vietnam', '2023-05-07', 98186856.0, 266266588.0, 90253541.0, 85923905.0, 0.9192018634347555, 0.8751059815990034, 2.950206552006641),
#  ('Vietnam', '2023-05-14', 98186856.0, 266312906.0, 90259259.0, 85931210.0, 0.9192600993354956, 0.8751803805592879, 2.950532820128736),
#  ('Vietnam', '2023-05-21', 98186856.0, 266312906.0, 90259259.0, 85931210.0, 0.9192600993354956, 0.8751803805592879, 2.950532820128736),
#  ('Vietnam', '2023-05-28', 98186856.0, 266403148.0, 90267647.0, 85950998.0, 0.9193455282853745, 0.8753819146627936, 2.9512583617029478),
#  ('Vietnam', '2023-06-04', 98186856.0, 266419940.0, 90268546.0, 85953004.0, 0.9193546842970509, 0.8754023450959668, 2.9514149923274493),
#  ('Vietnam', '2023-06-11', 98186856.0, 266448231.0, 90270583.0, 85958364.0, 0.9193754304547648, 0.8754569348874965, 2.951661794407598),
#  ('Vietnam', '2023-06-18', 98186856.0, 266448231.0, 90270583.0, 85958364.0, 0.9193754304547648, 0.8754569348874965, 2.951661794407598),
#  ('Vietnam', '2023-06-25', 98186856.0, 266448231.0, 90270583.0, 85958364.0, 0.9193754304547648, 0.8754569348874965, 2.951661794407598),
#  ('Vietnam', '2023-07-02', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-07-09', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-07-16', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-07-23', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-07-30', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-08-06', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-08-13', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-08-20', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-08-27', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-09-03', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-09-10', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-09-17', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-09-24', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-10-01', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-10-08', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-10-15', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123),
#  ('Vietnam', '2023-10-22', 98186856.0, 266492149.0, 90497674.0, 85961564.0, 0.9216882756689958, 0.8754895258078128, 2.944740314541123)]

# %% [markdown]
# **COVID-19 Vaccinations in Vietnam**
#
# **Vaccination Progress:**
# 1. **Total Vaccinations:**
#    - The total number of COVID-19 vaccine doses administered in Vietnam steadily increased over time.
#    - It started from zero and reached 265,668,329 by January 22, 2023.
#
# 2. **People Vaccinated:**
#    - The count of individuals who received at least one vaccine dose also rose steadily.
#    - It started from zero and reached 90,156,999 by January 22, 2023.
#
# 3. **People Fully Vaccinated:**
#    - The number of individuals fully vaccinated (received all required doses) increased over time.
#    - It started from zero and reached 85,848,363 by January 22, 2023.
#
# **Vaccination Rates:**
#
# 4. **Vaccinated Percentage:**
#    - The percentage of the population that received at least one dose increased over time.
#    - It started from 0% and reached approximately 87.43% by January 22, 2023.
#
# 5. **Fully Vaccinated Percentage:**
#    - The percentage of the population fully vaccinated also increased steadily.
#    - It started from 0% and reached around 87.43% by January 22, 2023.
#
# **Average Vaccination Rate:**
#
# 6. **Average Vaccination Rate:**
#    - The average number of vaccine doses administered per day increased as the vaccination campaign progressed.
#    - The average vaccination rate was calculated as the total vaccinations divided by the number of days.
#
# **Trends:**
#
# - **Early Stages (2020-2021):**
#   - Vaccination numbers remained low in 2020 and early 2021, with very few doses administered.
#   - Significant vaccination efforts began around March 2021, leading to a noticeable increase in total vaccinations.
#
# - **Rapid Expansion (Mid-2021):**
#   - The vaccination campaign rapidly expanded from May to September 2021, with a sharp rise in total and fully vaccinated individuals.
#   - Vaccination rates steadily increased during this period.
#
# - **Steady Progress (Late 2021 - Early 2023):**
#   - From late 2021 to early 2023, Vietnam maintained a steady increase in vaccination rates and percentages.
#   - The campaign focused on achieving high rates of full vaccination.
#
# **Observations:**
#
# - Vietnam experienced a substantial increase in vaccination rates and percentages starting from mid-2021.
# - The data suggests a successful vaccination campaign, with a large proportion of the population receiving both doses.
# - By January 22, 2023, approximately 87.43% of the population had been fully vaccinated, indicating significant progress in combating COVID-19.
#
# **Limitations:**
#
# - The dataset does not provide information on vaccine types, specific demographics, or vaccine distribution regions.
# - The average vaccination rate is a simplistic calculation and does not account for fluctuations in daily vaccination rates.
#
# This analysis provides an overview of Vietnam's COVID-19 vaccination progress based on the provided dataset. For a more detailed analysis or specific insights, additional data and parameters would be necessary.

# %% [markdown]
# # Conclusion

# %% [markdown]
# In conclusion, this project has provided a comprehensive analysis of COVID-19 data using SQL querying techniques. Here are the key takeaways:
#
# - **Global Overview:** We explored the global impact of COVID-19, highlighting total cases, deaths, vaccination efforts, and related percentages. The data revealed significant progress in vaccination campaigns, impacting COVID-19 percentages and trends over time.
#
# - **Continental and Income-Level Analysis:** Our analysis across continents and income levels showcased disparities in COVID-19 impact and vaccination rates. Higher income countries generally exhibited higher vaccination rates, while lower income countries faced challenges in controlling the spread.
#
# - **Country-Specific Insights:** Delving into individual countries' data provided a nuanced view of the pandemic. We observed varied trends in total cases, deaths, and vaccination rates, reflecting regional differences in healthcare infrastructure and response strategies.
#
# - **Vietnam's COVID-19 Trends:** Focusing on Vietnam, we analyzed its total cases, deaths, vaccinations, and trends over time. The data revealed a notable increase in cases in 2022, corresponding with an acceleration in vaccination efforts. The decreasing death percentage suggested positive impacts from these efforts.

# %% [markdown]
# ## Key Learnings

# %% [markdown]
# - **Data Analysis Skills:** Utilizing SQL and data visualization tools, we gained insights into complex datasets.
# - **Regional Disparities:** Highlighted the importance of equitable access to vaccines and healthcare resources across different regions and income levels.
# - **Impact of Vaccination:** Demonstrated the effectiveness of vaccination campaigns in reducing COVID-19 percentages and mortality rates.

# %% [markdown]
# ## Future Considerations

# %% [markdown]
# - **Continued Monitoring:** Ongoing monitoring of COVID-19 data is crucial for adapting strategies and interventions.
# - **Equitable Distribution:** Ensuring equitable distribution of vaccines to all regions and income levels remains a critical challenge.
# - **Healthcare Infrastructure:** Investing in healthcare infrastructure and response capabilities is essential for future pandemic preparedness.

# %% [markdown]
# This project underscores the power of data analysis in understanding and combating global health crises. By examining COVID-19 data through multiple lenses, we gain valuable insights that can inform policy decisions, healthcare strategies, and international collaborations in the ongoing fight against the pandemic.
